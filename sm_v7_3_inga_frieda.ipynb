# %%
# Load data and define sharpe function to evaluate the models: 
#need volatility data and the data from the risk_adjusted_returns file:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#Get volatility historical data:
url_volatility = 'https://raw.githubusercontent.com/inga-maria01/master_thesis/main/data/volatility_data.csv'
volatility_df = pd.read_csv(url_volatility)
#make the date a datetime object:
volatility_df['Date'] = pd.to_datetime(volatility_df['Date'])

# first we need the historical data: 
url_nasdaq_price = 'https://raw.githubusercontent.com/inga-maria01/master_thesis/main/data/QQQ.csv'
price_df = pd.read_csv(url_nasdaq_price)
price_df['Date'] = pd.to_datetime(price_df['Date'])
price_df.head()
#this dataset includes the prices and the volume!
# we now need to calculate the returns:
price_df['r_ndq'] = (price_df['Adj Close'] - price_df['Adj Close'].shift(1)) / price_df['Adj Close'].shift(1)
price_df.dropna(inplace=True)
price_df.head()

rf_df = pd.read_csv('https://raw.githubusercontent.com/inga-maria01/master_thesis/main/data/IEF.csv')
rf_df['r_rf'] = (rf_df['Adj Close'] - rf_df['Adj Close'].shift(1)) / rf_df['Adj Close'].shift(1)
rf_df.dropna(inplace=True)
rf_df['Date'] = pd.to_datetime(rf_df['Date'])

portfolio_df = pd.merge(price_df[['Date', 'r_ndq']], 
                     rf_df[['Date', 'r_rf']], 
                     on='Date', 
                     how='inner')

portfolio_df = pd.merge(portfolio_df,  
                     volatility_df[['Date', 'Price']],
                     on='Date', 
                     how='inner')

portfolio_df.rename(columns={'Price' : 'Volatility'}, inplace = True)
portfolio_df.head()

r_rf_df = pd.read_csv('https://raw.githubusercontent.com/inga-maria01/master_thesis/main/data/risk_free_rate.csv')

#divide by 100 because it was already in % -> we dont want that here!
#then divide by 252 since its on a yearly basis but everything else is on a daily basis
#(252 ~ number of us trading days a year)
r_rf_df['daily_rf'] = r_rf_df['rf_rate']/(100*250)
r_rf_df['Date'] = pd.to_datetime(r_rf_df['Date'])
#r_rf_df.set_index('Date', inplace=True)
r_rf_df.head()

portfolio_df = pd.merge(portfolio_df, 
                        r_rf_df[['Date', 'rf_rate', 'daily_rf']], 
                        on='Date', 
                        how='inner')

sentiment_index_df = pd.read_excel('https://raw.githubusercontent.com/inga-maria01/master_thesis/main/index/sentiment_index_unweighted_v7.xlsx')
sentiment_index_df.rename(columns={'date':'Date'}, inplace=True)
# sentiment_index_df['lag_sentiment'] = sentiment_index_df['sentiment_score'].shift(1)
sentiment_index_df.head()

portfolio_df_sent = pd.merge(portfolio_df, sentiment_index_df, on='Date', how='inner')
portfolio_df_sent.set_index('Date', inplace=True)
portfolio_df_sent['moving_average_10day'] = portfolio_df_sent['sentiment_score'].rolling(window = 10).mean() # maybe try exponential?
portfolio_df_sent['moving_average_5day'] = portfolio_df_sent['sentiment_score'].rolling(window = 5).mean() # maybe try exponential?
portfolio_df_sent['moving_average_20day'] = portfolio_df_sent['sentiment_score'].rolling(window = 20).mean() # maybe try exponential?
portfolio_df_sent['moving_average_30day'] = portfolio_df_sent['sentiment_score'].rolling(window = 30).mean() # maybe try exponential?
portfolio_df_sent['moving_average_15day'] = portfolio_df_sent['sentiment_score'].rolling(window = 15).mean() # maybe try exponential?

#want to just look at the training period for threshold optimization
#and then just at the test period for calculating the sharpe
portfolio_df_sent_train = portfolio_df_sent[:'2018-06-30'].copy()
portfolio_df_sent_test = portfolio_df_sent['2018-07-01':].copy()


data_df = pd.merge(portfolio_df_sent, price_df[['Date', 'Close', 'Adj Close']], on='Date', how='inner')
data_df = data_df.rename(columns={'Close': 'close_qqq', 'Adj Close': 'adj_close_qqq'})

# %%
# future MA includes today as today's sentiment is still unknown before the trading day 
portfolio_df_sent['sentiment_ma_next_10'] = portfolio_df_sent['sentiment_score'].rolling(window=10).mean().shift(-9)

portfolio_df_sent['sentiment_ma_next_5'] = portfolio_df_sent['sentiment_score'].rolling(window=5).mean().shift(-4)

portfolio_df_sent['sentiment_ma_next_15'] = portfolio_df_sent['sentiment_score'].rolling(window=15).mean().shift(-14)

# %%
# ma_past = portfolio_df_sent.copy()
# ma_past = ma_past.drop(columns='sentiment_ma_next_10')
# ma_past = ma_past.dropna()

ma_future_5day = portfolio_df_sent.copy()
ma_future_5day = ma_future_5day[ma_future_5day['sentiment_ma_next_5'].notna()]

# %%
def sharpe_correct_5day(sentiment, version): # version is either sentiment_score or moving_average_10day
    w_ndq = []
    w_rf = []

    # Assuming 'sentiment' is a pandas Series
    
    upper = ma_future_5day[version].shift(1).rolling(63).quantile(0.75) #apply(lambda x: weighted_quantile(x, quantile=0.75), raw=True)
    lower = ma_future_5day[version].shift(1).rolling(63).quantile(0.25) #apply(lambda x: weighted_quantile(x, quantile=0.25), raw=True)
    test_sent = sentiment['2018-07-01':]
    test_df = ma_future_5day['2018-07-01':].copy()
    for i in test_sent.index:
        score = sentiment[i]
        if score > upper[i]: #23: changing to see if it improves
            w_ndq.append(0.8)
            w_rf.append(0.2)
        elif score <= upper[i] and score > lower[i]: # was 20:
            w_ndq.append(0.6)
            w_rf.append(0.4)
        elif score <= lower[i]:
            w_ndq.append(0.2)
            w_rf.append(0.8)
    test_df['w_ndq'] = w_ndq
    test_df['w_rf'] = w_rf
    test_df['r_portfolio'] = test_df['w_ndq'] * test_df['r_ndq'] + test_df['w_rf'] * test_df['r_rf']
    test_df['excess returns'] = test_df['r_portfolio'] - test_df['daily_rf']
    test_df['trading day'] = (test_df['w_ndq'] != test_df['w_ndq'].shift(1)).astype(int)
    
    test_df.reset_index(inplace=True)
    # Identify maximum index in the dataset
    max_index = test_df.index.max()

    # Initialize starting portfolio value
    initial_portfolio_value = 1

    # Create a new DataFrame to store calculated values
    df_calc = pd.DataFrame(index=test_df.index, columns=['portfolio_value', 'ndq_start', 'rf_start', 'ndq_end', 'rf_end'])
    
    # Initialize first values from row 0
    df_calc.loc[0, 'portfolio_value'] = initial_portfolio_value
    df_calc.loc[0, 'ndq_start'] = 0
    df_calc.loc[0, 'rf_start'] = 0
    df_calc.loc[0, 'ndq_end'] = w_ndq[0] * initial_portfolio_value
    df_calc.loc[0, 'rf_end'] = w_rf[0] * initial_portfolio_value

    # Loop through rows from 1 to max_index to calculate the required columns
    for i in range(1, max_index + 1):
        # Calculate ndq_start and rf_start
        df_calc.loc[i, 'ndq_start'] = df_calc.loc[i - 1, 'ndq_end'] * (1 + test_df.loc[i, 'r_ndq'])
        df_calc.loc[i, 'rf_start'] = df_calc.loc[i - 1, 'rf_end'] * (1 + test_df.loc[i, 'r_rf'])

        # Calculate the new portfolio value
        df_calc.loc[i, 'portfolio_value'] = df_calc.loc[i, 'ndq_start'] + df_calc.loc[i, 'rf_start']

        # Calculate ndq_end and rf_end based on updated portfolio value
        df_calc.loc[i, 'ndq_end'] =  w_ndq[i] * df_calc.loc[i, 'portfolio_value']
        df_calc.loc[i, 'rf_end'] = w_rf[i] * df_calc.loc[i, 'portfolio_value']
    
    return2019 = (df_calc['portfolio_value'][-1:]/df_calc['portfolio_value'][0]) **(1/(365/250)) - 1
    risk_free2019 = test_df['rf_rate'].mean()/100
    std2019 = np.std(test_df['excess returns'])*np.sqrt(250)

    test_df.set_index('Date', inplace=True)
    
    return (return2019 - risk_free2019)/std2019, df_calc, test_df, upper, lower

# %%
data_df.set_index('Date', inplace=True)
ma_future_only = ma_future_5day.copy()
ma_future_only = pd.DataFrame(ma_future_only['sentiment_ma_next_5'])
merged_df = ma_future_only.join(data_df, how='inner')
original_features = merged_df.columns

original_features = original_features.drop(['r_rf', 'daily_rf'])
original_features
# want to use lagged values of everything but the future moving average itself

import pandas as pd

df = merged_df.copy()
# Create lagged features
for feature in original_features:
    for lag in range(1, 4):  # 3 lags
        df[f'{feature}_lag_{lag}'] = df[feature].shift(lag)

# Drop rows with NaN values that were created due to lagging
df = df.dropna()

# Split the data into training and testing sets based on the year
train_ma_df = df[:'2018-06-30']
test_ma_df = df['2018-07-01':]

# Prepare features and target variables
features_ma = [f for f in df.columns if 'lag' in f and 'sentiment_ma_next' not in f]

X_train_ma = train_ma_df[features_ma]
y_train_ma = train_ma_df['sentiment_ma_next_5']
y_train_sc = train_ma_df['sentiment_score']

X_test_ma = test_ma_df[features_ma]
y_test_ma = test_ma_df['sentiment_ma_next_5']
y_test_sc = test_ma_df['sentiment_score']

# %%
print(features_ma)
# Out:
# ['r_ndq_lag_1', 'r_ndq_lag_2', 'r_ndq_lag_3', 'Volatility_lag_1', 'Volatility_lag_2', 'Volatility_lag_3', 'rf_rate_lag_1', 'rf_rate_lag_2', 'rf_rate_lag_3', 'sentiment_score_lag_1', 'sentiment_score_lag_2', 'sentiment_score_lag_3', 'sentiment_slope_lag_1', 'sentiment_slope_lag_2', 'sentiment_slope_lag_3', 'moving_average_10day_lag_1', 'moving_average_10day_lag_2', 'moving_average_10day_lag_3', 'moving_average_5day_lag_1', 'moving_average_5day_lag_2', 'moving_average_5day_lag_3', 'moving_average_20day_lag_1', 'moving_average_20day_lag_2', 'moving_average_20day_lag_3', 'moving_average_30day_lag_1', 'moving_average_30day_lag_2', 'moving_average_30day_lag_3', 'moving_average_15day_lag_1', 'moving_average_15day_lag_2', 'moving_average_15day_lag_3', 'close_qqq_lag_1', 'close_qqq_lag_2', 'close_qqq_lag_3', 'adj_close_qqq_lag_1', 'adj_close_qqq_lag_2', 'adj_close_qqq_lag_3']

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor

# Models to be used
models = {
    "Random Forest": RandomForestRegressor(random_state=42),
    # "Gradient Boosting": GradientBoostingRegressor(random_state=42)
}

# Hyperparameters for tuning (simplified for rolling window example)
parameters = {
    "Random Forest": {'n_estimators': 30, 'max_depth': 7, 'min_samples_leaf' : 3},
    #"Gradient Boosting": {'n_estimators': 120, 'max_depth': 3, 'learning_rate': 0.1, 'min_samples_leaf' : 3}
    # "Gradient Boosting": {'n_estimators': 98, 'max_depth': 2, 'learning_rate': 0.23333333333333334} # not better than current one
}

# Initialize dictionaries to store results
model_performance_rw_ma = {}
model_predictions_rw_ma = {}

# Create test and train data set with date index
X_train_idx = X_train_ma.copy()
# X_train_idx.set_index()
y_train_idx = pd.DataFrame(y_train_ma).copy()

X_test_idx = X_test_ma.copy()
y_test_idx = pd.DataFrame(y_test_ma).copy()

# Implementing rolling window forecasting
for model_name in models:
    print('Model:  ', model_name)
    model = models[model_name]
    params = parameters[model_name]

    # Initialize storage for predictions and actuals
    predictions = []
    feature_importances = []
    # actuals = y_test_idx
    #print(actuals.head())

    # Start rolling window forecast
    for i in X_test_idx.index:

        # Scale x train:
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train_idx)
        X_train_scaled_df = pd.DataFrame(X_train_scaled, columns = X_train_idx.columns)
        model.set_params(**params)
        # model.fit(X_train_scaled_df, y_train_idx)
        model.fit(X_train_scaled_df, y_train_idx.values.ravel())


        # Obtain feature importance
        importance = model.feature_importances_
        feature_importances.append(importance)

        # Scale x test for the current point:
        X_test_scaled = scaler.transform(X_test_idx.loc[[i]])
        X_test_scaled_df = pd.DataFrame(X_test_scaled, columns = X_test_idx.columns)
    
        # Make a prediction for the next point
        next_point_prediction = model.predict(X_test_scaled_df)
        predictions.append(next_point_prediction[0])

        # Rolling feature window
        # X_test_to_train = pd.Series([X_test[i]], index=[i])
        X_test_to_train = X_test_idx.loc[[i]]
        print(X_test_to_train)
        X_train_idx = pd.concat([X_train_idx, X_test_to_train])
        X_train_idx = X_train_idx.iloc[1:]

        # Rolling target variable window
        y_test_to_train = y_test_idx.loc[[i]]
        print(y_test_to_train)
        y_train_idx = pd.concat([y_train_idx, y_test_to_train])
        y_train_idx = y_train_idx.iloc[1:]
    
    # Calculate performance metrics
    rmse = np.sqrt(mean_squared_error(y_test_ma, predictions))
    r2 = r2_score(y_test_ma, predictions)

    # Store results
    model_performance_rw_ma[model_name] = {'RMSE': rmse, 'R2': r2}
    model_predictions_rw_ma[model_name] = {'y_pred': predictions, 'feature_importance': feature_importances}

# Output model performance
print(model_performance_rw_ma)
# Out:
# Model:   Random Forest
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-02     0.002687     0.008602    -0.013599             19.26
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-02             20.06             19.67           1.93           1.93
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-02           1.93              19.547577  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-02                   22.803948                   21.953136
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-02                   22.152931                    21.75164
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-02       171.649994       171.190002       169.729996
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-02           165.101883            164.65947           163.255127
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-02            22.513136
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-03       0.0067     0.002687     0.008602             18.32
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-03             19.26             20.06           1.99           1.93
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-03           1.93               24.98873  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-03                   22.931795                   22.139909
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-03                   21.953136                   22.152931
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-03       172.800003       171.649994       171.190002
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-03           166.208023           165.101883            164.65947
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-03            21.431483
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-05    -0.011574       0.0067     0.002687             19.26
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-05             18.32             19.26           1.98           1.99
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-05           1.93              19.706582  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-05                   22.949502                   21.920727
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-05                   22.139909                   21.953136
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-05       170.800003       172.800003       171.649994
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-05           164.284317           166.208023           165.101883
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-05            21.841671
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-06     0.012412    -0.011574       0.0067             18.76
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-06             19.26             18.32           1.96           1.98
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-06           1.99              21.223874  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-06                   23.136622                   21.901837
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-06                   21.920727                   22.139909
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-06       172.919998       170.800003       172.800003
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-06           166.323456           164.284317           166.208023
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-06             23.46415
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-09     0.015556     0.012412    -0.011574             16.72
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-09             18.76             19.26           1.97           1.96
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-09           1.98              24.142937  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-09                   23.178225                   21.747884
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-09                   21.901837                   21.920727
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-09       175.610001       172.919998       170.800003
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-09           168.910812           166.323456           164.284317
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-09            23.170854
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-10     0.008997     0.015556     0.012412             15.23
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-10             16.72             18.76           1.99           1.97
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-10           1.96              22.503557  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-10                   23.195735                   21.938367
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-10                   21.747884                   21.901837
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-10       177.190002       175.610001       172.919998
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-10           170.430557           168.910812           166.323456
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-10            22.785633
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-11     0.000734     0.008997     0.015556             15.12
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-11             15.23             16.72           1.99           1.99
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-11           1.97              19.580463  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-11                   23.222198                   21.622005
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-11                   21.938367                   21.747884
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-11       177.320007       177.190002       175.610001
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-11           170.555649           170.430557           168.910812
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-11            23.857897
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-12    -0.005076     0.000734     0.008997             15.45
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-12             15.12             15.23           1.97           1.99
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-12           1.99              21.757524  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-12                   23.170114                   21.513245
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-12                   21.622005                   21.938367
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-12       176.419998       177.320007       177.190002
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-12           169.689957           170.555649           170.430557
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-12            23.230621
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-13     0.017232    -0.005076     0.000734             15.43
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-13             15.45             15.12           1.98           1.97
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-13           1.99              29.336269  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-13                    22.90636                   21.868514
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-13                   21.513245                   21.622005
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-13       179.460007       176.419998       177.320007
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-13           172.614014           169.689957           170.555649
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-13            21.574617
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-16     0.000836     0.017232    -0.005076             15.07
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-16             15.43             15.45           1.98           1.98
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-16           1.97              22.676456  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-16                   22.731171                   22.121988
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-16                   21.868514                   21.513245
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-16       179.610001       179.460007       176.419998
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-16            172.75827           172.614014           169.689957
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-16            21.446615
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-17    -0.002394     0.000836     0.017232              15.6
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-17             15.07             15.43           2.02           1.98
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-17           1.98              20.577455  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-17                   22.866934                   22.334749
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-17                   22.121988                   21.868514
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-17       179.179993       179.610001       179.460007
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-17           172.344666            172.75827           172.614014
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-17            22.013948
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-18     0.006083    -0.002394     0.000836              14.3
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-18              15.6             15.07           2.02           2.02
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-18           1.98              24.941782  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-18                   22.755068                   22.704604
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-18                   22.334749                   22.121988
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-18       180.270004       179.179993       179.610001
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-18           173.393082           172.344666            172.75827
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-18            21.972795
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-19    -0.001886     0.006083    -0.002394             13.94
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-19              14.3              15.6            2.0           2.02
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-19           2.02              18.621143  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-19                   22.392701                   22.357338
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-19                   22.704604                   22.334749
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-19       179.929993       180.270004       179.179993
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-19           173.066055           173.393082           172.344666
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-19            22.511887
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-20    -0.005002    -0.001886     0.006083             15.89
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-20             13.94              14.3            2.0            2.0
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-20           2.02              21.056247  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-20                   22.391159                   22.462609
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-20                   22.357338                   22.704604
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-20       179.029999       179.929993       180.270004
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-20           172.200348           173.066055           173.393082
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-20            22.742129
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-23    -0.000223    -0.005002    -0.001886             15.43
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-23             15.89             13.94           1.99            2.0
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-23            2.0               22.03645  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-23                   22.167584                   22.179803
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-23                   22.462609                   22.357338
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-23       178.990005       179.029999       179.929993
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-23           172.161896           172.200348           173.066055
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-23            21.851282
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-24     0.003185    -0.000223    -0.005002             13.97
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-24             15.43             15.89            2.0           1.99
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-24            2.0              23.414116  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-24                   22.107125                   22.437572
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-24                   22.179803                   22.462609
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-24       179.559998       178.990005       179.029999
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-24           172.710175           172.161896           172.200348
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-24            20.543853
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-25     0.004121     0.003185    -0.000223             14.42
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-25             13.97             15.43           2.02            2.0
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-25           1.99              24.736019  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-25                   22.166367                   22.420725
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-25                   22.437572                   22.179803
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-25       180.300003       179.559998       178.990005
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-25           173.421951           172.710175           172.161896
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-25            20.073119
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-26     0.013976     0.004121     0.003185             13.75
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-26             14.42             13.97           2.01           2.02
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-26            2.0              21.316605  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-26                   22.195354                    22.52806
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-26                   22.420725                   22.437572
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-26       182.820007       180.300003       179.559998
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-26           175.845734           173.421951           172.710175
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-26            20.217694
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-27    -0.015151     0.013976     0.004121             15.28
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-27             13.75             14.42           1.99           2.01
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-27           2.02              22.207455  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-27                   22.280317                   22.593632
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-27                    22.52806                   22.420725
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-27       180.050003       182.820007       180.300003
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-27           173.181458           175.845734           173.421951
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-27            20.766563
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-30    -0.013496    -0.015151     0.013976             16.92
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-30             15.28             13.75            2.0           1.99
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-30           2.01              17.582215  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-30                   22.224394                    22.15625
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-30                   22.593632                    22.52806
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-30       177.619995       180.050003       182.820007
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-30           170.844147           173.181458           175.845734
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-30            21.908653
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-07-31    -0.014131    -0.013496    -0.015151              17.9
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-07-31             16.92             15.28           2.05            2.0
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-07-31           1.99              16.876973  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-07-31                   22.247735                   21.781145
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-07-31                    22.15625                   22.593632
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-07-31       175.110001       177.619995       180.050003
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-07-31           168.429916           170.844147           173.181458
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-07-31            23.296553
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-08-01     0.007652    -0.014131    -0.013496              16.4
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-08-01              17.9             16.92           2.03           2.05
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-08-01            2.0              22.382348  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-08-01                   21.952067                   21.967937
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-08-01                   21.781145                    22.15625
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-08-01       176.449997       175.110001       177.619995
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-08-01            169.71875           168.429916           170.844147
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-08-01            23.677873
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-08-02     0.003797     0.007652    -0.014131             15.35
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-08-02              16.4              17.9           2.03           2.03
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-08-02           2.05               22.03948  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-08-02                   21.859756                   21.986734
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-08-02                   21.967937                   21.781145
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-08-02       177.119995       176.449997       175.110001
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-08-02            170.36319            169.71875           168.429916
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-08-02             23.91963
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-08-03     0.013607     0.003797     0.007652             14.33
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-08-03             15.35              16.4           2.02           2.03
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-08-03           2.03              24.951799  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-08-03                   21.794971                   21.694436
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-08-03                   21.986734                   21.967937
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-08-03       179.529999       177.119995       176.449997
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-08-03            172.68129            170.36319            169.71875
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-08-03            23.655978
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-08-06     0.003064     0.013607     0.003797             13.56
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-08-06             14.33             15.35           2.01           2.02
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-08-06           2.03              23.292668  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-08-06                   21.749989                   21.735517
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-08-06                   21.694436                   21.986734
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-08-06       180.080002       179.529999       177.119995
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-08-06           173.210327            172.68129            170.36319
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-08-06            22.641498
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-08-07     0.005886     0.003064     0.013607             12.73
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-08-07             13.56             14.33           2.06           2.01
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-08-07           2.02               23.81647  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-08-07                   21.781475                   21.951451
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-08-07                   21.735517                   21.694436
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-08-07       181.139999       180.080002       179.529999
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-08-07           174.229828           173.210327            172.68129
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-08-07            22.326019
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-08-08     0.003644     0.005886     0.003064             12.01
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-08-08             12.73             13.56           2.06           2.06
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-08-08           2.01               24.28895  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-08-08                   21.928753                   21.907929
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-08-08                   21.951451                   21.735517
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-08-08       181.800003       181.139999       180.080002
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-08-08             174.8647           174.229828           173.210327
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-08-08             22.20374
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-08-09      0.00121     0.003644     0.005886             11.89
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-08-09             12.01             12.73           2.06           2.06
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-08-09           2.06              23.248263  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-08-09                     22.1431                   22.216404
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-08-09                   21.907929                   21.951451
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-08-09       182.020004       181.800003       181.139999
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-08-09           175.076324             174.8647           174.229828
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-08-09            21.158613
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-08-10    -0.000604      0.00121     0.003644             12.87
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-08-10             11.89             12.01           2.06           2.06
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-08-10           2.06              23.633539  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-08-10                   22.306267                   22.388223
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-08-10                   22.216404                   21.907929
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-08-10       181.910004       182.020004       181.800003
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-08-10           174.970505           175.076324             174.8647
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-08-10             20.37713
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-08-13    -0.007641    -0.000604      0.00121             13.89
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2018-08-13             12.87             11.89           2.05           2.06
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2018-08-13           2.06              18.220267  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2018-08-13                   22.286871                   22.133811
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2018-08-13                   22.388223                   22.216404
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2018-08-13       180.520004       181.910004       182.020004
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2018-08-13            173.63353           174.970505           175.076324
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2018-08-13            20.655105
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2018-08-14    -0.001108    -0.007641    -0.000604             14.33
#
# ...
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2019-12-10    -0.004536     0.010698     0.001976             15.47
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2019-12-10             14.24             15.91           1.54           1.53
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2019-12-10           1.54              19.421242  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2019-12-10                   21.705674                   22.005816
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2019-12-10                    22.26939                   21.904879
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2019-12-10       204.070007            205.0       202.830002
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2019-12-10           198.395935           199.300049           197.190414
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2019-12-10            22.905696
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2019-12-11    -0.000833    -0.004536     0.010698             15.51
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2019-12-11             15.47             14.24           1.56           1.54
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2019-12-11           1.53              17.482563  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2019-12-11                   21.809061                   21.490509
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2019-12-11                   22.005816                    22.26939
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2019-12-11       203.899994       204.070007            205.0
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2019-12-11           198.230652           198.395935           199.300049
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2019-12-11            23.946002
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2019-12-12     0.005297    -0.000833    -0.004536             14.77
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2019-12-12             15.51             15.47           1.57           1.56
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2019-12-12           1.54              23.207731  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2019-12-12                   21.778773                   21.653733
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2019-12-12                   21.490509                   22.005816
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2019-12-12       204.979996       203.899994       204.070007
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2019-12-12           199.280624           198.230652           198.395935
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2019-12-12             23.16544
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2019-12-13     0.007464     0.005297    -0.000833             14.12
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2019-12-13             14.77             15.51           1.56           1.57
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2019-12-13           1.56              23.146175  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2019-12-13                   21.516935                   22.085393
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2019-12-13                   21.653733                   21.490509
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2019-12-13       206.509995       204.979996       203.899994
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2019-12-13           200.768066           199.280624           198.230652
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2019-12-13            23.081009
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2019-12-16     0.003293     0.007464     0.005297             12.55
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2019-12-16             14.12             14.77           1.57           1.56
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2019-12-16           1.57              24.376457  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2019-12-16                   21.480797                   22.517114
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2019-12-16                   22.085393                   21.653733
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2019-12-16       207.190002       206.509995       204.979996
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2019-12-16           201.429169           200.768066           199.280624
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2019-12-16            22.350264
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2019-12-17     0.010039     0.003293     0.007464             11.73
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2019-12-17             12.55             14.12           1.57           1.57
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2019-12-17           1.56              26.315553  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2019-12-17                   21.617484                   22.915387
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2019-12-17                   22.517114                   22.085393
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2019-12-17       209.270004       207.190002       206.509995
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2019-12-17            203.45134           201.429169           200.768066
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2019-12-17             22.26429
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2019-12-18     0.000573     0.010039     0.003293             11.79
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2019-12-18             11.73             12.55           1.56           1.57
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2019-12-18           1.57              22.684092  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2019-12-18                   21.609202                    22.70221
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2019-12-18                   22.915387                   22.517114
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2019-12-18       209.389999       209.270004       207.190002
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2019-12-18           203.568008            203.45134           201.429169
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2019-12-18            22.695252
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2019-12-19     0.000764     0.000573     0.010039             11.95
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2019-12-19             11.79             11.73           1.56           1.56
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2019-12-19           1.57              19.304922  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2019-12-19                   21.876717                   22.276028
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2019-12-19                    22.70221                   22.915387
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2019-12-19       209.550003       209.389999       209.270004
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2019-12-19           203.723541           203.568008            203.45134
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2019-12-19            24.594906
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2019-12-20     0.006251     0.000764     0.000573             11.73
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2019-12-20             11.95             11.79           1.57           1.56
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2019-12-20           1.56              22.724018  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2019-12-20                    21.81421                   22.094421
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2019-12-20                   22.276028                    22.70221
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2019-12-20       210.860001       209.550003       209.389999
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2019-12-20           204.997116           203.723541           203.568008
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2019-12-20            24.558201
#             r_ndq_lag_1  r_ndq_lag_2  r_ndq_lag_3  Volatility_lag_1  \
# Date
# 2019-12-23     0.004031     0.006251     0.000764             11.78
#
#             Volatility_lag_2  Volatility_lag_3  rf_rate_lag_1  rf_rate_lag_2  \
# Date
# 2019-12-23             11.73             11.95           1.58           1.57
#
#             rf_rate_lag_3  sentiment_score_lag_1  ...  \
# Date                                              ...
# 2019-12-23           1.56              20.722737  ...
#
#             moving_average_30day_lag_3  moving_average_15day_lag_1  \
# Date
# 2019-12-23                   21.694263                   21.703479
#
#             moving_average_15day_lag_2  moving_average_15day_lag_3  \
# Date
# 2019-12-23                   22.094421                   22.276028
#
#             close_qqq_lag_1  close_qqq_lag_2  close_qqq_lag_3  \
# Date
# 2019-12-23       211.710007       210.860001       209.550003
#
#             adj_close_qqq_lag_1  adj_close_qqq_lag_2  adj_close_qqq_lag_3
# Date
# 2019-12-23           205.823502           204.997116           203.723541
#
# [1 rows x 36 columns]
#             sentiment_ma_next_5
# Date
# 2019-12-23            25.152148
# {'Random Forest': {'RMSE': 1.921813845709978, 'R2': 0.46908420113577076}}

# %%
rf_ma_predictions = model_predictions_rw_ma['Random Forest']['y_pred']
rf_ma_pred_series = pd.Series(rf_ma_predictions)
rf_ma_pred_series.index = pd.to_datetime(X_test_ma.index)
# 0.25/75, 1.24, 44 trading days / 0.33/66, many inputs

sharpe_rf_ma, df_calc_rf_ma, test_df_rf_ma, upper_rf_ma, lower_rf_ma = sharpe_correct_5day(rf_ma_pred_series, 'moving_average_10day')
print(sharpe_rf_ma)
test_df_rf_ma['trading day'].sum()
# Out:
# 368    2.014898
# Name: portfolio_value, dtype: object
# 83

# %% [markdown]
# ## Implement a for loop to test several hyperparameter combinations

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from itertools import product

# Models to be used
models = {
    "Random Forest": RandomForestRegressor(random_state=42),
    # "Gradient Boosting": GradientBoostingRegressor(random_state=42)
}

# Hyperparameters for tuning
n_estimators = [30, 40, 50]
max_depth = [None, 5, 10]
min_samples_leaf = [1, 3, 5]

# Initialize dictionaries to store results
model_performance_rw_ma = {}
model_predictions_rw_ma = {}

# Create test and train data set with date index
X_train_idx = X_train_ma.copy()
y_train_idx = pd.DataFrame(y_train_ma).copy()
X_test_idx = X_test_ma.copy()
y_test_idx = pd.DataFrame(y_test_ma).copy()

# Implementing rolling window forecasting
for model_name in models:
    print('Model:  ', model_name)
    model = models[model_name]

    # Initialize storage for performance metrics
    best_rmse = float('inf')
    best_r2 = -float('inf')
    best_params = None
    best_predictions = None
    best_feature_importances = None

    # Iterate through all combinations of hyperparameters
    for params in product(n_estimators, max_depth, min_samples_leaf):
        param_dict = {
            'n_estimators': params[0],
            'max_depth': params[1],
            'min_samples_leaf': params[2]
        }
        
        # Initialize storage for predictions and actuals
        predictions = []
        feature_importances = []

        # Start rolling window forecast
        for i in X_test_idx.index:

            # Scale x train:
            scaler = StandardScaler()
            X_train_scaled = scaler.fit_transform(X_train_idx)
            X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train_idx.columns)
            model.set_params(**param_dict)
            model.fit(X_train_scaled_df, y_train_idx.values.ravel())

            # Obtain feature importance
            importance = model.feature_importances_
            feature_importances.append(importance)

            # Scale x test for the current point:
            X_test_scaled = scaler.transform(X_test_idx.loc[[i]])
            X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_test_idx.columns)

            # Make a prediction for the next point
            next_point_prediction = model.predict(X_test_scaled_df)
            predictions.append(next_point_prediction[0])

            # Rolling feature window
            X_test_to_train = X_test_idx.loc[[i]]
            X_train_idx = pd.concat([X_train_idx, X_test_to_train])
            X_train_idx = X_train_idx.iloc[1:]

            # Rolling target variable window
            y_test_to_train = y_test_idx.loc[[i]]
            y_train_idx = pd.concat([y_train_idx, y_test_to_train])
            y_train_idx = y_train_idx.iloc[1:]

        # Calculate performance metrics
        rmse = np.sqrt(mean_squared_error(y_test_ma, predictions))
        r2 = r2_score(y_test_ma, predictions)

        # Store results if performance is better
        if rmse < best_rmse and r2 > best_r2:
            best_rmse = rmse
            best_r2 = r2
            best_params = param_dict
            best_predictions = predictions
            best_feature_importances = feature_importances

    # Store best results for the model
    model_performance_rw_ma[model_name] = {'RMSE': best_rmse, 'R2': best_r2, 'Best Params': best_params}
    model_predictions_rw_ma[model_name] = {'y_pred': best_predictions, 'feature_importance': best_feature_importances}

# Output model performance
print(model_performance_rw_ma)
# Out:
# Model:   Random Forest
# {'Random Forest': {'RMSE': 0.18975805398015316, 'R2': 0.9948238905728287, 'Best Params': {'n_estimators': 40, 'max_depth': None, 'min_samples_leaf': 1}}}

# %%
rf_ma_predictions = model_predictions_rw_ma['Random Forest']['y_pred']
rf_ma_pred_series = pd.Series(rf_ma_predictions)
rf_ma_pred_series.index = pd.to_datetime(X_test_ma.index)
# 0.25/75, 1.24, 44 trading days / 0.33/66, many inputs

sharpe_rf_ma, df_calc_rf_ma, test_df_rf_ma, upper_rf_ma, lower_rf_ma = sharpe_correct_5day(rf_ma_pred_series, 'moving_average_10day')
print(sharpe_rf_ma)
test_df_rf_ma['trading day'].sum()
# Out:
# 368    4.333296
# Name: portfolio_value, dtype: object
# 71
