# %%
import pandas as pd
import requests
from io import BytesIO
from typing import List

def load_and_merge_csv_xz_from_github(years: List[int], companies: List[str], base_url: str) -> pd.DataFrame:
    all_dataframes = []
    
    for year in years:
        for company in companies:
            filename = f"df_{year}_{company}.csv.xz"
            file_url = f"{base_url}/{filename}"
            
            response = requests.get(file_url)
            if response.status_code == 200:
                file_content = BytesIO(response.content)
                df = pd.read_csv(file_content, compression='xz')
                all_dataframes.append(df)

    merged_dataframe = pd.concat(all_dataframes, ignore_index=True)

    # Sort dataframe by date
    df_sorted = merged_dataframe.sort_values(by='post_date')

    # Remove the 'Unnamed: 0' column
    df_sorted = df_sorted.drop(columns=['Unnamed: 0'])
    
    # Drop 'year' columns that was used previously to split dataframes and save them as smaller csv files 
    df_sorted = df_sorted.drop(columns=['year'])


    # Reset the index of the dataframe and drop the old one
    df_sorted = df_sorted.reset_index(drop=True)

    return df_sorted

    
base_url = "https://raw.githubusercontent.com/inga-maria01/master_thesis/main/data"
years = [2015, 2016, 2017, 2018, 2019]
companies = ['AAPL', 'AMZN', 'GOOGL', 'TSLA', 'GOOG', 'MSFT']
tweets_df = load_and_merge_csv_xz_from_github(years, companies, base_url)

# %%
tweets_df.dtypes
# Out:
# ticker_symbol    object
# company_name     object
# tweet_id          int64
# writer           object
# post_date        object
# body             object
# comment_num       int64
# retweet_num       int64
# like_num          int64
# dtype: object

# %%
tweets_df.head()
# Out:
#   ticker_symbol company_name            tweet_id           writer  \
# 0          AAPL        apple  550441509175443456  VisualStockRSRC
# 1          AAPL        apple  550441672312512512      KeralaGuy77
# 2          AMZN   Amazon.com  550441732014223360      DozenStocks
# 3          TSLA    Tesla Inc  550442977802207232     ShowDreamCar
# 4          TSLA    Tesla Inc  550443808606126081    aaplstocknews
#
#              post_date                                               body  \
# 0  2015-01-01 00:00:57  lx21 made $10,008  on $AAPL -Check it out! htt...
# 1  2015-01-01 00:01:36  Insanity of today weirdo massive selling. $aap...
# 2  2015-01-01 00:01:50  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...
# 3  2015-01-01 00:06:47  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...
# 4  2015-01-01 00:10:05  Swing Trading: Up To 8.91% Return In 14 Days h...
#
#    comment_num  retweet_num  like_num
# 0            0            0         1
# 1            0            0         0
# 2            0            0         0
# 3            0            0         1
# 4            0            0         1

# %%
# number of unique tweets
len(tweets_df['body'].unique())
# Out:
# 3326194

# %%
import pandas as pd
import re

def filter_tweets(df):
    df = df.copy()

    print("Initial dataset length:", len(df))

    # Normalize URLs in the tweet bodies - replace with "URL" or remove
    df['body'] = df['body'].apply(lambda text: re.sub(r'http\S+', 'URL', text))

    # Remove all duplicates based on 'tweet_id' and 'ticker_symbol' (possibly collection errors)
    df.drop_duplicates(subset=['tweet_id', 'ticker_symbol'], inplace=True, keep = 'first')
    print("After removing duplicate tweet_ids and ticker_symbols:", len(df))

    # Remove last duplicates based on 'tweet_id' and 'company_name'(will only apply to Google as they have different ticker_symbols)
    df.drop_duplicates(subset=['tweet_id', 'company_name'], inplace=True, keep = 'first')
    print("After removing duplicate tweet_ids and company_names (Google):", len(df))

    # Introduce new common ticker symbol for google
    df['ticker_symbol'] = df['ticker_symbol'].replace({'GOOG': 'GOOGLE', 'GOOGL': 'GOOGLE'})

    # Remove tweets with duplicate texts longer than 5 words considering the ticker symbol
    df['word_count'] = df['body'].apply(lambda text: len(text.split()))
    duplicates = df[(df['word_count'] > 5)].duplicated(subset=['body', 'ticker_symbol'], keep=False)
    df = df.loc[~df.index.isin(duplicates[duplicates].index)]
    print("After removing tweets duplicate texts longer than 5 words:", len(df))

    # Apply counting functions
    df['hashtag_count'] = df['body'].apply(lambda text: sum(1 for word in text.split() if word.startswith('#')))
    df['cashtag_count'] = df['body'].apply(lambda text: sum(1 for word in text.split() if word.startswith('$')))
    df['mention_count'] = df['body'].apply(lambda text: sum(1 for word in text.split() if word.startswith('@')))

    # Filter tweets based on hashtag and cashtag counts
    df = df[(df['cashtag_count'] < 5) & (df['hashtag_count'] < 8)]
    print("After filtering by cashtags and hashtags:", len(df))

    # Ratio filters (cashtags, hashtags, mentions to words)
    df['cashtag_ratio'] = df['cashtag_count'] / df['word_count'].replace(0, 1)
    df['hashtag_ratio'] = df['hashtag_count'] / df['word_count'].replace(0, 1)
    df['mention_ratio'] = df['mention_count'] / df['word_count'].replace(0, 1)
    df = df[(df['cashtag_ratio'] <= 0.5) & (df['hashtag_ratio'] <= 0.5) & (df['mention_ratio'] <= 0.5)]
    print("After filtering by ratios:", len(df))

    # Keyword filter (defined by Wilksch, Abramova (2023) PyFin-sentiment: Towards a machine-learning-based model for deriving sentiment from financial tweets)
    keywords = ['bitcoin', 'etherium', 'btc', 'eth', 'nft', 'token', 'wallet', 'web3',
                'airdrop', 'wagmi', 'solana', 'opensea', 'cryptopunks', 'uniswap', 
                'lunar', 'hodl', 'binance', 'coinbase', 'cryptocom', 'doge']
    df['keyword_count'] = df['body'].apply(lambda text: sum(text.lower().count(kw) for kw in keywords))
    df = df[df['keyword_count'] <= 2]
    print("After filtering by keyword count:", len(df))

    df = df.reset_index(drop=True)

    return df

# %%
filtered_df = filter_tweets(tweets_df)
# Out:
# Initial dataset length: 4336445
# After removing duplicate tweet_ids and ticker_symbols: 4336445
# After removing duplicate tweet_ids and company_names (Google): 4288706
# After removing tweets duplicate texts longer than 5 words: 3192655
# After filtering by cashtags and hashtags: 2761216
# After filtering by ratios: 2728425
# After filtering by keyword count: 2727245

# %%
# old method (stronger filtering)
filtered_df = filter_tweets(tweets_df)
# Out:
# Initial dataset length: 4336445
# After removing duplicate tweet_ids and ticker_symbols: 4336445
# After removing duplicate tweet_ids and company_names (Google): 4288706
# After removing tweets duplicate texts longer than 5 words: 3192655
# After filtering by cashtags and hashtags: 2526934
# After filtering by ratios: 2506779
# After filtering by keyword count: 2506058

# %%
# number of unique tweets
len(filtered_df['body'].unique())
# Out:
# 2380386

# %%
import pandas as pd

def check_empty_bodies(df):
    # Check for empty or NaN entries in the 'body' column
    empty_bodies = df['body'].isna() | (df['body'] == '')
    
    # Count the number of empty or NaN entries
    empty_count = empty_bodies.sum()
    
    # Print the results
    if empty_count > 0:
        print(f"There are {empty_count} empty 'body' cells in the DataFrame.")
    else:
        print("There are no empty 'body' cells in the DataFrame.")

    # Optionally, you might want to return a DataFrame with the empty entries for review
    empty_entries = df[empty_bodies]
    return empty_entries

# %%
# Check processed data frame for missing text values
empty_entries = check_empty_bodies(filtered_df)
if not empty_entries.empty:
    print("Empty entries found:", empty_entries)
# Out:
# There are no empty 'body' cells in the DataFrame.

# %%
import datetime
import pytz

# convert post_date back to int64

# convert from object to datetime
filtered_df['post_date'] = pd.to_datetime(filtered_df['post_date'])

# convert to int64
filtered_df['date_int'] = filtered_df['post_date'].apply(lambda x: int(x.timestamp()))

def convert_utc_to_ny(timestamp):
    # Define the UTC timezone
    utc_timezone = pytz.timezone('UTC')
    
    # Define the New York timezone
    ny_timezone = pytz.timezone('America/New_York')
    
    # Create a timezone-aware datetime object in UTC directly from the Unix timestamp
    utc_aware_datetime = datetime.datetime.fromtimestamp(timestamp, utc_timezone)
    
    # Convert the datetime object from UTC to New York Time
    ny_datetime = utc_aware_datetime.astimezone(ny_timezone)

    # # Format New York datetime to a string without timezone information
    # formatted_new_york_datetime = new_york_datetime.strftime('%Y-%m-%d %H:%M:%S')
    
    # return formatted_new_york_datetime
    
    return ny_datetime

# Example usage
# timestamp = 1420070457
# print(convert_utc_to_ny(timestamp))

# The example usage is commented out to adhere to instructions of not executing the code here.

# %%
filtered_df['date_new_york'] = filtered_df['date_int'].apply(convert_utc_to_ny)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame and it contains a 'date_new_york' column

# Extracting the hour from 'date_new_york' and creating a new column 'hour'
filtered_df['hour'] = filtered_df['date_new_york'].dt.hour

# Group by the new 'hour' column and calculate the mean number of tweets per hour
# average_tweets_per_hour = filtered_df.groupby('hour').count().mean()

filtered_df.groupby('hour').size().plot(kind='bar')
# Out:
# <Axes: xlabel='hour'>

# %%
filtered_df = filtered_df.rename(columns={'post_date': 'date_utc'}).drop(columns=['date_int'])

# %%
filtered_df.describe()
# Out:
#            tweet_id                       date_utc   comment_num  \
# count  2.727245e+06                        2727245  2.727245e+06
# mean   8.928803e+17  2017-08-02 22:50:27.532667648  3.964950e-01
# min    5.504417e+17            2015-01-01 00:01:36  0.000000e+00
# 25%    7.156841e+17            2016-03-31 23:36:05  0.000000e+00
# 50%    9.036395e+17            2017-09-01 15:23:35  0.000000e+00
# 75%    1.067094e+18            2018-11-26 16:33:35  0.000000e+00
# max    1.212160e+18            2019-12-31 23:55:53  5.630000e+02
# std    1.969770e+17                            NaN  1.989257e+00
#
#         retweet_num      like_num    word_count  hashtag_count  cashtag_count  \
# count  2.727245e+06  2.727245e+06  2.727245e+06   2.727245e+06   2.727245e+06
# mean   6.649465e-01  2.703388e+00  1.762487e+01   5.771627e-01   1.909034e+00
# min    0.000000e+00  0.000000e+00  1.000000e+00   0.000000e+00   0.000000e+00
# 25%    0.000000e+00  0.000000e+00  1.100000e+01   0.000000e+00   1.000000e+00
# 50%    0.000000e+00  0.000000e+00  1.500000e+01   0.000000e+00   1.000000e+00
# 75%    0.000000e+00  1.000000e+00  2.100000e+01   1.000000e+00   3.000000e+00
# max    9.990000e+02  9.990000e+02  6.800000e+01   1.000000e+01   6.000000e+00
# std    6.409917e+00  1.527421e+01  9.965350e+00   1.202745e+00   1.380986e+00
#
#        mention_count  cashtag_ratio  hashtag_ratio  mention_ratio  \
# count   2.727245e+06   2.727245e+06   2.727245e+06   2.727245e+06
# mean    2.066195e-01   1.334143e-01   3.802120e-02   1.222092e-02
# min     0.000000e+00   0.000000e+00   0.000000e+00   0.000000e+00
# 25%     0.000000e+00   6.060606e-02   0.000000e+00   0.000000e+00
# 50%     0.000000e+00   1.000000e-01   0.000000e+00   0.000000e+00
# 75%     0.000000e+00   1.851852e-01   5.263158e-02   0.000000e+00
# max     1.600000e+01   5.000000e-01   5.000000e-01   5.000000e-01
# std     6.219076e-01   1.015484e-01   7.855419e-02   3.781486e-02
#
#        keyword_count          hour
# count   2.727245e+06  2.727245e+06
# mean    1.900893e-02  1.247416e+01
# min     0.000000e+00  0.000000e+00
# 25%     0.000000e+00  9.000000e+00
# 50%     0.000000e+00  1.200000e+01
# 75%     0.000000e+00  1.600000e+01
# max     2.000000e+00  2.300000e+01
# std     1.454573e-01  5.103923e+00

# %% [markdown]
# ## only keep tweets from 9 to 16h (9:00 - 16:59) to have a more representative sentiment score

# %%
# Define the list of desired hours
desired_hours = [9, 10, 11, 12, 13, 14, 15, 16]

# Filter the DataFrame
filtered_hours_df = filtered_df[filtered_df['hour'].isin(desired_hours)]

# %%
filtered_hours_df['hour'].unique()
# Out:
# array([ 9, 10, 11, 12, 13, 14, 15, 16], dtype=int32)

# %%
print(len(filtered_hours_df))
# Out:
# 1625815

# %%
# check if data set contains emojis

# pip install emoji
import emoji

def contains_emoji(text):
    return emoji.emoji_count(text) > 0


filtered_hours_df['has_emoji'] = filtered_hours_df['body'].apply(contains_emoji)

any_emojis = filtered_hours_df['has_emoji'].any()
print("Is there at least one emoji in the text body column?", any_emojis)
# Out:
# Is there at least one emoji in the text body column? True
# /var/folders/np/4cg_s0x15fx5mmp3__772_lc0000gn/T/ipykernel_2458/396429563.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_hours_df['has_emoji'] = filtered_hours_df['body'].apply(contains_emoji)

# %%
import re
import emoji

def preprocess_text_column(df):
    df = df.copy()  # Create a copy to avoid modifying the original DataFrame

    # Escape regex special characters and join them to form a regex pattern
    punctuation_marks = [',', '.', '?', '!', '*', ':', ';', '”', 
                         '“', '"', "’", "’", "%", "&", "'", "(",
                         ")", "-", '``', "''"]
    escaped_punctuation = [re.escape(char) for char in punctuation_marks]
    punctuation_pattern = f"[{''.join(escaped_punctuation)}]"

    def transform_text(text):
        # Replace emojis with a space
        text = emoji.replace_emoji(text, replace=' ')
        
        # Convert to lowercase
        text = text.lower()

        # Replace newlines with spaces
        text = text.replace('\n', ' ')

        # Remove repeated characters more than twice
        text = re.sub(r'(.)\1{2,}', r'\1', text)
        
        # Remove specific punctuation
        text = re.sub(punctuation_pattern, '', text)

        # Strip and replace multiple spaces with a single space
        text = re.sub(r'\s+', ' ', text).strip()
        
        return text

    # Apply the transformation to the 'body' column
    df['body'] = df['body'].apply(transform_text)
    
    return df

# Example usage:
# import pandas as pd
# df = pd.DataFrame({'body': ['Long money game. ♟                            We hope Jackboys has some Tesla stocks since their adding hype to $TSLA brand.']})
# print(preprocess_text_column(df))

# %%
# Preprocess text column
preprocessed_df = preprocess_text_column(filtered_hours_df)

# %%
preprocessed_df['has_emoji_pp'] = preprocessed_df['body'].apply(contains_emoji)

any_emojis_pp = preprocessed_df['has_emoji_pp'].any()
print("Is there at least one emoji in the text body column?", any_emojis_pp)
# Out:
# Is there at least one emoji in the text body column? False

# %%
preprocessed_df = preprocessed_df.drop(columns=['has_emoji', 'has_emoji_pp'])

# %%
preprocessed_df.head()
# Out:
#     ticker_symbol company_name            tweet_id           writer  \
# 144          AAPL        apple  550653576716890113  LloydCreekStock
# 145          AAPL        apple  550654457420066818      MacHashNews
# 146          AAPL        apple  550658389122895873         ybfmiami
# 147          TSLA    Tesla Inc  550658779117666304       kirillklip
# 148          TSLA    Tesla Inc  550661171309600768       kirillklip
#
#                date_utc                                               body  \
# 144 2015-01-01 14:03:37  2015 will be apples year raising price target ...
# 145 2015-01-01 14:07:07  apple pushes ‘start something new webpage worl...
# 146 2015-01-01 14:22:45  commented on stocktwits he knows that $aapl ha...
# 147 2015-01-01 14:24:18  almost 100 electric cars were sold in china in...
# 148 2015-01-01 14:33:48  how its made dream cars tesla model s url $tsl...
#
#      comment_num  retweet_num  like_num  word_count  hashtag_count  \
# 144            0            0         1          18              0
# 145            0            0         1          13              1
# 146            0            0         1          20              0
# 147            0            1         1          14              0
# 148            0            0         0          13              0
#
#      cashtag_count  mention_count  cashtag_ratio  hashtag_ratio  \
# 144              2              0       0.111111       0.000000
# 145              1              0       0.076923       0.076923
# 146              1              0       0.050000       0.000000
# 147              3              0       0.214286       0.000000
# 148              3              0       0.230769       0.000000
#
#      mention_ratio  keyword_count             date_new_york  hour
# 144            0.0              0 2015-01-01 09:03:37-05:00     9
# 145            0.0              1 2015-01-01 09:07:07-05:00     9
# 146            0.0              0 2015-01-01 09:22:45-05:00     9
# 147            0.0              0 2015-01-01 09:24:18-05:00     9
# 148            0.0              0 2015-01-01 09:33:48-05:00     9

# %%
from pyfin_sentiment.model import SentimentModel
import numpy as np
import pandas as pd  # Ensure pandas is imported if not already

# Initialize the sentiment model
model = SentimentModel("small")

def apply_batch_sentiment(texts, batch_size=1000):
    # Initialize lists to store sentiment results and probabilities
    sentiments = []
    probabilities = []
    
    # Process texts in batches
    total_texts = len(texts)
    for i in range(0, total_texts, batch_size):
        batch_texts = texts[i:i + batch_size]
        
        # Get predictions and probabilities
        batch_predictions = model.predict(batch_texts)
        batch_probabilities = model.predict_proba(batch_texts)
        
        sentiments.extend(batch_predictions)
        probabilities.extend(batch_probabilities)
        
        # Print progress
        processed = min(i + batch_size, total_texts)
        print(f"Processed {processed}/{total_texts} texts")
    
    return sentiments, probabilities
# Out:
# /Users/friederikeeichholz/anaconda3/lib/python3.11/site-packages/sklearn/base.py:347: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.1.1 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/friederikeeichholz/anaconda3/lib/python3.11/site-packages/sklearn/base.py:347: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.1.1 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/friederikeeichholz/anaconda3/lib/python3.11/site-packages/sklearn/base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.1.1 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/friederikeeichholz/anaconda3/lib/python3.11/site-packages/sklearn/base.py:347: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.1.1 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# Apply sentiment analysis in batches to the 'body' column
sentiment_df = preprocessed_df.copy()

results = apply_batch_sentiment(sentiment_df['body'].tolist(), batch_size=1000)
sentiment_df['sentiment'] = results[0]
sentiment_df['sentiment_probability'] = results[1]
# Out:
# Processed 1000/1625815 texts
# Processed 2000/1625815 texts
# Processed 3000/1625815 texts
# Processed 4000/1625815 texts
# Processed 5000/1625815 texts
# Processed 6000/1625815 texts
# Processed 7000/1625815 texts
# Processed 8000/1625815 texts
# Processed 9000/1625815 texts
# Processed 10000/1625815 texts
# Processed 11000/1625815 texts
# Processed 12000/1625815 texts
# Processed 13000/1625815 texts
# Processed 14000/1625815 texts
# Processed 15000/1625815 texts
# Processed 16000/1625815 texts
# Processed 17000/1625815 texts
# Processed 18000/1625815 texts
# Processed 19000/1625815 texts
# Processed 20000/1625815 texts
# Processed 21000/1625815 texts
# Processed 22000/1625815 texts
# Processed 23000/1625815 texts
# Processed 24000/1625815 texts
# Processed 25000/1625815 texts
# Processed 26000/1625815 texts
# Processed 27000/1625815 texts
# Processed 28000/1625815 texts
# Processed 29000/1625815 texts
# Processed 30000/1625815 texts
# Processed 31000/1625815 texts
# Processed 32000/1625815 texts
# Processed 33000/1625815 texts
# Processed 34000/1625815 texts
# Processed 35000/1625815 texts
# Processed 36000/1625815 texts
# Processed 37000/1625815 texts
# Processed 38000/1625815 texts
# Processed 39000/1625815 texts
# Processed 40000/1625815 texts
# Processed 41000/1625815 texts
# Processed 42000/1625815 texts
# Processed 43000/1625815 texts
# Processed 44000/1625815 texts
# Processed 45000/1625815 texts
# Processed 46000/1625815 texts
# Processed 47000/1625815 texts
# Processed 48000/1625815 texts
# Processed 49000/1625815 texts
# Processed 50000/1625815 texts
# Processed 51000/1625815 texts
# Processed 52000/1625815 texts
# Processed 53000/1625815 texts
# Processed 54000/1625815 texts
# Processed 55000/1625815 texts
# Processed 56000/1625815 texts
# Processed 57000/1625815 texts
# Processed 58000/1625815 texts
# Processed 59000/1625815 texts
# Processed 60000/1625815 texts
# Processed 61000/1625815 texts
# Processed 62000/1625815 texts
# Processed 63000/1625815 texts
# Processed 64000/1625815 texts
# Processed 65000/1625815 texts
# Processed 66000/1625815 texts
# Processed 67000/1625815 texts
# Processed 68000/1625815 texts
# Processed 69000/1625815 texts
# Processed 70000/1625815 texts
# Processed 71000/1625815 texts
# Processed 72000/1625815 texts
# Processed 73000/1625815 texts
# Processed 74000/1625815 texts
# Processed 75000/1625815 texts
# Processed 76000/1625815 texts
# Processed 77000/1625815 texts
# Processed 78000/1625815 texts
# Processed 79000/1625815 texts
# Processed 80000/1625815 texts
# Processed 81000/1625815 texts
# Processed 82000/1625815 texts
# Processed 83000/1625815 texts
# Processed 84000/1625815 texts
# Processed 85000/1625815 texts
# Processed 86000/1625815 texts
# Processed 87000/1625815 texts
# Processed 88000/1625815 texts
# Processed 89000/1625815 texts
# Processed 90000/1625815 texts
# Processed 91000/1625815 texts
# Processed 92000/1625815 texts
# Processed 93000/1625815 texts
# Processed 94000/1625815 texts
# Processed 95000/1625815 texts
# Processed 96000/1625815 texts
# Processed 97000/1625815 texts
# Processed 98000/1625815 texts
# Processed 99000/1625815 texts
# Processed 100000/1625815 texts
# Processed 101000/1625815 texts
# Processed 102000/1625815 texts
# Processed 103000/1625815 texts
# Processed 104000/1625815 texts
# Processed 105000/1625815 texts
# Processed 106000/1625815 texts
# Processed 107000/1625815 texts
# Processed 108000/1625815 texts
# Processed 109000/1625815 texts
# Processed 110000/1625815 texts
# Processed 111000/1625815 texts
# Processed 112000/1625815 texts
# Processed 113000/1625815 texts
# Processed 114000/1625815 texts
# Processed 115000/1625815 texts
# Processed 116000/1625815 texts
# Processed 117000/1625815 texts
# Processed 118000/1625815 texts
# Processed 119000/1625815 texts
# Processed 120000/1625815 texts
# Processed 121000/1625815 texts
# Processed 122000/1625815 texts
# Processed 123000/1625815 texts
# Processed 124000/1625815 texts
# Processed 125000/1625815 texts
# Processed 126000/1625815 texts
# Processed 127000/1625815 texts
# Processed 128000/1625815 texts
# Processed 129000/1625815 texts
# Processed 130000/1625815 texts
# Processed 131000/1625815 texts
# Processed 132000/1625815 texts
# Processed 133000/1625815 texts
# Processed 134000/1625815 texts
# Processed 135000/1625815 texts
# Processed 136000/1625815 texts
# Processed 137000/1625815 texts
# Processed 138000/1625815 texts
# Processed 139000/1625815 texts
# Processed 140000/1625815 texts
# Processed 141000/1625815 texts
# Processed 142000/1625815 texts
# Processed 143000/1625815 texts
# Processed 144000/1625815 texts
# Processed 145000/1625815 texts
# Processed 146000/1625815 texts
# Processed 147000/1625815 texts
# Processed 148000/1625815 texts
# Processed 149000/1625815 texts
# Processed 150000/1625815 texts
# Processed 151000/1625815 texts
# Processed 152000/1625815 texts
# Processed 153000/1625815 texts
# Processed 154000/1625815 texts
# Processed 155000/1625815 texts
# Processed 156000/1625815 texts
# Processed 157000/1625815 texts
# Processed 158000/1625815 texts
# Processed 159000/1625815 texts
# Processed 160000/1625815 texts
# Processed 161000/1625815 texts
# Processed 162000/1625815 texts
# Processed 163000/1625815 texts
# Processed 164000/1625815 texts
# Processed 165000/1625815 texts
# Processed 166000/1625815 texts
# Processed 167000/1625815 texts
# Processed 168000/1625815 texts
# Processed 169000/1625815 texts
# Processed 170000/1625815 texts
# Processed 171000/1625815 texts
# Processed 172000/1625815 texts
# Processed 173000/1625815 texts
# Processed 174000/1625815 texts
# Processed 175000/1625815 texts
# Processed 176000/1625815 texts
# Processed 177000/1625815 texts
# Processed 178000/1625815 texts
# Processed 179000/1625815 texts
# Processed 180000/1625815 texts
# Processed 181000/1625815 texts
# Processed 182000/1625815 texts
# Processed 183000/1625815 texts
# Processed 184000/1625815 texts
# Processed 185000/1625815 texts
# Processed 186000/1625815 texts
# Processed 187000/1625815 texts
# Processed 188000/1625815 texts
# Processed 189000/1625815 texts
# Processed 190000/1625815 texts
# Processed 191000/1625815 texts
# Processed 192000/1625815 texts
# Processed 193000/1625815 texts
# Processed 194000/1625815 texts
# Processed 195000/1625815 texts
# Processed 196000/1625815 texts
# Processed 197000/1625815 texts
# Processed 198000/1625815 texts
# Processed 199000/1625815 texts
# Processed 200000/1625815 texts
# Processed 201000/1625815 texts
# Processed 202000/1625815 texts
# Processed 203000/1625815 texts
# Processed 204000/1625815 texts
# Processed 205000/1625815 texts
# Processed 206000/1625815 texts
# Processed 207000/1625815 texts
# Processed 208000/1625815 texts
# Processed 209000/1625815 texts
# Processed 210000/1625815 texts
# Processed 211000/1625815 texts
# Processed 212000/1625815 texts
# Processed 213000/1625815 texts
# Processed 214000/1625815 texts
# Processed 215000/1625815 texts
# Processed 216000/1625815 texts
# Processed 217000/1625815 texts
# Processed 218000/1625815 texts
# Processed 219000/1625815 texts
# Processed 220000/1625815 texts
# Processed 221000/1625815 texts
# Processed 222000/1625815 texts
# Processed 223000/1625815 texts
# Processed 224000/1625815 texts
# Processed 225000/1625815 texts
# Processed 226000/1625815 texts
# Processed 227000/1625815 texts
# Processed 228000/1625815 texts
# Processed 229000/1625815 texts
# Processed 230000/1625815 texts
# Processed 231000/1625815 texts
# Processed 232000/1625815 texts
# Processed 233000/1625815 texts
# Processed 234000/1625815 texts
# Processed 235000/1625815 texts
# Processed 236000/1625815 texts
# Processed 237000/1625815 texts
# Processed 238000/1625815 texts
# Processed 239000/1625815 texts
# Processed 240000/1625815 texts
# Processed 241000/1625815 texts
# Processed 242000/1625815 texts
# Processed 243000/1625815 texts
# Processed 244000/1625815 texts
# Processed 245000/1625815 texts
# Processed 246000/1625815 texts
# Processed 247000/1625815 texts
# Processed 248000/1625815 texts
# Processed 249000/1625815 texts
# Processed 250000/1625815 texts
# Processed 251000/1625815 texts
# Processed 252000/1625815 texts
# Processed 253000/1625815 texts
# Processed 254000/1625815 texts
# Processed 255000/1625815 texts
# Processed 256000/1625815 texts
# Processed 257000/1625815 texts
# Processed 258000/1625815 texts
# Processed 259000/1625815 texts
# Processed 260000/1625815 texts
# Processed 261000/1625815 texts
# Processed 262000/1625815 texts
# Processed 263000/1625815 texts
# Processed 264000/1625815 texts
# Processed 265000/1625815 texts
# Processed 266000/1625815 texts
# Processed 267000/1625815 texts
# Processed 268000/1625815 texts
# Processed 269000/1625815 texts
# Processed 270000/1625815 texts
# Processed 271000/1625815 texts
# Processed 272000/1625815 texts
# Processed 273000/1625815 texts
# Processed 274000/1625815 texts
# Processed 275000/1625815 texts
# Processed 276000/1625815 texts
# Processed 277000/1625815 texts
# Processed 278000/1625815 texts
# Processed 279000/1625815 texts
# Processed 280000/1625815 texts
# Processed 281000/1625815 texts
# Processed 282000/1625815 texts
# Processed 283000/1625815 texts
# Processed 284000/1625815 texts
# Processed 285000/1625815 texts
# Processed 286000/1625815 texts
# Processed 287000/1625815 texts
# Processed 288000/1625815 texts
# Processed 289000/1625815 texts
# Processed 290000/1625815 texts
# Processed 291000/1625815 texts
# Processed 292000/1625815 texts
# Processed 293000/1625815 texts
# Processed 294000/1625815 texts
# Processed 295000/1625815 texts
# Processed 296000/1625815 texts
# Processed 297000/1625815 texts
# Processed 298000/1625815 texts
# Processed 299000/1625815 texts
# Processed 300000/1625815 texts
# Processed 301000/1625815 texts
# Processed 302000/1625815 texts
# Processed 303000/1625815 texts
# Processed 304000/1625815 texts
# Processed 305000/1625815 texts
# Processed 306000/1625815 texts
# Processed 307000/1625815 texts
# Processed 308000/1625815 texts
# Processed 309000/1625815 texts
# Processed 310000/1625815 texts
# Processed 311000/1625815 texts
# Processed 312000/1625815 texts
# Processed 313000/1625815 texts
# Processed 314000/1625815 texts
# Processed 315000/1625815 texts
# Processed 316000/1625815 texts
# Processed 317000/1625815 texts
# Processed 318000/1625815 texts
# Processed 319000/1625815 texts
# Processed 320000/1625815 texts
# Processed 321000/1625815 texts
# Processed 322000/1625815 texts
# Processed 323000/1625815 texts
# Processed 324000/1625815 texts
# Processed 325000/1625815 texts
# Processed 326000/1625815 texts
# Processed 327000/1625815 texts
# Processed 328000/1625815 texts
# Processed 329000/1625815 texts
# Processed 330000/1625815 texts
# Processed 331000/1625815 texts
# Processed 332000/1625815 texts
# Processed 333000/1625815 texts
# Processed 334000/1625815 texts
# Processed 335000/1625815 texts
# Processed 336000/1625815 texts
# Processed 337000/1625815 texts
# Processed 338000/1625815 texts
# Processed 339000/1625815 texts
# Processed 340000/1625815 texts
# Processed 341000/1625815 texts
# Processed 342000/1625815 texts
# Processed 343000/1625815 texts
# Processed 344000/1625815 texts
# Processed 345000/1625815 texts
# Processed 346000/1625815 texts
# Processed 347000/1625815 texts
# Processed 348000/1625815 texts
# Processed 349000/1625815 texts
# Processed 350000/1625815 texts
# Processed 351000/1625815 texts
# Processed 352000/1625815 texts
# Processed 353000/1625815 texts
# Processed 354000/1625815 texts
# Processed 355000/1625815 texts
# Processed 356000/1625815 texts
# Processed 357000/1625815 texts
# Processed 358000/1625815 texts
# Processed 359000/1625815 texts
# Processed 360000/1625815 texts
# Processed 361000/1625815 texts
# Processed 362000/1625815 texts
# Processed 363000/1625815 texts
# Processed 364000/1625815 texts
# Processed 365000/1625815 texts
# Processed 366000/1625815 texts
# Processed 367000/1625815 texts
# Processed 368000/1625815 texts
# Processed 369000/1625815 texts
# Processed 370000/1625815 texts
# Processed 371000/1625815 texts
# Processed 372000/1625815 texts
# Processed 373000/1625815 texts
# Processed 374000/1625815 texts
# Processed 375000/1625815 texts
# Processed 376000/1625815 texts
# Processed 377000/1625815 texts
# Processed 378000/1625815 texts
# Processed 379000/1625815 texts
# Processed 380000/1625815 texts
# Processed 381000/1625815 texts
# Processed 382000/1625815 texts
# Processed 383000/1625815 texts
# Processed 384000/1625815 texts
# Processed 385000/1625815 texts
# Processed 386000/1625815 texts
# Processed 387000/1625815 texts
# Processed 388000/1625815 texts
# Processed 389000/1625815 texts
# Processed 390000/1625815 texts
# Processed 391000/1625815 texts
# Processed 392000/1625815 texts
# Processed 393000/1625815 texts
# Processed 394000/1625815 texts
# Processed 395000/1625815 texts
# Processed 396000/1625815 texts
# Processed 397000/1625815 texts
# Processed 398000/1625815 texts
# Processed 399000/1625815 texts
# Processed 400000/1625815 texts
# Processed 401000/1625815 texts
# Processed 402000/1625815 texts
# Processed 403000/1625815 texts
# Processed 404000/1625815 texts
# Processed 405000/1625815 texts
# Processed 406000/1625815 texts
# Processed 407000/1625815 texts
# Processed 408000/1625815 texts
# Processed 409000/1625815 texts
# Processed 410000/1625815 texts
# Processed 411000/1625815 texts
# Processed 412000/1625815 texts
# Processed 413000/1625815 texts
# Processed 414000/1625815 texts
# Processed 415000/1625815 texts
# Processed 416000/1625815 texts
# Processed 417000/1625815 texts
# Processed 418000/1625815 texts
# Processed 419000/1625815 texts
# Processed 420000/1625815 texts
# Processed 421000/1625815 texts
# Processed 422000/1625815 texts
# Processed 423000/1625815 texts
# Processed 424000/1625815 texts
# Processed 425000/1625815 texts
# Processed 426000/1625815 texts
# Processed 427000/1625815 texts
# Processed 428000/1625815 texts
# Processed 429000/1625815 texts
# Processed 430000/1625815 texts
# Processed 431000/1625815 texts
# Processed 432000/1625815 texts
# Processed 433000/1625815 texts
# Processed 434000/1625815 texts
# Processed 435000/1625815 texts
# Processed 436000/1625815 texts
# Processed 437000/1625815 texts
# Processed 438000/1625815 texts
# Processed 439000/1625815 texts
# Processed 440000/1625815 texts
# Processed 441000/1625815 texts
# Processed 442000/1625815 texts
# Processed 443000/1625815 texts
# Processed 444000/1625815 texts
# Processed 445000/1625815 texts
# Processed 446000/1625815 texts
# Processed 447000/1625815 texts
# Processed 448000/1625815 texts
# Processed 449000/1625815 texts
# Processed 450000/1625815 texts
# Processed 451000/1625815 texts
# Processed 452000/1625815 texts
# Processed 453000/1625815 texts
# Processed 454000/1625815 texts
# Processed 455000/1625815 texts
# Processed 456000/1625815 texts
# Processed 457000/1625815 texts
# Processed 458000/1625815 texts
# Processed 459000/1625815 texts
# Processed 460000/1625815 texts
# Processed 461000/1625815 texts
# Processed 462000/1625815 texts
# Processed 463000/1625815 texts
# Processed 464000/1625815 texts
# Processed 465000/1625815 texts
# Processed 466000/1625815 texts
# Processed 467000/1625815 texts
# Processed 468000/1625815 texts
# Processed 469000/1625815 texts
# Processed 470000/1625815 texts
# Processed 471000/1625815 texts
# Processed 472000/1625815 texts
# Processed 473000/1625815 texts
# Processed 474000/1625815 texts
# Processed 475000/1625815 texts
# Processed 476000/1625815 texts
# Processed 477000/1625815 texts
# Processed 478000/1625815 texts
# Processed 479000/1625815 texts
# Processed 480000/1625815 texts
# Processed 481000/1625815 texts
# Processed 482000/1625815 texts
# Processed 483000/1625815 texts
# Processed 484000/1625815 texts
# Processed 485000/1625815 texts
# Processed 486000/1625815 texts
# Processed 487000/1625815 texts
# Processed 488000/1625815 texts
# Processed 489000/1625815 texts
# Processed 490000/1625815 texts
# Processed 491000/1625815 texts
# Processed 492000/1625815 texts
# Processed 493000/1625815 texts
# Processed 494000/1625815 texts
# Processed 495000/1625815 texts
# Processed 496000/1625815 texts
# Processed 497000/1625815 texts
# Processed 498000/1625815 texts
# Processed 499000/1625815 texts
# Processed 500000/1625815 texts
# Processed 501000/1625815 texts
# Processed 502000/1625815 texts
# Processed 503000/1625815 texts
# Processed 504000/1625815 texts
# Processed 505000/1625815 texts
# Processed 506000/1625815 texts
# Processed 507000/1625815 texts
# Processed 508000/1625815 texts
# Processed 509000/1625815 texts
# Processed 510000/1625815 texts
# Processed 511000/1625815 texts
# Processed 512000/1625815 texts
# Processed 513000/1625815 texts
# Processed 514000/1625815 texts
# Processed 515000/1625815 texts
# Processed 516000/1625815 texts
# Processed 517000/1625815 texts
# Processed 518000/1625815 texts
# Processed 519000/1625815 texts
# Processed 520000/1625815 texts
# Processed 521000/1625815 texts
# Processed 522000/1625815 texts
# Processed 523000/1625815 texts
# Processed 524000/1625815 texts
# Processed 525000/1625815 texts
# Processed 526000/1625815 texts
# Processed 527000/1625815 texts
# Processed 528000/1625815 texts
# Processed 529000/1625815 texts
# Processed 530000/1625815 texts
# Processed 531000/1625815 texts
# Processed 532000/1625815 texts
# Processed 533000/1625815 texts
# Processed 534000/1625815 texts
# Processed 535000/1625815 texts
# Processed 536000/1625815 texts
# Processed 537000/1625815 texts
# Processed 538000/1625815 texts
# Processed 539000/1625815 texts
# Processed 540000/1625815 texts
# Processed 541000/1625815 texts
# Processed 542000/1625815 texts
# Processed 543000/1625815 texts
# Processed 544000/1625815 texts
# Processed 545000/1625815 texts
# Processed 546000/1625815 texts
# Processed 547000/1625815 texts
# Processed 548000/1625815 texts
# Processed 549000/1625815 texts
# Processed 550000/1625815 texts
# Processed 551000/1625815 texts
# Processed 552000/1625815 texts
# Processed 553000/1625815 texts
# Processed 554000/1625815 texts
# Processed 555000/1625815 texts
# Processed 556000/1625815 texts
# Processed 557000/1625815 texts
# Processed 558000/1625815 texts
# Processed 559000/1625815 texts
# Processed 560000/1625815 texts
# Processed 561000/1625815 texts
# Processed 562000/1625815 texts
# Processed 563000/1625815 texts
# Processed 564000/1625815 texts
# Processed 565000/1625815 texts
# Processed 566000/1625815 texts
# Processed 567000/1625815 texts
# Processed 568000/1625815 texts
# Processed 569000/1625815 texts
# Processed 570000/1625815 texts
# Processed 571000/1625815 texts
# Processed 572000/1625815 texts
# Processed 573000/1625815 texts
# Processed 574000/1625815 texts
# Processed 575000/1625815 texts
# Processed 576000/1625815 texts
# Processed 577000/1625815 texts
# Processed 578000/1625815 texts
# Processed 579000/1625815 texts
# Processed 580000/1625815 texts
# Processed 581000/1625815 texts
# Processed 582000/1625815 texts
# Processed 583000/1625815 texts
# Processed 584000/1625815 texts
# Processed 585000/1625815 texts
# Processed 586000/1625815 texts
# Processed 587000/1625815 texts
# Processed 588000/1625815 texts
# Processed 589000/1625815 texts
# Processed 590000/1625815 texts
# Processed 591000/1625815 texts
# Processed 592000/1625815 texts
# Processed 593000/1625815 texts
# Processed 594000/1625815 texts
# Processed 595000/1625815 texts
# Processed 596000/1625815 texts
# Processed 597000/1625815 texts
# Processed 598000/1625815 texts
# Processed 599000/1625815 texts
# Processed 600000/1625815 texts
# Processed 601000/1625815 texts
# Processed 602000/1625815 texts
# Processed 603000/1625815 texts
# Processed 604000/1625815 texts
# Processed 605000/1625815 texts
# Processed 606000/1625815 texts
# Processed 607000/1625815 texts
# Processed 608000/1625815 texts
# Processed 609000/1625815 texts
# Processed 610000/1625815 texts
# Processed 611000/1625815 texts
# Processed 612000/1625815 texts
# Processed 613000/1625815 texts
# Processed 614000/1625815 texts
# Processed 615000/1625815 texts
# Processed 616000/1625815 texts
# Processed 617000/1625815 texts
# Processed 618000/1625815 texts
# Processed 619000/1625815 texts
# Processed 620000/1625815 texts
# Processed 621000/1625815 texts
# Processed 622000/1625815 texts
# Processed 623000/1625815 texts
# Processed 624000/1625815 texts
# Processed 625000/1625815 texts
# Processed 626000/1625815 texts
# Processed 627000/1625815 texts
# Processed 628000/1625815 texts
# Processed 629000/1625815 texts
# Processed 630000/1625815 texts
# Processed 631000/1625815 texts
# Processed 632000/1625815 texts
# Processed 633000/1625815 texts
# Processed 634000/1625815 texts
# Processed 635000/1625815 texts
# Processed 636000/1625815 texts
# Processed 637000/1625815 texts
# Processed 638000/1625815 texts
# Processed 639000/1625815 texts
# Processed 640000/1625815 texts
# Processed 641000/1625815 texts
# Processed 642000/1625815 texts
# Processed 643000/1625815 texts
# Processed 644000/1625815 texts
# Processed 645000/1625815 texts
# Processed 646000/1625815 texts
# Processed 647000/1625815 texts
# Processed 648000/1625815 texts
# Processed 649000/1625815 texts
# Processed 650000/1625815 texts
# Processed 651000/1625815 texts
# Processed 652000/1625815 texts
# Processed 653000/1625815 texts
# Processed 654000/1625815 texts
# Processed 655000/1625815 texts
# Processed 656000/1625815 texts
# Processed 657000/1625815 texts
# Processed 658000/1625815 texts
# Processed 659000/1625815 texts
# Processed 660000/1625815 texts
# Processed 661000/1625815 texts
# Processed 662000/1625815 texts
# Processed 663000/1625815 texts
# Processed 664000/1625815 texts
# Processed 665000/1625815 texts
# Processed 666000/1625815 texts
# Processed 667000/1625815 texts
# Processed 668000/1625815 texts
# Processed 669000/1625815 texts
# Processed 670000/1625815 texts
# Processed 671000/1625815 texts
# Processed 672000/1625815 texts
# Processed 673000/1625815 texts
# Processed 674000/1625815 texts
# Processed 675000/1625815 texts
# Processed 676000/1625815 texts
# Processed 677000/1625815 texts
# Processed 678000/1625815 texts
# Processed 679000/1625815 texts
# Processed 680000/1625815 texts
# Processed 681000/1625815 texts
# Processed 682000/1625815 texts
# Processed 683000/1625815 texts
# Processed 684000/1625815 texts
# Processed 685000/1625815 texts
# Processed 686000/1625815 texts
# Processed 687000/1625815 texts
# Processed 688000/1625815 texts
# Processed 689000/1625815 texts
# Processed 690000/1625815 texts
# Processed 691000/1625815 texts
# Processed 692000/1625815 texts
# Processed 693000/1625815 texts
# Processed 694000/1625815 texts
# Processed 695000/1625815 texts
# Processed 696000/1625815 texts
# Processed 697000/1625815 texts
# Processed 698000/1625815 texts
# Processed 699000/1625815 texts
# Processed 700000/1625815 texts
# Processed 701000/1625815 texts
# Processed 702000/1625815 texts
# Processed 703000/1625815 texts
# Processed 704000/1625815 texts
# Processed 705000/1625815 texts
# Processed 706000/1625815 texts
# Processed 707000/1625815 texts
# Processed 708000/1625815 texts
# Processed 709000/1625815 texts
# Processed 710000/1625815 texts
# Processed 711000/1625815 texts
# Processed 712000/1625815 texts
# Processed 713000/1625815 texts
# Processed 714000/1625815 texts
# Processed 715000/1625815 texts
# Processed 716000/1625815 texts
# Processed 717000/1625815 texts
# Processed 718000/1625815 texts
# Processed 719000/1625815 texts
# Processed 720000/1625815 texts
# Processed 721000/1625815 texts
# Processed 722000/1625815 texts
# Processed 723000/1625815 texts
# Processed 724000/1625815 texts
# Processed 725000/1625815 texts
# Processed 726000/1625815 texts
# Processed 727000/1625815 texts
# Processed 728000/1625815 texts
# Processed 729000/1625815 texts
# Processed 730000/1625815 texts
# Processed 731000/1625815 texts
# Processed 732000/1625815 texts
# Processed 733000/1625815 texts
# Processed 734000/1625815 texts
# Processed 735000/1625815 texts
# Processed 736000/1625815 texts
# Processed 737000/1625815 texts
# Processed 738000/1625815 texts
# Processed 739000/1625815 texts
# Processed 740000/1625815 texts
# Processed 741000/1625815 texts
# Processed 742000/1625815 texts
# Processed 743000/1625815 texts
# Processed 744000/1625815 texts
# Processed 745000/1625815 texts
# Processed 746000/1625815 texts
# Processed 747000/1625815 texts
# Processed 748000/1625815 texts
# Processed 749000/1625815 texts
# Processed 750000/1625815 texts
# Processed 751000/1625815 texts
# Processed 752000/1625815 texts
# Processed 753000/1625815 texts
# Processed 754000/1625815 texts
# Processed 755000/1625815 texts
# Processed 756000/1625815 texts
# Processed 757000/1625815 texts
# Processed 758000/1625815 texts
# Processed 759000/1625815 texts
# Processed 760000/1625815 texts
# Processed 761000/1625815 texts
# Processed 762000/1625815 texts
# Processed 763000/1625815 texts
# Processed 764000/1625815 texts
# Processed 765000/1625815 texts
# Processed 766000/1625815 texts
# Processed 767000/1625815 texts
# Processed 768000/1625815 texts
# Processed 769000/1625815 texts
# Processed 770000/1625815 texts
# Processed 771000/1625815 texts
# Processed 772000/1625815 texts
# Processed 773000/1625815 texts
# Processed 774000/1625815 texts
# Processed 775000/1625815 texts
# Processed 776000/1625815 texts
# Processed 777000/1625815 texts
# Processed 778000/1625815 texts
# Processed 779000/1625815 texts
# Processed 780000/1625815 texts
# Processed 781000/1625815 texts
# Processed 782000/1625815 texts
# Processed 783000/1625815 texts
# Processed 784000/1625815 texts
# Processed 785000/1625815 texts
# Processed 786000/1625815 texts
# Processed 787000/1625815 texts
# Processed 788000/1625815 texts
# Processed 789000/1625815 texts
# Processed 790000/1625815 texts
# Processed 791000/1625815 texts
# Processed 792000/1625815 texts
# Processed 793000/1625815 texts
# Processed 794000/1625815 texts
# Processed 795000/1625815 texts
# Processed 796000/1625815 texts
# Processed 797000/1625815 texts
# Processed 798000/1625815 texts
# Processed 799000/1625815 texts
# Processed 800000/1625815 texts
# Processed 801000/1625815 texts
# Processed 802000/1625815 texts
# Processed 803000/1625815 texts
# Processed 804000/1625815 texts
# Processed 805000/1625815 texts
# Processed 806000/1625815 texts
# Processed 807000/1625815 texts
# Processed 808000/1625815 texts
# Processed 809000/1625815 texts
# Processed 810000/1625815 texts
# Processed 811000/1625815 texts
# Processed 812000/1625815 texts
# Processed 813000/1625815 texts
# Processed 814000/1625815 texts
# Processed 815000/1625815 texts
# Processed 816000/1625815 texts
# Processed 817000/1625815 texts
# Processed 818000/1625815 texts
# Processed 819000/1625815 texts
# Processed 820000/1625815 texts
# Processed 821000/1625815 texts
# Processed 822000/1625815 texts
# Processed 823000/1625815 texts
# Processed 824000/1625815 texts
# Processed 825000/1625815 texts
# Processed 826000/1625815 texts
# Processed 827000/1625815 texts
# Processed 828000/1625815 texts
# Processed 829000/1625815 texts
# Processed 830000/1625815 texts
# Processed 831000/1625815 texts
# Processed 832000/1625815 texts
# Processed 833000/1625815 texts
# Processed 834000/1625815 texts
# Processed 835000/1625815 texts
# Processed 836000/1625815 texts
# Processed 837000/1625815 texts
# Processed 838000/1625815 texts
# Processed 839000/1625815 texts
# Processed 840000/1625815 texts
# Processed 841000/1625815 texts
# Processed 842000/1625815 texts
# Processed 843000/1625815 texts
# Processed 844000/1625815 texts
# Processed 845000/1625815 texts
# Processed 846000/1625815 texts
# Processed 847000/1625815 texts
# Processed 848000/1625815 texts
# Processed 849000/1625815 texts
# Processed 850000/1625815 texts
# Processed 851000/1625815 texts
# Processed 852000/1625815 texts
# Processed 853000/1625815 texts
# Processed 854000/1625815 texts
# Processed 855000/1625815 texts
# Processed 856000/1625815 texts
# Processed 857000/1625815 texts
# Processed 858000/1625815 texts
# Processed 859000/1625815 texts
# Processed 860000/1625815 texts
# Processed 861000/1625815 texts
# Processed 862000/1625815 texts
# Processed 863000/1625815 texts
# Processed 864000/1625815 texts
# Processed 865000/1625815 texts
# Processed 866000/1625815 texts
# Processed 867000/1625815 texts
# Processed 868000/1625815 texts
# Processed 869000/1625815 texts
# Processed 870000/1625815 texts
# Processed 871000/1625815 texts
# Processed 872000/1625815 texts
# Processed 873000/1625815 texts
# Processed 874000/1625815 texts
# Processed 875000/1625815 texts
# Processed 876000/1625815 texts
# Processed 877000/1625815 texts
# Processed 878000/1625815 texts
# Processed 879000/1625815 texts
# Processed 880000/1625815 texts
# Processed 881000/1625815 texts
# Processed 882000/1625815 texts
# Processed 883000/1625815 texts
# Processed 884000/1625815 texts
# Processed 885000/1625815 texts
# Processed 886000/1625815 texts
# Processed 887000/1625815 texts
# Processed 888000/1625815 texts
# Processed 889000/1625815 texts
# Processed 890000/1625815 texts
# Processed 891000/1625815 texts
# Processed 892000/1625815 texts
# Processed 893000/1625815 texts
# Processed 894000/1625815 texts
# Processed 895000/1625815 texts
# Processed 896000/1625815 texts
# Processed 897000/1625815 texts
# Processed 898000/1625815 texts
# Processed 899000/1625815 texts
# Processed 900000/1625815 texts
# Processed 901000/1625815 texts
# Processed 902000/1625815 texts
# Processed 903000/1625815 texts
# Processed 904000/1625815 texts
# Processed 905000/1625815 texts
# Processed 906000/1625815 texts
# Processed 907000/1625815 texts
# Processed 908000/1625815 texts
# Processed 909000/1625815 texts
# Processed 910000/1625815 texts
# Processed 911000/1625815 texts
# Processed 912000/1625815 texts
# Processed 913000/1625815 texts
# Processed 914000/1625815 texts
# Processed 915000/1625815 texts
# Processed 916000/1625815 texts
# Processed 917000/1625815 texts
# Processed 918000/1625815 texts
# Processed 919000/1625815 texts
# Processed 920000/1625815 texts
# Processed 921000/1625815 texts
# Processed 922000/1625815 texts
# Processed 923000/1625815 texts
# Processed 924000/1625815 texts
# Processed 925000/1625815 texts
# Processed 926000/1625815 texts
# Processed 927000/1625815 texts
# Processed 928000/1625815 texts
# Processed 929000/1625815 texts
# Processed 930000/1625815 texts
# Processed 931000/1625815 texts
# Processed 932000/1625815 texts
# Processed 933000/1625815 texts
# Processed 934000/1625815 texts
# Processed 935000/1625815 texts
# Processed 936000/1625815 texts
# Processed 937000/1625815 texts
# Processed 938000/1625815 texts
# Processed 939000/1625815 texts
# Processed 940000/1625815 texts
# Processed 941000/1625815 texts
# Processed 942000/1625815 texts
# Processed 943000/1625815 texts
# Processed 944000/1625815 texts
# Processed 945000/1625815 texts
# Processed 946000/1625815 texts
# Processed 947000/1625815 texts
# Processed 948000/1625815 texts
# Processed 949000/1625815 texts
# Processed 950000/1625815 texts
# Processed 951000/1625815 texts
# Processed 952000/1625815 texts
# Processed 953000/1625815 texts
# Processed 954000/1625815 texts
# Processed 955000/1625815 texts
# Processed 956000/1625815 texts
# Processed 957000/1625815 texts
# Processed 958000/1625815 texts
# Processed 959000/1625815 texts
# Processed 960000/1625815 texts
# Processed 961000/1625815 texts
# Processed 962000/1625815 texts
# Processed 963000/1625815 texts
# Processed 964000/1625815 texts
# Processed 965000/1625815 texts
# Processed 966000/1625815 texts
# Processed 967000/1625815 texts
# Processed 968000/1625815 texts
# Processed 969000/1625815 texts
# Processed 970000/1625815 texts
# Processed 971000/1625815 texts
# Processed 972000/1625815 texts
# Processed 973000/1625815 texts
# Processed 974000/1625815 texts
# Processed 975000/1625815 texts
# Processed 976000/1625815 texts
# Processed 977000/1625815 texts
# Processed 978000/1625815 texts
# Processed 979000/1625815 texts
# Processed 980000/1625815 texts
# Processed 981000/1625815 texts
# Processed 982000/1625815 texts
# Processed 983000/1625815 texts
# Processed 984000/1625815 texts
# Processed 985000/1625815 texts
# Processed 986000/1625815 texts
# Processed 987000/1625815 texts
# Processed 988000/1625815 texts
# Processed 989000/1625815 texts
# Processed 990000/1625815 texts
# Processed 991000/1625815 texts
# Processed 992000/1625815 texts
# Processed 993000/1625815 texts
# Processed 994000/1625815 texts
# Processed 995000/1625815 texts
# Processed 996000/1625815 texts
# Processed 997000/1625815 texts
# Processed 998000/1625815 texts
# Processed 999000/1625815 texts
# Processed 1000000/1625815 texts
# Processed 1001000/1625815 texts
# Processed 1002000/1625815 texts
# Processed 1003000/1625815 texts
# Processed 1004000/1625815 texts
# Processed 1005000/1625815 texts
# Processed 1006000/1625815 texts
# Processed 1007000/1625815 texts
# Processed 1008000/1625815 texts
# Processed 1009000/1625815 texts
# Processed 1010000/1625815 texts
# Processed 1011000/1625815 texts
# Processed 1012000/1625815 texts
# Processed 1013000/1625815 texts
# Processed 1014000/1625815 texts
# Processed 1015000/1625815 texts
# Processed 1016000/1625815 texts
# Processed 1017000/1625815 texts
# Processed 1018000/1625815 texts
# Processed 1019000/1625815 texts
# Processed 1020000/1625815 texts
# Processed 1021000/1625815 texts
# Processed 1022000/1625815 texts
# Processed 1023000/1625815 texts
# Processed 1024000/1625815 texts
# Processed 1025000/1625815 texts
# Processed 1026000/1625815 texts
# Processed 1027000/1625815 texts
# Processed 1028000/1625815 texts
# Processed 1029000/1625815 texts
# Processed 1030000/1625815 texts
# Processed 1031000/1625815 texts
# Processed 1032000/1625815 texts
# Processed 1033000/1625815 texts
# Processed 1034000/1625815 texts
# Processed 1035000/1625815 texts
# Processed 1036000/1625815 texts
# Processed 1037000/1625815 texts
# Processed 1038000/1625815 texts
# Processed 1039000/1625815 texts
# Processed 1040000/1625815 texts
# Processed 1041000/1625815 texts
# Processed 1042000/1625815 texts
# Processed 1043000/1625815 texts
# Processed 1044000/1625815 texts
# Processed 1045000/1625815 texts
# Processed 1046000/1625815 texts
# Processed 1047000/1625815 texts
# Processed 1048000/1625815 texts
# Processed 1049000/1625815 texts
# Processed 1050000/1625815 texts
# Processed 1051000/1625815 texts
# Processed 1052000/1625815 texts
# Processed 1053000/1625815 texts
# Processed 1054000/1625815 texts
# Processed 1055000/1625815 texts
# Processed 1056000/1625815 texts
# Processed 1057000/1625815 texts
# Processed 1058000/1625815 texts
# Processed 1059000/1625815 texts
# Processed 1060000/1625815 texts
# Processed 1061000/1625815 texts
# Processed 1062000/1625815 texts
# Processed 1063000/1625815 texts
# Processed 1064000/1625815 texts
# Processed 1065000/1625815 texts
# Processed 1066000/1625815 texts
# Processed 1067000/1625815 texts
# Processed 1068000/1625815 texts
# Processed 1069000/1625815 texts
# Processed 1070000/1625815 texts
# Processed 1071000/1625815 texts
# Processed 1072000/1625815 texts
# Processed 1073000/1625815 texts
# Processed 1074000/1625815 texts
# Processed 1075000/1625815 texts
# Processed 1076000/1625815 texts
# Processed 1077000/1625815 texts
# Processed 1078000/1625815 texts
# Processed 1079000/1625815 texts
# Processed 1080000/1625815 texts
# Processed 1081000/1625815 texts
# Processed 1082000/1625815 texts
# Processed 1083000/1625815 texts
# Processed 1084000/1625815 texts
# Processed 1085000/1625815 texts
# Processed 1086000/1625815 texts
# Processed 1087000/1625815 texts
# Processed 1088000/1625815 texts
# Processed 1089000/1625815 texts
# Processed 1090000/1625815 texts
# Processed 1091000/1625815 texts
# Processed 1092000/1625815 texts
# Processed 1093000/1625815 texts
# Processed 1094000/1625815 texts
# Processed 1095000/1625815 texts
# Processed 1096000/1625815 texts
# Processed 1097000/1625815 texts
# Processed 1098000/1625815 texts
# Processed 1099000/1625815 texts
# Processed 1100000/1625815 texts
# Processed 1101000/1625815 texts
# Processed 1102000/1625815 texts
# Processed 1103000/1625815 texts
# Processed 1104000/1625815 texts
# Processed 1105000/1625815 texts
# Processed 1106000/1625815 texts
# Processed 1107000/1625815 texts
# Processed 1108000/1625815 texts
# Processed 1109000/1625815 texts
# Processed 1110000/1625815 texts
# Processed 1111000/1625815 texts
# Processed 1112000/1625815 texts
# Processed 1113000/1625815 texts
# Processed 1114000/1625815 texts
# Processed 1115000/1625815 texts
# Processed 1116000/1625815 texts
# Processed 1117000/1625815 texts
# Processed 1118000/1625815 texts
# Processed 1119000/1625815 texts
# Processed 1120000/1625815 texts
# Processed 1121000/1625815 texts
# Processed 1122000/1625815 texts
# Processed 1123000/1625815 texts
# Processed 1124000/1625815 texts
# Processed 1125000/1625815 texts
# Processed 1126000/1625815 texts
# Processed 1127000/1625815 texts
# Processed 1128000/1625815 texts
# Processed 1129000/1625815 texts
# Processed 1130000/1625815 texts
# Processed 1131000/1625815 texts
# Processed 1132000/1625815 texts
# Processed 1133000/1625815 texts
# Processed 1134000/1625815 texts
# Processed 1135000/1625815 texts
# Processed 1136000/1625815 texts
# Processed 1137000/1625815 texts
# Processed 1138000/1625815 texts
# Processed 1139000/1625815 texts
# Processed 1140000/1625815 texts
# Processed 1141000/1625815 texts
# Processed 1142000/1625815 texts
# Processed 1143000/1625815 texts
# Processed 1144000/1625815 texts
# Processed 1145000/1625815 texts
# Processed 1146000/1625815 texts
# Processed 1147000/1625815 texts
# Processed 1148000/1625815 texts
# Processed 1149000/1625815 texts
# Processed 1150000/1625815 texts
# Processed 1151000/1625815 texts
# Processed 1152000/1625815 texts
# Processed 1153000/1625815 texts
# Processed 1154000/1625815 texts
# Processed 1155000/1625815 texts
# Processed 1156000/1625815 texts
# Processed 1157000/1625815 texts
# Processed 1158000/1625815 texts
# Processed 1159000/1625815 texts
# Processed 1160000/1625815 texts
# Processed 1161000/1625815 texts
# Processed 1162000/1625815 texts
# Processed 1163000/1625815 texts
# Processed 1164000/1625815 texts
# Processed 1165000/1625815 texts
# Processed 1166000/1625815 texts
# Processed 1167000/1625815 texts
# Processed 1168000/1625815 texts
# Processed 1169000/1625815 texts
# Processed 1170000/1625815 texts
# Processed 1171000/1625815 texts
# Processed 1172000/1625815 texts
# Processed 1173000/1625815 texts
# Processed 1174000/1625815 texts
# Processed 1175000/1625815 texts
# Processed 1176000/1625815 texts
# Processed 1177000/1625815 texts
# Processed 1178000/1625815 texts
# Processed 1179000/1625815 texts
# Processed 1180000/1625815 texts
# Processed 1181000/1625815 texts
# Processed 1182000/1625815 texts
# Processed 1183000/1625815 texts
# Processed 1184000/1625815 texts
# Processed 1185000/1625815 texts
# Processed 1186000/1625815 texts
# Processed 1187000/1625815 texts
# Processed 1188000/1625815 texts
# Processed 1189000/1625815 texts
# Processed 1190000/1625815 texts
# Processed 1191000/1625815 texts
# Processed 1192000/1625815 texts
# Processed 1193000/1625815 texts
# Processed 1194000/1625815 texts
# Processed 1195000/1625815 texts
# Processed 1196000/1625815 texts
# Processed 1197000/1625815 texts
# Processed 1198000/1625815 texts
# Processed 1199000/1625815 texts
# Processed 1200000/1625815 texts
# Processed 1201000/1625815 texts
# Processed 1202000/1625815 texts
# Processed 1203000/1625815 texts
# Processed 1204000/1625815 texts
# Processed 1205000/1625815 texts
# Processed 1206000/1625815 texts
# Processed 1207000/1625815 texts
# Processed 1208000/1625815 texts
# Processed 1209000/1625815 texts
# Processed 1210000/1625815 texts
# Processed 1211000/1625815 texts
# Processed 1212000/1625815 texts
# Processed 1213000/1625815 texts
# Processed 1214000/1625815 texts
# Processed 1215000/1625815 texts
# Processed 1216000/1625815 texts
# Processed 1217000/1625815 texts
# Processed 1218000/1625815 texts
# Processed 1219000/1625815 texts
# Processed 1220000/1625815 texts
# Processed 1221000/1625815 texts
# Processed 1222000/1625815 texts
# Processed 1223000/1625815 texts
# Processed 1224000/1625815 texts
# Processed 1225000/1625815 texts
# Processed 1226000/1625815 texts
# Processed 1227000/1625815 texts
# Processed 1228000/1625815 texts
# Processed 1229000/1625815 texts
# Processed 1230000/1625815 texts
# Processed 1231000/1625815 texts
# Processed 1232000/1625815 texts
# Processed 1233000/1625815 texts
# Processed 1234000/1625815 texts
# Processed 1235000/1625815 texts
# Processed 1236000/1625815 texts
# Processed 1237000/1625815 texts
# Processed 1238000/1625815 texts
# Processed 1239000/1625815 texts
# Processed 1240000/1625815 texts
# Processed 1241000/1625815 texts
# Processed 1242000/1625815 texts
# Processed 1243000/1625815 texts
# Processed 1244000/1625815 texts
# Processed 1245000/1625815 texts
# Processed 1246000/1625815 texts
# Processed 1247000/1625815 texts
# Processed 1248000/1625815 texts
# Processed 1249000/1625815 texts
# Processed 1250000/1625815 texts
# Processed 1251000/1625815 texts
# Processed 1252000/1625815 texts
# Processed 1253000/1625815 texts
# Processed 1254000/1625815 texts
# Processed 1255000/1625815 texts
# Processed 1256000/1625815 texts
# Processed 1257000/1625815 texts
# Processed 1258000/1625815 texts
# Processed 1259000/1625815 texts
# Processed 1260000/1625815 texts
# Processed 1261000/1625815 texts
# Processed 1262000/1625815 texts
# Processed 1263000/1625815 texts
# Processed 1264000/1625815 texts
# Processed 1265000/1625815 texts
# Processed 1266000/1625815 texts
# Processed 1267000/1625815 texts
# Processed 1268000/1625815 texts
# Processed 1269000/1625815 texts
# Processed 1270000/1625815 texts
# Processed 1271000/1625815 texts
# Processed 1272000/1625815 texts
# Processed 1273000/1625815 texts
# Processed 1274000/1625815 texts
# Processed 1275000/1625815 texts
# Processed 1276000/1625815 texts
# Processed 1277000/1625815 texts
# Processed 1278000/1625815 texts
# Processed 1279000/1625815 texts
# Processed 1280000/1625815 texts
# Processed 1281000/1625815 texts
# Processed 1282000/1625815 texts
# Processed 1283000/1625815 texts
# Processed 1284000/1625815 texts
# Processed 1285000/1625815 texts
# Processed 1286000/1625815 texts
# Processed 1287000/1625815 texts
# Processed 1288000/1625815 texts
# Processed 1289000/1625815 texts
# Processed 1290000/1625815 texts
# Processed 1291000/1625815 texts
# Processed 1292000/1625815 texts
# Processed 1293000/1625815 texts
# Processed 1294000/1625815 texts
# Processed 1295000/1625815 texts
# Processed 1296000/1625815 texts
# Processed 1297000/1625815 texts
# Processed 1298000/1625815 texts
# Processed 1299000/1625815 texts
# Processed 1300000/1625815 texts
# Processed 1301000/1625815 texts
# Processed 1302000/1625815 texts
# Processed 1303000/1625815 texts
# Processed 1304000/1625815 texts
# Processed 1305000/1625815 texts
# Processed 1306000/1625815 texts
# Processed 1307000/1625815 texts
# Processed 1308000/1625815 texts
# Processed 1309000/1625815 texts
# Processed 1310000/1625815 texts
# Processed 1311000/1625815 texts
# Processed 1312000/1625815 texts
# Processed 1313000/1625815 texts
# Processed 1314000/1625815 texts
# Processed 1315000/1625815 texts
# Processed 1316000/1625815 texts
# Processed 1317000/1625815 texts
# Processed 1318000/1625815 texts
# Processed 1319000/1625815 texts
# Processed 1320000/1625815 texts
# Processed 1321000/1625815 texts
# Processed 1322000/1625815 texts
# Processed 1323000/1625815 texts
# Processed 1324000/1625815 texts
# Processed 1325000/1625815 texts
# Processed 1326000/1625815 texts
# Processed 1327000/1625815 texts
# Processed 1328000/1625815 texts
# Processed 1329000/1625815 texts
# Processed 1330000/1625815 texts
# Processed 1331000/1625815 texts
# Processed 1332000/1625815 texts
# Processed 1333000/1625815 texts
# Processed 1334000/1625815 texts
# Processed 1335000/1625815 texts
# Processed 1336000/1625815 texts
# Processed 1337000/1625815 texts
# Processed 1338000/1625815 texts
# Processed 1339000/1625815 texts
# Processed 1340000/1625815 texts
# Processed 1341000/1625815 texts
# Processed 1342000/1625815 texts
# Processed 1343000/1625815 texts
# Processed 1344000/1625815 texts
# Processed 1345000/1625815 texts
# Processed 1346000/1625815 texts
# Processed 1347000/1625815 texts
# Processed 1348000/1625815 texts
# Processed 1349000/1625815 texts
# Processed 1350000/1625815 texts
# Processed 1351000/1625815 texts
# Processed 1352000/1625815 texts
# Processed 1353000/1625815 texts
# Processed 1354000/1625815 texts
# Processed 1355000/1625815 texts
# Processed 1356000/1625815 texts
# Processed 1357000/1625815 texts
# Processed 1358000/1625815 texts
# Processed 1359000/1625815 texts
# Processed 1360000/1625815 texts
# Processed 1361000/1625815 texts
# Processed 1362000/1625815 texts
# Processed 1363000/1625815 texts
# Processed 1364000/1625815 texts
# Processed 1365000/1625815 texts
# Processed 1366000/1625815 texts
# Processed 1367000/1625815 texts
# Processed 1368000/1625815 texts
# Processed 1369000/1625815 texts
# Processed 1370000/1625815 texts
# Processed 1371000/1625815 texts
# Processed 1372000/1625815 texts
# Processed 1373000/1625815 texts
# Processed 1374000/1625815 texts
# Processed 1375000/1625815 texts
# Processed 1376000/1625815 texts
# Processed 1377000/1625815 texts
# Processed 1378000/1625815 texts
# Processed 1379000/1625815 texts
# Processed 1380000/1625815 texts
# Processed 1381000/1625815 texts
# Processed 1382000/1625815 texts
# Processed 1383000/1625815 texts
# Processed 1384000/1625815 texts
# Processed 1385000/1625815 texts
# Processed 1386000/1625815 texts
# Processed 1387000/1625815 texts
# Processed 1388000/1625815 texts
# Processed 1389000/1625815 texts
# Processed 1390000/1625815 texts
# Processed 1391000/1625815 texts
# Processed 1392000/1625815 texts
# Processed 1393000/1625815 texts
# Processed 1394000/1625815 texts
# Processed 1395000/1625815 texts
# Processed 1396000/1625815 texts
# Processed 1397000/1625815 texts
# Processed 1398000/1625815 texts
# Processed 1399000/1625815 texts
# Processed 1400000/1625815 texts
# Processed 1401000/1625815 texts
# Processed 1402000/1625815 texts
# Processed 1403000/1625815 texts
# Processed 1404000/1625815 texts
# Processed 1405000/1625815 texts
# Processed 1406000/1625815 texts
# Processed 1407000/1625815 texts
# Processed 1408000/1625815 texts
# Processed 1409000/1625815 texts
# Processed 1410000/1625815 texts
# Processed 1411000/1625815 texts
# Processed 1412000/1625815 texts
# Processed 1413000/1625815 texts
# Processed 1414000/1625815 texts
# Processed 1415000/1625815 texts
# Processed 1416000/1625815 texts
# Processed 1417000/1625815 texts
# Processed 1418000/1625815 texts
# Processed 1419000/1625815 texts
# Processed 1420000/1625815 texts
# Processed 1421000/1625815 texts
# Processed 1422000/1625815 texts
# Processed 1423000/1625815 texts
# Processed 1424000/1625815 texts
# Processed 1425000/1625815 texts
# Processed 1426000/1625815 texts
# Processed 1427000/1625815 texts
# Processed 1428000/1625815 texts
# Processed 1429000/1625815 texts
# Processed 1430000/1625815 texts
# Processed 1431000/1625815 texts
# Processed 1432000/1625815 texts
# Processed 1433000/1625815 texts
# Processed 1434000/1625815 texts
# Processed 1435000/1625815 texts
# Processed 1436000/1625815 texts
# Processed 1437000/1625815 texts
# Processed 1438000/1625815 texts
# Processed 1439000/1625815 texts
# Processed 1440000/1625815 texts
# Processed 1441000/1625815 texts
# Processed 1442000/1625815 texts
# Processed 1443000/1625815 texts
# Processed 1444000/1625815 texts
# Processed 1445000/1625815 texts
# Processed 1446000/1625815 texts
# Processed 1447000/1625815 texts
# Processed 1448000/1625815 texts
# Processed 1449000/1625815 texts
# Processed 1450000/1625815 texts
# Processed 1451000/1625815 texts
# Processed 1452000/1625815 texts
# Processed 1453000/1625815 texts
# Processed 1454000/1625815 texts
# Processed 1455000/1625815 texts
# Processed 1456000/1625815 texts
# Processed 1457000/1625815 texts
# Processed 1458000/1625815 texts
# Processed 1459000/1625815 texts
# Processed 1460000/1625815 texts
# Processed 1461000/1625815 texts
# Processed 1462000/1625815 texts
# Processed 1463000/1625815 texts
# Processed 1464000/1625815 texts
# Processed 1465000/1625815 texts
# Processed 1466000/1625815 texts
# Processed 1467000/1625815 texts
# Processed 1468000/1625815 texts
# Processed 1469000/1625815 texts
# Processed 1470000/1625815 texts
# Processed 1471000/1625815 texts
# Processed 1472000/1625815 texts
# Processed 1473000/1625815 texts
# Processed 1474000/1625815 texts
# Processed 1475000/1625815 texts
# Processed 1476000/1625815 texts
# Processed 1477000/1625815 texts
# Processed 1478000/1625815 texts
# Processed 1479000/1625815 texts
# Processed 1480000/1625815 texts
# Processed 1481000/1625815 texts
# Processed 1482000/1625815 texts
# Processed 1483000/1625815 texts
# Processed 1484000/1625815 texts
# Processed 1485000/1625815 texts
# Processed 1486000/1625815 texts
# Processed 1487000/1625815 texts
# Processed 1488000/1625815 texts
# Processed 1489000/1625815 texts
# Processed 1490000/1625815 texts
# Processed 1491000/1625815 texts
# Processed 1492000/1625815 texts
# Processed 1493000/1625815 texts
# Processed 1494000/1625815 texts
# Processed 1495000/1625815 texts
# Processed 1496000/1625815 texts
# Processed 1497000/1625815 texts
# Processed 1498000/1625815 texts
# Processed 1499000/1625815 texts
# Processed 1500000/1625815 texts
# Processed 1501000/1625815 texts
# Processed 1502000/1625815 texts
# Processed 1503000/1625815 texts
# Processed 1504000/1625815 texts
# Processed 1505000/1625815 texts
# Processed 1506000/1625815 texts
# Processed 1507000/1625815 texts
# Processed 1508000/1625815 texts
# Processed 1509000/1625815 texts
# Processed 1510000/1625815 texts
# Processed 1511000/1625815 texts
# Processed 1512000/1625815 texts
# Processed 1513000/1625815 texts
# Processed 1514000/1625815 texts
# Processed 1515000/1625815 texts
# Processed 1516000/1625815 texts
# Processed 1517000/1625815 texts
# Processed 1518000/1625815 texts
# Processed 1519000/1625815 texts
# Processed 1520000/1625815 texts
# Processed 1521000/1625815 texts
# Processed 1522000/1625815 texts
# Processed 1523000/1625815 texts
# Processed 1524000/1625815 texts
# Processed 1525000/1625815 texts
# Processed 1526000/1625815 texts
# Processed 1527000/1625815 texts
# Processed 1528000/1625815 texts
# Processed 1529000/1625815 texts
# Processed 1530000/1625815 texts
# Processed 1531000/1625815 texts
# Processed 1532000/1625815 texts
# Processed 1533000/1625815 texts
# Processed 1534000/1625815 texts
# Processed 1535000/1625815 texts
# Processed 1536000/1625815 texts
# Processed 1537000/1625815 texts
# Processed 1538000/1625815 texts
# Processed 1539000/1625815 texts
# Processed 1540000/1625815 texts
# Processed 1541000/1625815 texts
# Processed 1542000/1625815 texts
# Processed 1543000/1625815 texts
# Processed 1544000/1625815 texts
# Processed 1545000/1625815 texts
# Processed 1546000/1625815 texts
# Processed 1547000/1625815 texts
# Processed 1548000/1625815 texts
# Processed 1549000/1625815 texts
# Processed 1550000/1625815 texts
# Processed 1551000/1625815 texts
# Processed 1552000/1625815 texts
# Processed 1553000/1625815 texts
# Processed 1554000/1625815 texts
# Processed 1555000/1625815 texts
# Processed 1556000/1625815 texts
# Processed 1557000/1625815 texts
# Processed 1558000/1625815 texts
# Processed 1559000/1625815 texts
# Processed 1560000/1625815 texts
# Processed 1561000/1625815 texts
# Processed 1562000/1625815 texts
# Processed 1563000/1625815 texts
# Processed 1564000/1625815 texts
# Processed 1565000/1625815 texts
# Processed 1566000/1625815 texts
# Processed 1567000/1625815 texts
# Processed 1568000/1625815 texts
# Processed 1569000/1625815 texts
# Processed 1570000/1625815 texts
# Processed 1571000/1625815 texts
# Processed 1572000/1625815 texts
# Processed 1573000/1625815 texts
# Processed 1574000/1625815 texts
# Processed 1575000/1625815 texts
# Processed 1576000/1625815 texts
# Processed 1577000/1625815 texts
# Processed 1578000/1625815 texts
# Processed 1579000/1625815 texts
# Processed 1580000/1625815 texts
# Processed 1581000/1625815 texts
# Processed 1582000/1625815 texts
# Processed 1583000/1625815 texts
# Processed 1584000/1625815 texts
# Processed 1585000/1625815 texts
# Processed 1586000/1625815 texts
# Processed 1587000/1625815 texts
# Processed 1588000/1625815 texts
# Processed 1589000/1625815 texts
# Processed 1590000/1625815 texts
# Processed 1591000/1625815 texts
# Processed 1592000/1625815 texts
# Processed 1593000/1625815 texts
# Processed 1594000/1625815 texts
# Processed 1595000/1625815 texts
# Processed 1596000/1625815 texts
# Processed 1597000/1625815 texts
# Processed 1598000/1625815 texts
# Processed 1599000/1625815 texts
# Processed 1600000/1625815 texts
# Processed 1601000/1625815 texts
# Processed 1602000/1625815 texts
# Processed 1603000/1625815 texts
# Processed 1604000/1625815 texts
# Processed 1605000/1625815 texts
# Processed 1606000/1625815 texts
# Processed 1607000/1625815 texts
# Processed 1608000/1625815 texts
# Processed 1609000/1625815 texts
# Processed 1610000/1625815 texts
# Processed 1611000/1625815 texts
# Processed 1612000/1625815 texts
# Processed 1613000/1625815 texts
# Processed 1614000/1625815 texts
# Processed 1615000/1625815 texts
# Processed 1616000/1625815 texts
# Processed 1617000/1625815 texts
# Processed 1618000/1625815 texts
# Processed 1619000/1625815 texts
# Processed 1620000/1625815 texts
# Processed 1621000/1625815 texts
# Processed 1622000/1625815 texts
# Processed 1623000/1625815 texts
# Processed 1624000/1625815 texts
# Processed 1625000/1625815 texts
# Processed 1625815/1625815 texts

# %%
sentiment_df.head()
# Out:
#     ticker_symbol company_name            tweet_id           writer  \
# 144          AAPL        apple  550653576716890113  LloydCreekStock
# 145          AAPL        apple  550654457420066818      MacHashNews
# 146          AAPL        apple  550658389122895873         ybfmiami
# 147          TSLA    Tesla Inc  550658779117666304       kirillklip
# 148          TSLA    Tesla Inc  550661171309600768       kirillklip
#
#                date_utc                                               body  \
# 144 2015-01-01 14:03:37  2015 will be apples year raising price target ...
# 145 2015-01-01 14:07:07  apple pushes ‘start something new webpage worl...
# 146 2015-01-01 14:22:45  commented on stocktwits he knows that $aapl ha...
# 147 2015-01-01 14:24:18  almost 100 electric cars were sold in china in...
# 148 2015-01-01 14:33:48  how its made dream cars tesla model s url $tsl...
#
#      comment_num  retweet_num  like_num  word_count  ...  cashtag_count  \
# 144            0            0         1          18  ...              2
# 145            0            0         1          13  ...              1
# 146            0            0         1          20  ...              1
# 147            0            1         1          14  ...              3
# 148            0            0         0          13  ...              3
#
#      mention_count  cashtag_ratio  hashtag_ratio  mention_ratio  \
# 144              0       0.111111       0.000000            0.0
# 145              0       0.076923       0.076923            0.0
# 146              0       0.050000       0.000000            0.0
# 147              0       0.214286       0.000000            0.0
# 148              0       0.230769       0.000000            0.0
#
#      keyword_count             date_new_york hour  sentiment  \
# 144              0 2015-01-01 09:03:37-05:00    9          1
# 145              1 2015-01-01 09:07:07-05:00    9          1
# 146              0 2015-01-01 09:22:45-05:00    9          2
# 147              0 2015-01-01 09:24:18-05:00    9          1
# 148              0 2015-01-01 09:33:48-05:00    9          1
#
#                                  sentiment_probability
# 144  [0.654727864920058, 0.22675529669355593, 0.118...
# 145  [0.4333587103104307, 0.41166565493077784, 0.15...
# 146  [0.17909566304603766, 0.5372814214205074, 0.28...
# 147  [0.5721005456025544, 0.10387717651417847, 0.32...
# 148  [0.4869454321463026, 0.33155936876012554, 0.18...
#
# [5 rows x 21 columns]

# %%
# Replace sentiment values so we can compute their average

# Convert the 'sentiment' column to integer
sentiment_df['sentiment'] = sentiment_df['sentiment'].astype(int)

# Define the mapping of old values to new values
replacement_map = {2: 0, 3: -1}

# Replace the values in the 'sentiment' column
sentiment_df['sentiment'] = sentiment_df['sentiment'].replace(replacement_map)

sentiment_df.head(n=2)
# Out:
#     ticker_symbol company_name            tweet_id           writer  \
# 144          AAPL        apple  550653576716890113  LloydCreekStock
# 145          AAPL        apple  550654457420066818      MacHashNews
#
#                date_utc                                               body  \
# 144 2015-01-01 14:03:37  2015 will be apples year raising price target ...
# 145 2015-01-01 14:07:07  apple pushes ‘start something new webpage worl...
#
#      comment_num  retweet_num  like_num  word_count  ...  cashtag_count  \
# 144            0            0         1          18  ...              2
# 145            0            0         1          13  ...              1
#
#      mention_count  cashtag_ratio  hashtag_ratio  mention_ratio  \
# 144              0       0.111111       0.000000            0.0
# 145              0       0.076923       0.076923            0.0
#
#      keyword_count             date_new_york hour  sentiment  \
# 144              0 2015-01-01 09:03:37-05:00    9          1
# 145              1 2015-01-01 09:07:07-05:00    9          1
#
#                                  sentiment_probability
# 144  [0.654727864920058, 0.22675529669355593, 0.118...
# 145  [0.4333587103104307, 0.41166565493077784, 0.15...
#
# [2 rows x 21 columns]

# %%
# Add column which calculates sentiment score as weighted sum of the probabilites
sentiment_df['sentiment_prob_sum'] = (sentiment_df['sentiment_probability'].apply(lambda p: 1 * p[0] + 0 * p[1] + -1 * p[2]))*100

# Add date_only column
sentiment_df['date_only_NY'] = pd.to_datetime(sentiment_df['date_new_york'].dt.date)

# %%
sentiment_df[(sentiment_df['date_only_NY']=='2015-01-01') & (sentiment_df['hour']==16)]['ticker_symbol'].unique()
# Out:
# array(['AAPL', 'TSLA', 'GOOGLE', 'MSFT'], dtype=object)

# %%
# Plot average sentiment per hour on a random day

jan_21_2015 = sentiment_df[sentiment_df['date_only_NY']=='2015-01-21']

jan_21_2015_hourly_sentiment = jan_21_2015.groupby(['ticker_symbol', 'hour'])['sentiment_prob_sum'].mean().reset_index()


jan_22_2015 = sentiment_df[sentiment_df['date_only_NY']=='2015-01-22']

jan_22_2015_hourly_sentiment = jan_22_2015.groupby(['ticker_symbol', 'hour'])['sentiment_prob_sum'].mean().reset_index()

jan_23_2015 = sentiment_df[sentiment_df['date_only_NY']=='2015-01-23']

jan_23_2015_hourly_sentiment = jan_23_2015.groupby(['ticker_symbol', 'hour'])['sentiment_prob_sum'].mean().reset_index()

# %%
jan_22_2015_hourly_sentiment.head()
# Out:
#   ticker_symbol  hour  sentiment_prob_sum
# 0          AAPL     9           28.024218
# 1          AAPL    10           12.759505
# 2          AAPL    11           16.903481
# 3          AAPL    12           12.008856
# 4          AAPL    13           -2.747039

# %%
companies = np.array(jan_21_2015_hourly_sentiment['ticker_symbol'].unique())

# %%
import matplotlib.pyplot as plt

# Assuming 'companies' and your dataframes are already defined and imported
plt.figure(figsize=(20, 10))
for i in range(len(companies)):
    # Specific hours where vertical lines should be added
    vertical_lines = [9, 16]

    # Plot for January 21, 2015
    plt.subplot(3, 5, 1 + i)
    df = jan_21_2015_hourly_sentiment[jan_21_2015_hourly_sentiment['ticker_symbol'] == companies[i]]
    mean_sentiment = df['sentiment_prob_sum'].mean()  # Calculate mean sentiment
    plt.plot(df['hour'], df['sentiment_prob_sum'])
    plt.axhline(y=mean_sentiment, color='r', linestyle='--')  # Plot mean line
    for hour in vertical_lines:
        plt.axvline(x=hour, color='g', linestyle=':')  # Add vertical lines
    plt.title(companies[i])

    # Plot for January 22, 2015
    plt.subplot(3, 5, 6 + i)
    df = jan_22_2015_hourly_sentiment[jan_22_2015_hourly_sentiment['ticker_symbol'] == companies[i]]
    mean_sentiment = df['sentiment_prob_sum'].mean()
    plt.plot(df['hour'], df['sentiment_prob_sum'])
    plt.axhline(y=mean_sentiment, color='r', linestyle='--')
    for hour in vertical_lines:
        plt.axvline(x=hour, color='g', linestyle=':')  # Add vertical lines
    plt.title(companies[i])

    # Plot for January 23, 2015
    plt.subplot(3, 5, 11 + i)
    df = jan_23_2015_hourly_sentiment[jan_23_2015_hourly_sentiment['ticker_symbol'] == companies[i]]
    mean_sentiment = df['sentiment_prob_sum'].mean()
    plt.plot(df['hour'], df['sentiment_prob_sum'])
    plt.axhline(y=mean_sentiment, color='r', linestyle='--')
    for hour in vertical_lines:
        plt.axvline(x=hour, color='g', linestyle=':')  # Add vertical lines
    plt.title(companies[i])

plt.show()  # Ensure this is correctly called to display the figure

# %% [markdown]
# ## Create slope variable for sentiment index
# The slope refers to the slope from hour 9 until hour 16, so actually 9:00 - 16:59.

# %%
hourly_sentiment = sentiment_df.groupby(['ticker_symbol', 'date_only_NY', 'hour'])['sentiment_prob_sum'].mean().reset_index()

# %%
hourly_sentiment.head()
# Out:
#   ticker_symbol date_only_NY  hour  sentiment_prob_sum
# 0          AAPL   2015-01-01     9           23.756269
# 1          AAPL   2015-01-01    10           20.132582
# 2          AAPL   2015-01-01    11           19.728412
# 3          AAPL   2015-01-01    12            7.438756
# 4          AAPL   2015-01-01    13            7.803944

# %%
hourly_sentiment_9_16 = hourly_sentiment[(hourly_sentiment['hour']==9)|(hourly_sentiment['hour']==16)]

# %%
hourly_sentiment_9_16[hourly_sentiment_9_16['date_only_NY']=='2015-01-01']
# Out:
#       ticker_symbol date_only_NY  hour  sentiment_prob_sum
# 0              AAPL   2015-01-01     9           23.756269
# 7              AAPL   2015-01-01    16           -0.296172
# 14158          AMZN   2015-01-01     9           -3.927115
# 28172        GOOGLE   2015-01-01    16           13.584372
# 42245          MSFT   2015-01-01     9           28.338205
# 42252          MSFT   2015-01-01    16           18.683730
# 55388          TSLA   2015-01-01     9           -1.903005
# 55395          TSLA   2015-01-01    16           35.396222

# %%
(10.946513-20.420781)/(16-9)
# Out:
# -1.3534668571428574

# %%
# Manual test for first observations
(0.109465-0.204208)/(16-9)
# Out:
# -0.013534714285714285

# %%
import pandas as pd

# Since I cannot directly load the dataframe from a CSV file, I'll simulate the process with dummy data.
# I will write the code assuming the dataframe has been loaded from a CSV file as `df`.

# Sample data structure based on the provided image
# data = {
#     'ticker_symbol': ['AAPL', 'AAPL', 'AAPL', 'AAPL', 'TSLA', 'TSLA', 'TSLA', 'TSLA'],
#     'date_only_NY': ['2015-01-01', '2015-01-01', '2015-01-02', '2015-01-02', '2019-12-30', '2019-12-30', '2019-12-31', '2019-12-31'],
#     'hour': [9, 16, 9, 16, 9, 16, 9, 16],
#     'sentiment_prob_sum': [0.237563, -0.002962, 0.109465, 0.204208, 0.050779, 0.153689, 0.181841, 0.141999]
# }

# # Create a DataFrame
# df = pd.DataFrame(data)

# Function to calculate slope given two points
def calculate_slope(y1, y2, x1=9, x2=16):
    return (y2 - y1) / (x2 - x1)

# Group by 'ticker_symbol' and 'date_only_NY' and calculate the slope for each group
def group_and_calculate_slope(df):
    grouped = df.groupby(['ticker_symbol', 'date_only_NY'])
    slopes = {}
    
    for name, group in grouped:
        if group[group['hour'] == 9]['sentiment_prob_sum'].empty or group[group['hour'] == 16]['sentiment_prob_sum'].empty:
            # If data for both hours is not available, skip this group
            continue
        
        y1 = group[group['hour'] == 9]['sentiment_prob_sum'].values[0]
        y2 = group[group['hour'] == 16]['sentiment_prob_sum'].values[0]
        slope = calculate_slope(y1, y2)
        slopes[name] = slope
    
    # Convert the slopes dictionary to a DataFrame
    slopes_df = pd.DataFrame(list(slopes.items()), columns=['Group', 'slope'])
    # Split 'Group' back into the original columns
    slopes_df[['ticker_symbol', 'date_only_NY']] = pd.DataFrame(slopes_df['Group'].tolist(), index=slopes_df.index)
    # Drop the 'Group' column as it is no longer needed
    slopes_df.drop('Group', axis=1, inplace=True)
    
    return slopes_df

# We will call the function once the user provides their data
# slope_df = group_and_calculate_slope(df)

# For now, just to demonstrate, we will uncomment the above line
# Note: This should only be uncommented when the user's actual data is loaded
slope_df = group_and_calculate_slope(hourly_sentiment_9_16)
slope_df
# Out:
#          slope ticker_symbol date_only_NY
# 0    -3.436063          AAPL   2015-01-01
# 1     1.353467          AAPL   2015-01-02
# 2     1.044999          AAPL   2015-01-03
# 3     1.955365          AAPL   2015-01-04
# 4    -2.148962          AAPL   2015-01-05
# ...        ...           ...          ...
# 8213 -1.508083          TSLA   2019-12-27
# 8214  0.802217          TSLA   2019-12-28
# 8215 -0.509695          TSLA   2019-12-29
# 8216  1.470147          TSLA   2019-12-30
# 8217 -0.569175          TSLA   2019-12-31
#
# [8218 rows x 3 columns]

# %%
sentiment_df
# Out:
#         ticker_symbol company_name             tweet_id           writer  \
# 135              AAPL        apple   550653576716890113  LloydCreekStock
# 136              AAPL        apple   550654457420066818      MacHashNews
# 137              AAPL        apple   550658389122895873         ybfmiami
# 138              TSLA    Tesla Inc   550658779117666304       kirillklip
# 139              TSLA    Tesla Inc   550661171309600768       kirillklip
# ...               ...          ...                  ...              ...
# 2505970          MSFT    Microsoft  1212129352403628039  Realmikerambler
# 2505971          AAPL        apple  1212130278027776000         treabase
# 2505972          AMZN   Amazon.com  1212130355517382656     naashonomics
# 2505973        GOOGLE   Google Inc  1212130411356344321        econalert
# 2505974          TSLA    Tesla Inc  1212131129345499138   jeffreyplarsen
#
#                    date_utc  \
# 135     2015-01-01 14:03:37
# 136     2015-01-01 14:07:07
# 137     2015-01-01 14:22:45
# 138     2015-01-01 14:24:18
# 139     2015-01-01 14:33:48
# ...                     ...
# 2505970 2019-12-31 21:52:12
# 2505971 2019-12-31 21:55:53
# 2505972 2019-12-31 21:56:11
# 2505973 2019-12-31 21:56:25
# 2505974 2019-12-31 21:59:16
#
#                                                       body  comment_num  \
# 135      2015 will be apples year raising price target ...            0
# 136      apple pushes ‘start something new webpage worl...            0
# 137      commented on stocktwits he knows that $aapl ha...            0
# 138      almost 100 electric cars were sold in china in...            0
# 139      how its made dream cars tesla model s url $tsl...            0
# ...                                                    ...          ...
# 2505970  so in the next recession do we just short $aap...            0
# 2505971  $aapl #patent 10523431 secure circuit for encr...            0
# 2505972  $amzn $wmt #reliances #ecommerce venture jioma...            0
# 2505973  $goog #patent 10523916 modifying images with s...            0
# 2505974  $nio is to $tsla as $lk is to $sbux chinese co...            0
#
#          retweet_num  like_num  word_count  ...  cashtag_ratio  hashtag_ratio  \
# 135                0         1          18  ...       0.111111       0.000000
# 136                0         1          13  ...       0.076923       0.076923
# 137                0         1          20  ...       0.050000       0.000000
# 138                1         1          14  ...       0.214286       0.000000
# 139                0         0          13  ...       0.230769       0.000000
# ...              ...       ...         ...  ...            ...            ...
# 2505970            0         0          16  ...       0.125000       0.000000
# 2505971            0         0          13  ...       0.076923       0.307692
# 2505972            0         0          14  ...       0.142857       0.142857
# 2505973            0         0          13  ...       0.076923       0.307692
# 2505974            0         1          28  ...       0.142857       0.000000
#
#          mention_ratio  keyword_count             date_new_york  hour  \
# 135                0.0              0 2015-01-01 09:03:37-05:00     9
# 136                0.0              1 2015-01-01 09:07:07-05:00     9
# 137                0.0              0 2015-01-01 09:22:45-05:00     9
# 138                0.0              0 2015-01-01 09:24:18-05:00     9
# 139                0.0              0 2015-01-01 09:33:48-05:00     9
# ...                ...            ...                       ...   ...
# 2505970            0.0              0 2019-12-31 16:52:12-05:00    16
# 2505971            0.0              0 2019-12-31 16:55:53-05:00    16
# 2505972            0.0              0 2019-12-31 16:56:11-05:00    16
# 2505973            0.0              0 2019-12-31 16:56:25-05:00    16
# 2505974            0.0              0 2019-12-31 16:59:16-05:00    16
#
#          sentiment                              sentiment_probability  \
# 135              1  [0.654727864920058, 0.22675529669355593, 0.118...
# 136              1  [0.4333587103104307, 0.41166565493077784, 0.15...
# 137              0  [0.17909566304603766, 0.5372814214205074, 0.28...
# 138              1  [0.5721005456025544, 0.10387717651417847, 0.32...
# 139              1  [0.4869454321463026, 0.33155936876012554, 0.18...
# ...            ...                                                ...
# 2505970         -1  [0.22384713888315189, 0.37754617384158745, 0.3...
# 2505971          0  [0.4139145115366789, 0.48973383031018114, 0.09...
# 2505972          1  [0.7377469659473392, 0.19575789553706122, 0.06...
# 2505973          1  [0.4652783128990486, 0.4090293363114174, 0.125...
# 2505974          1  [0.5230794192738126, 0.33584787224321705, 0.14...
#
#          sentiment_prob_sum  date_only_NY
# 135               53.621103    2015-01-01
# 136               27.838308    2015-01-01
# 137              -10.452725    2015-01-01
# 138               24.807827    2015-01-01
# 139               30.545023    2015-01-01
# ...                     ...           ...
# 2505970          -17.475955    2019-12-31
# 2505971           31.756285    2019-12-31
# 2505972           67.125183    2019-12-31
# 2505973           33.958596    2019-12-31
# 2505974           38.200671    2019-12-31
#
# [1496915 rows x 23 columns]

# %%
plt.scatter(sentiment_df['date_only_NY'], sentiment_df['sentiment_prob_sum'], alpha=0.005)

# %% [markdown]
# ## Calculate unweighted sentiment score per day
#
# With the information available in our dataset, we can't set the like, comment, or retweet numbers in relation to the number of views of the tweet or the author's number of followers! Therefore, weighting the sentiment scores could falsely skew resulting index!

# %%
unweighted_sentiment_df = sentiment_df.groupby(['date_only_NY', 'ticker_symbol'])['sentiment_prob_sum'].mean().reset_index()
unweighted_sentiment_df.columns = ['date_only_NY', 'ticker_symbol', 'unweighted_sentiment_score']

# %%
unweighted_sentiment_df.head(n=10)
# Out:
#   date_only_NY ticker_symbol  unweighted_sentiment_score
# 0   2015-01-01          AAPL                   14.040915
# 1   2015-01-01          AMZN                   12.546614
# 2   2015-01-01        GOOGLE                   11.686613
# 3   2015-01-01          MSFT                   21.676938
# 4   2015-01-01          TSLA                   10.184191
# 5   2015-01-02          AAPL                   13.353343
# 6   2015-01-02          AMZN                   18.760426
# 7   2015-01-02        GOOGLE                   13.735801
# 8   2015-01-02          MSFT                   15.366015
# 9   2015-01-02          TSLA                    1.912373

# %%
slope_df[slope_df['date_only_NY']=='2015-01-01']
# Out:
#          slope ticker_symbol date_only_NY
# 0    -3.436063          AAPL   2015-01-01
# 5069 -1.379211          MSFT   2015-01-01
# 6518  5.328461          TSLA   2015-01-01

# %% [markdown]
# ## Merge sentiment score with slope data

# %%
sentiment_slope_df = pd.merge(unweighted_sentiment_df, slope_df, on=['date_only_NY', 'ticker_symbol'])

# %%
sentiment_slope_df
# Out:
#      date_only_NY ticker_symbol  unweighted_sentiment_score     slope
# 0      2015-01-01          AAPL                   14.040915 -3.436063
# 1      2015-01-01          MSFT                   21.676938 -1.379211
# 2      2015-01-01          TSLA                   10.184191  5.328461
# 3      2015-01-02          AAPL                   13.353343  1.353467
# 4      2015-01-02          AMZN                   18.760426 -2.150535
# ...           ...           ...                         ...       ...
# 8213   2019-12-31          AAPL                   25.756553  0.002828
# 8214   2019-12-31          AMZN                   23.841670  0.774379
# 8215   2019-12-31        GOOGLE                   19.178219 -7.318812
# 8216   2019-12-31          MSFT                   29.640249  0.854491
# 8217   2019-12-31          TSLA                   16.814354 -0.569175
#
# [8218 rows x 4 columns]

# %% [markdown]
# # Load market cap data

# %%
companies
# Out:
# array(['AAPL', 'AMZN', 'GOOGLE', 'MSFT', 'TSLA'], dtype=object)

# %%
# Load market cap file

market_cap_path = "https://raw.githubusercontent.com/inga-maria01/master_thesis/main/data/market_cap/total_market_cap_2015-2019.xlsx"

market_cap_df = pd.read_excel(market_cap_path).sort_values("date").reset_index(drop=True)

market_cap_df['date'] = pd.to_datetime(market_cap_df['date'])

market_cap_df['weights_abs'] = market_cap_df['weights_abs'].astype(int)

market_cap_df['weights_rel'] = market_cap_df.groupby('date')['weights_abs'].transform(lambda x: x / x.sum())

# replace company ticker by company name for a smooth join

replacements = {"AAPL.O": "AAPL", "AMZN.O": "AMZN", "GOOG.O": "GOOGLE", "MSFT.O": "MSFT", "TSLA.O": "TSLA"}

market_cap_df['company_ticker'] = market_cap_df['company_ticker'].replace(replacements)

market_cap_df.rename(columns={'company_ticker': 'ticker_symbol'}, inplace=True)

# %%
market_cap_df.head(n=10)
# Out:
#   ticker_symbol       date  weekday    market_cap   weights_abs  weights_rel
# 0          AAPL 2015-01-02        4  6.412030e+11  697510000000     0.422972
# 1          TSLA 2015-01-02        4  2.749748e+10   30660000000     0.018592
# 2        GOOGLE 2015-01-02        4  3.576201e+11  370020000000     0.224381
# 3          MSFT 2015-01-02        4  3.854358e+11  394090000000     0.238977
# 4          AMZN 2015-01-02        4  1.434618e+11  156790000000     0.095078
# 5        GOOGLE 2015-01-05        0  3.504869e+11  370020000000     0.224381
# 6          AMZN 2015-01-05        0  1.405184e+11  156790000000     0.095078
# 7          TSLA 2015-01-05        0  2.634146e+10   30660000000     0.018592
# 8          AAPL 2015-01-05        0  6.231392e+11  697510000000     0.422972
# 9          MSFT 2015-01-05        0  3.818502e+11  394090000000     0.238977

# %%
# Fill in values for non-workdays

import pandas as pd
import numpy as np

# # Example DataFrame creation
# data = {
#     'company_name': ['Company A', 'Company A', 'Company B', 'Company B'],
#     'date': ['2015-01-01', '2015-01-02', '2015-01-01', '2015-01-02'],
#     'weekday': ['Thursday', 'Friday', 'Thursday', 'Friday'],
#     'market_cap': [100, 105, 200, 210],
#     'weights_abs': [10, 10.5, 20, 21],
#     'weights_rel': [0.1, 0.105, 0.2, 0.21]
# }

# # Create DataFrame
# df = pd.DataFrame(data)

# Convert 'date' column to datetime
market_cap_df['date'] = pd.to_datetime(market_cap_df['date'])

# Create copy to not overwrite market_cap_df
market_cap_copy = market_cap_df.copy()

# Set the 'date' as index
market_cap_copy.set_index('date', inplace=True)

# Creating a full date range from 2015-01-01 to 2015-01-04 (for this example)
all_dates = pd.date_range(start='2015-01-01', end='2019-12-31')

# Reindexing DataFrame to the new date range for each company
market_cap_full_df = market_cap_copy.groupby('ticker_symbol').apply(lambda x: x.reindex(all_dates).ffill()).reset_index(level=0, drop=True)

# Fix the 'weekday' column to reflect the correct day of the week
market_cap_full_df['weekday'] = market_cap_full_df.index.day_name()

# Reset the index to convert 'date' from index to a regular column and reindex with default integer indexing
market_cap_full_df = market_cap_full_df.reset_index().rename(columns={'index': 'date'})

# %%
# Fill 2015-01-01 with values from 2015-01-02
jan_01_2015_data = np.array(market_cap_full_df[market_cap_full_df['date']=="2015-01-01"].index)

# %%
for idx in jan_01_2015_data:
    market_cap_full_df.loc[idx, 'ticker_symbol'] = market_cap_full_df.loc[idx+1, 'ticker_symbol']
    market_cap_full_df.loc[idx, 'market_cap'] = market_cap_full_df.loc[idx+1, 'market_cap']
    market_cap_full_df.loc[idx, 'weights_abs'] = market_cap_full_df.loc[idx+1, 'weights_abs']
    market_cap_full_df.loc[idx, 'weights_rel'] = market_cap_full_df.loc[idx+1, 'weights_rel']

# %%
market_cap_full_df[(market_cap_full_df['date']=="2015-01-01") | (market_cap_full_df['date']=="2015-01-02")]
# Out:
#            date ticker_symbol   weekday    market_cap   weights_abs  \
# 0    2015-01-01          AAPL  Thursday  6.412030e+11  6.975100e+11
# 1    2015-01-02          AAPL    Friday  6.412030e+11  6.975100e+11
# 1826 2015-01-01          AMZN  Thursday  1.434618e+11  1.567900e+11
# 1827 2015-01-02          AMZN    Friday  1.434618e+11  1.567900e+11
# 3652 2015-01-01        GOOGLE  Thursday  3.576201e+11  3.700200e+11
# 3653 2015-01-02        GOOGLE    Friday  3.576201e+11  3.700200e+11
# 5478 2015-01-01          MSFT  Thursday  3.854358e+11  3.940900e+11
# 5479 2015-01-02          MSFT    Friday  3.854358e+11  3.940900e+11
# 7304 2015-01-01          TSLA  Thursday  2.749748e+10  3.066000e+10
# 7305 2015-01-02          TSLA    Friday  2.749748e+10  3.066000e+10
#
#       weights_rel
# 0        0.422972
# 1        0.422972
# 1826     0.095078
# 1827     0.095078
# 3652     0.224381
# 3653     0.224381
# 5478     0.238977
# 5479     0.238977
# 7304     0.018592
# 7305     0.018592

# %%
market_cap_full_sorted_df = market_cap_full_df.sort_values(by='date').reset_index(drop=True)
market_cap_full_sorted_df.head(n=10)
# Out:
#         date ticker_symbol   weekday    market_cap   weights_abs  weights_rel
# 0 2015-01-01          AAPL  Thursday  6.412030e+11  6.975100e+11     0.422972
# 1 2015-01-01          TSLA  Thursday  2.749748e+10  3.066000e+10     0.018592
# 2 2015-01-01          AMZN  Thursday  1.434618e+11  1.567900e+11     0.095078
# 3 2015-01-01        GOOGLE  Thursday  3.576201e+11  3.700200e+11     0.224381
# 4 2015-01-01          MSFT  Thursday  3.854358e+11  3.940900e+11     0.238977
# 5 2015-01-02          AAPL    Friday  6.412030e+11  6.975100e+11     0.422972
# 6 2015-01-02          TSLA    Friday  2.749748e+10  3.066000e+10     0.018592
# 7 2015-01-02          AMZN    Friday  1.434618e+11  1.567900e+11     0.095078
# 8 2015-01-02        GOOGLE    Friday  3.576201e+11  3.700200e+11     0.224381
# 9 2015-01-02          MSFT    Friday  3.854358e+11  3.940900e+11     0.238977

# %%
sentiment_slope_df
# Out:
#            date ticker_symbol  unweighted_sentiment_score     slope
# 0    2015-01-01          AAPL                   14.040915 -3.436063
# 1    2015-01-01          MSFT                   21.676938 -1.379211
# 2    2015-01-01          TSLA                   10.184191  5.328461
# 3    2015-01-02          AAPL                   13.353343  1.353467
# 4    2015-01-02          AMZN                   18.760426 -2.150535
# ...         ...           ...                         ...       ...
# 8213 2019-12-31          AAPL                   25.756553  0.002828
# 8214 2019-12-31          AMZN                   23.841670  0.774379
# 8215 2019-12-31        GOOGLE                   19.178219 -7.318812
# 8216 2019-12-31          MSFT                   29.640249  0.854491
# 8217 2019-12-31          TSLA                   16.814354 -0.569175
#
# [8218 rows x 4 columns]

# %%
# before joining, adapt column names of sentiment_slope_df
sentiment_slope_df.rename(columns={'date_only_NY': 'date'}, inplace=True)
sentiment_slope_df['date'] = pd.to_datetime(sentiment_slope_df['date'])

# join market_cap_full_sorted_df and unweighted_sentiment_df
unweighted_sentiment_market_cap_df = pd.merge(market_cap_full_sorted_df, sentiment_slope_df, on=['date', 'ticker_symbol'])

# %%
unweighted_sentiment_market_cap_df.head(n=10)
# Out:
#         date ticker_symbol   weekday    market_cap   weights_abs  weights_rel  \
# 0 2015-01-01          AAPL  Thursday  6.412030e+11  6.975100e+11     0.422972
# 1 2015-01-01          TSLA  Thursday  2.749748e+10  3.066000e+10     0.018592
# 2 2015-01-01          MSFT  Thursday  3.854358e+11  3.940900e+11     0.238977
# 3 2015-01-02          AAPL    Friday  6.412030e+11  6.975100e+11     0.422972
# 4 2015-01-02          AMZN    Friday  1.434618e+11  1.567900e+11     0.095078
# 5 2015-01-02        GOOGLE    Friday  3.576201e+11  3.700200e+11     0.224381
# 6 2015-01-02          MSFT    Friday  3.854358e+11  3.940900e+11     0.238977
# 7 2015-01-03          TSLA  Saturday  2.749748e+10  3.066000e+10     0.018592
# 8 2015-01-03        GOOGLE  Saturday  3.576201e+11  3.700200e+11     0.224381
# 9 2015-01-03          AAPL  Saturday  6.412030e+11  6.975100e+11     0.422972
#
#    unweighted_sentiment_score     slope
# 0                   14.040915 -3.436063
# 1                   10.184191  5.328461
# 2                   21.676938 -1.379211
# 3                   13.353343  1.353467
# 4                   18.760426 -2.150535
# 5                   13.735801 -0.194901
# 6                   15.366015 -1.888971
# 7                   22.929154  1.793392
# 8                   28.069392  4.428656
# 9                   20.595774  1.044999

# %%
# Calculate the weighted average of sentiment per day
sentiment_index_unweighted_df = unweighted_sentiment_market_cap_df.groupby('date').apply(
    lambda x: pd.Series({
        'sentiment_score': (x['weights_rel'] * x['unweighted_sentiment_score']).sum(),
        'sentiment_slope': (x['weights_rel'] * x['slope']).sum()
        })
).reset_index()

# Moving average sentiment (now calculated in model file)
# sentiment_index_unweighted_df['moving_average'] = sentiment_index_unweighted_df['sentiment_score'].rolling(window=30).mean()

# %%
sentiment_index_unweighted_df.head(n=10)
# Out:
#         date  sentiment_score  sentiment_slope
# 0 2015-01-02        14.185966        -0.127143
# 1 2015-01-05        18.631666        -1.688521
# 2 2015-01-06        10.882382         0.484480
# 3 2015-01-07        17.620721        -1.852799
# 4 2015-01-08        15.960441         0.916068
# 5 2015-01-09        20.128338        -2.596250
# 6 2015-01-12        12.308471         0.376702
# 7 2015-01-13        20.185215        -1.680963
# 8 2015-01-14        18.683842        -1.579964
# 9 2015-01-15        17.783641         0.454067

# %%
plt.figure(figsize=(20,5))
plt.subplot(1, 2, 1)
plt.plot(sentiment_index_unweighted_df['date'],sentiment_index_unweighted_df['sentiment_score'])
plt.title('sentiment_index_unweighted_df')
plt.subplot(1, 2, 2)
plt.plot(sentiment_index_unweighted_df['date'],sentiment_index_unweighted_df['sentiment_slope'])
plt.title('sentiment_index_unweighted_df slope')
plt.show()

# %% [markdown]
# ## Save index to xlsx file

# %%
# Save index to xlsx
sentiment_index_unweighted_path = "Users/friederikeeichholz/Library/CloudStorage/OneDrive-LundUniversity/Desktop/DABN01_Thesis/index/sentiment_index_unweighted_v5.xlsx"

sentiment_index_unweighted_df.to_excel(sentiment_index_unweighted_path, index=False)
