# %%
import pandas as pd
import requests
from io import BytesIO
from typing import List

def load_and_merge_csv_xz_from_github(years: List[int], companies: List[str], base_url: str) -> pd.DataFrame:
    all_dataframes = []
    
    for year in years:
        for company in companies:
            filename = f"df_{year}_{company}.csv.xz"
            file_url = f"{base_url}/{filename}"
            
            response = requests.get(file_url)
            if response.status_code == 200:
                file_content = BytesIO(response.content)
                df = pd.read_csv(file_content, compression='xz')
                all_dataframes.append(df)

    merged_dataframe = pd.concat(all_dataframes, ignore_index=True)

    # Sort dataframe by date
    df_sorted = merged_dataframe.sort_values(by='post_date')

    # Remove the 'Unnamed: 0' column
    df_sorted = df_sorted.drop(columns=['Unnamed: 0'])
    
    # Drop 'year' columns that was used previously to split dataframes and save them as smaller csv files 
    df_sorted = df_sorted.drop(columns=['year'])


    # Reset the index of the dataframe and drop the old one
    df_sorted = df_sorted.reset_index(drop=True)

    return df_sorted

    
base_url = "https://raw.githubusercontent.com/inga-maria01/master_thesis/main/data"
years = [2015, 2016, 2017, 2018, 2019]
companies = ['AAPL', 'AMZN', 'GOOGL', 'TSLA', 'GOOG', 'MSFT']
tweets_df = load_and_merge_csv_xz_from_github(years, companies, base_url)

# %%
tweets_df.dtypes
# Out:
# ticker_symbol    object
# company_name     object
# tweet_id          int64
# writer           object
# post_date        object
# body             object
# comment_num       int64
# retweet_num       int64
# like_num          int64
# dtype: object

# %%
tweets_df.head()
# Out:
#   ticker_symbol company_name            tweet_id           writer  \
# 0          AAPL        apple  550441509175443456  VisualStockRSRC
# 1          AAPL        apple  550441672312512512      KeralaGuy77
# 2          AMZN   Amazon.com  550441732014223360      DozenStocks
# 3          TSLA    Tesla Inc  550442977802207232     ShowDreamCar
# 4          TSLA    Tesla Inc  550443808606126081    aaplstocknews
#
#              post_date                                               body  \
# 0  2015-01-01 00:00:57  lx21 made $10,008  on $AAPL -Check it out! htt...
# 1  2015-01-01 00:01:36  Insanity of today weirdo massive selling. $aap...
# 2  2015-01-01 00:01:50  S&P100 #Stocks Performance $HD $LOW $SBUX $TGT...
# 3  2015-01-01 00:06:47  $GM $TSLA: Volkswagen Pushes 2014 Record Recal...
# 4  2015-01-01 00:10:05  Swing Trading: Up To 8.91% Return In 14 Days h...
#
#    comment_num  retweet_num  like_num
# 0            0            0         1
# 1            0            0         0
# 2            0            0         0
# 3            0            0         1
# 4            0            0         1

# %%
# number of unique tweets
len(tweets_df['body'].unique())
# Out:
# 3326194

# %%
import pandas as pd
import re

def filter_tweets(df):
    df = df.copy()

    print("Initial dataset length:", len(df))

    # Normalize URLs in the tweet bodies - replace with "URL" or remove
    df['body'] = df['body'].apply(lambda text: re.sub(r'http\S+', 'URL', text))

    # Remove all duplicates based on 'tweet_id' and 'ticker_symbol' (possibly collection errors)
    df.drop_duplicates(subset=['tweet_id', 'ticker_symbol'], inplace=True, keep = 'first')
    print("After removing duplicate tweet_ids and ticker_symbols:", len(df))

    # Remove last duplicates based on 'tweet_id' and 'company_name'(will only apply to Google as they have different ticker_symbols)
    df.drop_duplicates(subset=['tweet_id', 'company_name'], inplace=True, keep = 'first')
    print("After removing duplicate tweet_ids and company_names (Google):", len(df))

    # Introduce new common ticker symbol for google
    df['ticker_symbol'] = df['ticker_symbol'].replace({'GOOG': 'GOOGLE', 'GOOGL': 'GOOGLE'})

    # Remove tweets with duplicate texts longer than 5 words considering the ticker symbol
    df['word_count'] = df['body'].apply(lambda text: len(text.split()))
    duplicates = df[(df['word_count'] > 5)].duplicated(subset=['body', 'ticker_symbol'], keep=False)
    df = df.loc[~df.index.isin(duplicates[duplicates].index)]
    print("After removing tweets duplicate texts longer than 5 words:", len(df))

    # Apply counting functions
    df['hashtag_count'] = df['body'].apply(lambda text: sum(1 for word in text.split() if word.startswith('#')))
    df['cashtag_count'] = df['body'].apply(lambda text: sum(1 for word in text.split() if word.startswith('$')))
    df['mention_count'] = df['body'].apply(lambda text: sum(1 for word in text.split() if word.startswith('@')))

    # Filter tweets based on hashtag and cashtag counts
    df = df[(df['cashtag_count'] < 5) & (df['hashtag_count'] < 8)]
    print("After filtering by cashtags and hashtags:", len(df))

    # Ratio filters (cashtags, hashtags, mentions to words)
    df['cashtag_ratio'] = df['cashtag_count'] / df['word_count'].replace(0, 1)
    df['hashtag_ratio'] = df['hashtag_count'] / df['word_count'].replace(0, 1)
    df['mention_ratio'] = df['mention_count'] / df['word_count'].replace(0, 1)
    df = df[(df['cashtag_ratio'] <= 0.5) & (df['hashtag_ratio'] <= 0.5) & (df['mention_ratio'] <= 0.5)]
    print("After filtering by ratios:", len(df))

    # Keyword filter (defined by Wilksch, Abramova (2023) PyFin-sentiment: Towards a machine-learning-based model for deriving sentiment from financial tweets)
    keywords = ['bitcoin', 'etherium', 'btc', 'eth', 'nft', 'token', 'wallet', 'web3',
                'airdrop', 'wagmi', 'solana', 'opensea', 'cryptopunks', 'uniswap', 
                'lunar', 'hodl', 'binance', 'coinbase', 'cryptocom', 'doge']
    df['keyword_count'] = df['body'].apply(lambda text: sum(text.lower().count(kw) for kw in keywords))
    df = df[df['keyword_count'] <= 2]
    print("After filtering by keyword count:", len(df))

    df = df.reset_index(drop=True)

    return df

# %%
filtered_df = filter_tweets(tweets_df)
# Out:
# Initial dataset length: 4336445
# After removing duplicate tweet_ids and ticker_symbols: 4336445
# After removing duplicate tweet_ids and company_names (Google): 4288706
# After removing tweets duplicate texts longer than 5 words: 3192655
# After filtering by cashtags and hashtags: 2526934
# After filtering by ratios: 2506779
# After filtering by keyword count: 2506058

# %%
# number of unique tweets
len(filtered_df['body'].unique())
# Out:
# 2380386

# %%
import pandas as pd

def check_empty_bodies(df):
    # Check for empty or NaN entries in the 'body' column
    empty_bodies = df['body'].isna() | (df['body'] == '')
    
    # Count the number of empty or NaN entries
    empty_count = empty_bodies.sum()
    
    # Print the results
    if empty_count > 0:
        print(f"There are {empty_count} empty 'body' cells in the DataFrame.")
    else:
        print("There are no empty 'body' cells in the DataFrame.")

    # Optionally, you might want to return a DataFrame with the empty entries for review
    empty_entries = df[empty_bodies]
    return empty_entries

# %%
# Check processed data frame for missing text values
empty_entries = check_empty_bodies(filtered_df)
if not empty_entries.empty:
    print("Empty entries found:", empty_entries)
# Out:
# There are no empty 'body' cells in the DataFrame.

# %%
import datetime
import pytz

# convert post_date back to int64

# convert from object to datetime
filtered_df['post_date'] = pd.to_datetime(filtered_df['post_date'])

# convert to int64
filtered_df['date_int'] = filtered_df['post_date'].apply(lambda x: int(x.timestamp()))

def convert_utc_to_ny(timestamp):
    # Define the UTC timezone
    utc_timezone = pytz.timezone('UTC')
    
    # Define the New York timezone
    ny_timezone = pytz.timezone('America/New_York')
    
    # Create a timezone-aware datetime object in UTC directly from the Unix timestamp
    utc_aware_datetime = datetime.datetime.fromtimestamp(timestamp, utc_timezone)
    
    # Convert the datetime object from UTC to New York Time
    ny_datetime = utc_aware_datetime.astimezone(ny_timezone)

    # # Format New York datetime to a string without timezone information
    # formatted_new_york_datetime = new_york_datetime.strftime('%Y-%m-%d %H:%M:%S')
    
    # return formatted_new_york_datetime
    
    return ny_datetime

# Example usage
# timestamp = 1420070457
# print(convert_utc_to_ny(timestamp))

# The example usage is commented out to adhere to instructions of not executing the code here.

# %%
filtered_df['date_new_york'] = filtered_df['date_int'].apply(convert_utc_to_ny)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame and it contains a 'date_new_york' column

# Extracting the hour from 'date_new_york' and creating a new column 'hour'
filtered_df['hour'] = filtered_df['date_new_york'].dt.hour

# Group by the new 'hour' column and calculate the mean number of tweets per hour
# average_tweets_per_hour = filtered_df.groupby('hour').count().mean()

filtered_df.groupby('hour').size().plot(kind='bar')
# Out:
# <Axes: xlabel='hour'>

# %%
filtered_df = filtered_df.rename(columns={'post_date': 'date_utc'}).drop(columns=['date_int'])

# %%
filtered_df.describe()
# Out:
#            tweet_id                       date_utc   comment_num  \
# count  2.506058e+06                        2506058  2.506058e+06
# mean   8.943899e+17  2017-08-07 02:48:55.654100224  4.128659e-01
# min    5.504417e+17            2015-01-01 00:01:36  0.000000e+00
# 25%    7.199259e+17  2016-04-12 16:31:26.750000128  0.000000e+00
# 50%    9.076666e+17     2017-09-12 18:05:51.500000  0.000000e+00
# 75%    1.067321e+18            2018-11-27 07:33:41  0.000000e+00
# max    1.212160e+18            2019-12-31 23:55:53  5.630000e+02
# std    1.962730e+17                            NaN  2.034381e+00
#
#         retweet_num      like_num    word_count  hashtag_count  cashtag_count  \
# count  2.506058e+06  2.506058e+06  2.506058e+06   2.506058e+06   2.506058e+06
# mean   6.590410e-01  2.803712e+00  1.737428e+01   5.478301e-01   1.611388e+00
# min    0.000000e+00  0.000000e+00  1.000000e+00   0.000000e+00   0.000000e+00
# 25%    0.000000e+00  0.000000e+00  1.100000e+01   0.000000e+00   1.000000e+00
# 50%    0.000000e+00  0.000000e+00  1.500000e+01   0.000000e+00   1.000000e+00
# 75%    0.000000e+00  1.000000e+00  2.100000e+01   1.000000e+00   2.000000e+00
# max    9.990000e+02  9.990000e+02  6.800000e+01   7.000000e+00   4.000000e+00
# std    6.281905e+00  1.570587e+01  1.002514e+01   1.100227e+00   9.699733e-01
#
#        mention_count  cashtag_ratio  hashtag_ratio  mention_ratio  \
# count   2.506058e+06   2.506058e+06   2.506058e+06   2.506058e+06
# mean    2.072131e-01   1.192850e-01   3.754889e-02   1.248654e-02
# min     0.000000e+00   0.000000e+00   0.000000e+00   0.000000e+00
# 25%     0.000000e+00   5.882353e-02   0.000000e+00   0.000000e+00
# 50%     0.000000e+00   9.090909e-02   0.000000e+00   0.000000e+00
# 75%     0.000000e+00   1.666667e-01   5.263158e-02   0.000000e+00
# max     1.600000e+01   5.000000e-01   5.000000e-01   5.000000e-01
# std     6.143123e-01   8.916754e-02   7.723931e-02   3.829380e-02
#
#        keyword_count          hour
# count   2.506058e+06  2.506058e+06
# mean    1.880004e-02  1.248325e+01
# min     0.000000e+00  0.000000e+00
# 25%     0.000000e+00  9.000000e+00
# 50%     0.000000e+00  1.200000e+01
# 75%     0.000000e+00  1.600000e+01
# max     2.000000e+00  2.300000e+01
# std     1.436263e-01  5.095320e+00

# %%
# check if data set contains emojis

# pip install emoji
import emoji

def contains_emoji(text):
    return emoji.emoji_count(text) > 0


filtered_df['has_emoji'] = filtered_df['body'].apply(contains_emoji)

any_emojis = filtered_df['has_emoji'].any()
print("Is there at least one emoji in the text body column?", any_emojis)
# Out:
# Is there at least one emoji in the text body column? True

# %%
import re
import emoji

def preprocess_text_column(df):
    df = df.copy()  # Create a copy to avoid modifying the original DataFrame

    # Escape regex special characters and join them to form a regex pattern
    punctuation_marks = [',', '.', '?', '!', '*', ':', ';', '”', 
                         '“', '"', "’", "’", "%", "&", "'", "(",
                         ")", "-", '``', "''"]
    escaped_punctuation = [re.escape(char) for char in punctuation_marks]
    punctuation_pattern = f"[{''.join(escaped_punctuation)}]"

    def transform_text(text):
        # Replace emojis with a space
        text = emoji.replace_emoji(text, replace=' ')
        
        # Convert to lowercase
        text = text.lower()

        # Replace newlines with spaces
        text = text.replace('\n', ' ')

        # Remove repeated characters more than twice
        text = re.sub(r'(.)\1{2,}', r'\1', text)
        
        # Remove specific punctuation
        text = re.sub(punctuation_pattern, '', text)

        # Strip and replace multiple spaces with a single space
        text = re.sub(r'\s+', ' ', text).strip()
        
        return text

    # Apply the transformation to the 'body' column
    df['body'] = df['body'].apply(transform_text)
    
    return df

# Example usage:
# import pandas as pd
# df = pd.DataFrame({'body': ['Long money game. ♟                            We hope Jackboys has some Tesla stocks since their adding hype to $TSLA brand.']})
# print(preprocess_text_column(df))

# %%
# Preprocess text column
preprocessed_df = preprocess_text_column(filtered_df)

# %%
preprocessed_df['has_emoji_pp'] = preprocessed_df['body'].apply(contains_emoji)

any_emojis_pp = preprocessed_df['has_emoji_pp'].any()
print("Is there at least one emoji in the text body column?", any_emojis_pp)
# Out:
# Is there at least one emoji in the text body column? False

# %%
preprocessed_df = preprocessed_df.drop(columns=['has_emoji', 'has_emoji_pp'])

# %%
preprocessed_df.head()
# Out:
#   ticker_symbol company_name            tweet_id         writer  \
# 0          AAPL        apple  550441672312512512    KeralaGuy77
# 1          TSLA    Tesla Inc  550442977802207232   ShowDreamCar
# 2          AAPL        apple  550444969924653056  AppleNewsAAPL
# 3          AAPL        apple  550444970738335744   espositooooo
# 4          AAPL        apple  550445066444369921     Bidnessetc
#
#              date_utc                                               body  \
# 0 2015-01-01 00:01:36  insanity of today weirdo massive selling $aapl...
# 1 2015-01-01 00:06:47  $gm $tsla volkswagen pushes 2014 record recall...
# 2 2015-01-01 00:14:42  $aapl apple goes global with start something n...
# 3 2015-01-01 00:14:42  @wsj apple is being sued for falsely advertisi...
# 4 2015-01-01 00:15:05  apple filed for its own stylus patent in 2010 ...
#
#    comment_num  retweet_num  like_num  word_count  hashtag_count  \
# 0            0            0         0          20              0
# 1            0            0         1          13              0
# 2            0            0         1          12              0
# 3            0            0         0          15              0
# 4            0            0         0          11              0
#
#    cashtag_count  mention_count  cashtag_ratio  hashtag_ratio  mention_ratio  \
# 0              1              0       0.050000            0.0       0.000000
# 1              2              2       0.153846            0.0       0.153846
# 2              1              1       0.083333            0.0       0.083333
# 3              1              0       0.066667            0.0       0.000000
# 4              1              0       0.090909            0.0       0.000000
#
#    keyword_count             date_new_york  hour
# 0              0 2014-12-31 19:01:36-05:00    19
# 1              0 2014-12-31 19:06:47-05:00    19
# 2              1 2014-12-31 19:14:42-05:00    19
# 3              0 2014-12-31 19:14:42-05:00    19
# 4              0 2014-12-31 19:15:05-05:00    19

# %%
from pyfin_sentiment.model import SentimentModel
import numpy as np
import pandas as pd  # Ensure pandas is imported if not already

# Initialize the sentiment model
model = SentimentModel("small")

def apply_batch_sentiment(texts, batch_size=1000):
    # Initialize lists to store sentiment results and probabilities
    sentiments = []
    probabilities = []
    
    # Process texts in batches
    total_texts = len(texts)
    for i in range(0, total_texts, batch_size):
        batch_texts = texts[i:i + batch_size]
        
        # Get predictions and probabilities
        batch_predictions = model.predict(batch_texts)
        batch_probabilities = model.predict_proba(batch_texts)
        
        sentiments.extend(batch_predictions)
        probabilities.extend(batch_probabilities)
        
        # Print progress
        processed = min(i + batch_size, total_texts)
        print(f"Processed {processed}/{total_texts} texts")
    
    return sentiments, probabilities
# Out:
# /Users/friederikeeichholz/anaconda3/lib/python3.11/site-packages/sklearn/base.py:347: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.1.1 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/friederikeeichholz/anaconda3/lib/python3.11/site-packages/sklearn/base.py:347: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.1.1 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/friederikeeichholz/anaconda3/lib/python3.11/site-packages/sklearn/base.py:347: InconsistentVersionWarning: Trying to unpickle estimator LogisticRegression from version 1.1.1 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/friederikeeichholz/anaconda3/lib/python3.11/site-packages/sklearn/base.py:347: InconsistentVersionWarning: Trying to unpickle estimator Pipeline from version 1.1.1 when using version 1.3.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# Apply sentiment analysis in batches to the 'body' column
sentiment_df = preprocessed_df.copy()

results = apply_batch_sentiment(sentiment_df['body'].tolist(), batch_size=1000)
sentiment_df['sentiment'] = results[0]
sentiment_df['sentiment_probability'] = results[1]
# Out:
# Processed 1000/2506058 texts
# Processed 2000/2506058 texts
# Processed 3000/2506058 texts
# Processed 4000/2506058 texts
# Processed 5000/2506058 texts
# Processed 6000/2506058 texts
# Processed 7000/2506058 texts
# Processed 8000/2506058 texts
# Processed 9000/2506058 texts
# Processed 10000/2506058 texts
# Processed 11000/2506058 texts
# Processed 12000/2506058 texts
# Processed 13000/2506058 texts
# Processed 14000/2506058 texts
# Processed 15000/2506058 texts
# Processed 16000/2506058 texts
# Processed 17000/2506058 texts
# Processed 18000/2506058 texts
# Processed 19000/2506058 texts
# Processed 20000/2506058 texts
# Processed 21000/2506058 texts
# Processed 22000/2506058 texts
# Processed 23000/2506058 texts
# Processed 24000/2506058 texts
# Processed 25000/2506058 texts
# Processed 26000/2506058 texts
# Processed 27000/2506058 texts
# Processed 28000/2506058 texts
# Processed 29000/2506058 texts
# Processed 30000/2506058 texts
# Processed 31000/2506058 texts
# Processed 32000/2506058 texts
# Processed 33000/2506058 texts
# Processed 34000/2506058 texts
# Processed 35000/2506058 texts
# Processed 36000/2506058 texts
# Processed 37000/2506058 texts
# Processed 38000/2506058 texts
# Processed 39000/2506058 texts
# Processed 40000/2506058 texts
# Processed 41000/2506058 texts
# Processed 42000/2506058 texts
# Processed 43000/2506058 texts
# Processed 44000/2506058 texts
# Processed 45000/2506058 texts
# Processed 46000/2506058 texts
# Processed 47000/2506058 texts
# Processed 48000/2506058 texts
# Processed 49000/2506058 texts
# Processed 50000/2506058 texts
# Processed 51000/2506058 texts
# Processed 52000/2506058 texts
# Processed 53000/2506058 texts
# Processed 54000/2506058 texts
# Processed 55000/2506058 texts
# Processed 56000/2506058 texts
# Processed 57000/2506058 texts
# Processed 58000/2506058 texts
# Processed 59000/2506058 texts
# Processed 60000/2506058 texts
# Processed 61000/2506058 texts
# Processed 62000/2506058 texts
# Processed 63000/2506058 texts
# Processed 64000/2506058 texts
# Processed 65000/2506058 texts
# Processed 66000/2506058 texts
# Processed 67000/2506058 texts
# Processed 68000/2506058 texts
# Processed 69000/2506058 texts
# Processed 70000/2506058 texts
# Processed 71000/2506058 texts
# Processed 72000/2506058 texts
# Processed 73000/2506058 texts
# Processed 74000/2506058 texts
# Processed 75000/2506058 texts
# Processed 76000/2506058 texts
# Processed 77000/2506058 texts
# Processed 78000/2506058 texts
# Processed 79000/2506058 texts
# Processed 80000/2506058 texts
# Processed 81000/2506058 texts
# Processed 82000/2506058 texts
# Processed 83000/2506058 texts
# Processed 84000/2506058 texts
# Processed 85000/2506058 texts
# Processed 86000/2506058 texts
# Processed 87000/2506058 texts
# Processed 88000/2506058 texts
# Processed 89000/2506058 texts
# Processed 90000/2506058 texts
# Processed 91000/2506058 texts
# Processed 92000/2506058 texts
# Processed 93000/2506058 texts
# Processed 94000/2506058 texts
# Processed 95000/2506058 texts
# Processed 96000/2506058 texts
# Processed 97000/2506058 texts
# Processed 98000/2506058 texts
# Processed 99000/2506058 texts
# Processed 100000/2506058 texts
# Processed 101000/2506058 texts
# Processed 102000/2506058 texts
# Processed 103000/2506058 texts
# Processed 104000/2506058 texts
# Processed 105000/2506058 texts
# Processed 106000/2506058 texts
# Processed 107000/2506058 texts
# Processed 108000/2506058 texts
# Processed 109000/2506058 texts
# Processed 110000/2506058 texts
# Processed 111000/2506058 texts
# Processed 112000/2506058 texts
# Processed 113000/2506058 texts
# Processed 114000/2506058 texts
# Processed 115000/2506058 texts
# Processed 116000/2506058 texts
# Processed 117000/2506058 texts
# Processed 118000/2506058 texts
# Processed 119000/2506058 texts
# Processed 120000/2506058 texts
# Processed 121000/2506058 texts
# Processed 122000/2506058 texts
# Processed 123000/2506058 texts
# Processed 124000/2506058 texts
# Processed 125000/2506058 texts
# Processed 126000/2506058 texts
# Processed 127000/2506058 texts
# Processed 128000/2506058 texts
# Processed 129000/2506058 texts
# Processed 130000/2506058 texts
# Processed 131000/2506058 texts
# Processed 132000/2506058 texts
# Processed 133000/2506058 texts
# Processed 134000/2506058 texts
# Processed 135000/2506058 texts
# Processed 136000/2506058 texts
# Processed 137000/2506058 texts
# Processed 138000/2506058 texts
# Processed 139000/2506058 texts
# Processed 140000/2506058 texts
# Processed 141000/2506058 texts
# Processed 142000/2506058 texts
# Processed 143000/2506058 texts
# Processed 144000/2506058 texts
# Processed 145000/2506058 texts
# Processed 146000/2506058 texts
# Processed 147000/2506058 texts
# Processed 148000/2506058 texts
# Processed 149000/2506058 texts
# Processed 150000/2506058 texts
# Processed 151000/2506058 texts
# Processed 152000/2506058 texts
# Processed 153000/2506058 texts
# Processed 154000/2506058 texts
# Processed 155000/2506058 texts
# Processed 156000/2506058 texts
# Processed 157000/2506058 texts
# Processed 158000/2506058 texts
# Processed 159000/2506058 texts
# Processed 160000/2506058 texts
# Processed 161000/2506058 texts
# Processed 162000/2506058 texts
# Processed 163000/2506058 texts
# Processed 164000/2506058 texts
# Processed 165000/2506058 texts
# Processed 166000/2506058 texts
# Processed 167000/2506058 texts
# Processed 168000/2506058 texts
# Processed 169000/2506058 texts
# Processed 170000/2506058 texts
# Processed 171000/2506058 texts
# Processed 172000/2506058 texts
# Processed 173000/2506058 texts
# Processed 174000/2506058 texts
# Processed 175000/2506058 texts
# Processed 176000/2506058 texts
# Processed 177000/2506058 texts
# Processed 178000/2506058 texts
# Processed 179000/2506058 texts
# Processed 180000/2506058 texts
# Processed 181000/2506058 texts
# Processed 182000/2506058 texts
# Processed 183000/2506058 texts
# Processed 184000/2506058 texts
# Processed 185000/2506058 texts
# Processed 186000/2506058 texts
# Processed 187000/2506058 texts
# Processed 188000/2506058 texts
# Processed 189000/2506058 texts
# Processed 190000/2506058 texts
# Processed 191000/2506058 texts
# Processed 192000/2506058 texts
# Processed 193000/2506058 texts
# Processed 194000/2506058 texts
# Processed 195000/2506058 texts
# Processed 196000/2506058 texts
# Processed 197000/2506058 texts
# Processed 198000/2506058 texts
# Processed 199000/2506058 texts
# Processed 200000/2506058 texts
# Processed 201000/2506058 texts
# Processed 202000/2506058 texts
# Processed 203000/2506058 texts
# Processed 204000/2506058 texts
# Processed 205000/2506058 texts
# Processed 206000/2506058 texts
# Processed 207000/2506058 texts
# Processed 208000/2506058 texts
# Processed 209000/2506058 texts
# Processed 210000/2506058 texts
# Processed 211000/2506058 texts
# Processed 212000/2506058 texts
# Processed 213000/2506058 texts
# Processed 214000/2506058 texts
# Processed 215000/2506058 texts
# Processed 216000/2506058 texts
# Processed 217000/2506058 texts
# Processed 218000/2506058 texts
# Processed 219000/2506058 texts
# Processed 220000/2506058 texts
# Processed 221000/2506058 texts
# Processed 222000/2506058 texts
# Processed 223000/2506058 texts
# Processed 224000/2506058 texts
# Processed 225000/2506058 texts
# Processed 226000/2506058 texts
# Processed 227000/2506058 texts
# Processed 228000/2506058 texts
# Processed 229000/2506058 texts
# Processed 230000/2506058 texts
# Processed 231000/2506058 texts
# Processed 232000/2506058 texts
# Processed 233000/2506058 texts
# Processed 234000/2506058 texts
# Processed 235000/2506058 texts
# Processed 236000/2506058 texts
# Processed 237000/2506058 texts
# Processed 238000/2506058 texts
# Processed 239000/2506058 texts
# Processed 240000/2506058 texts
# Processed 241000/2506058 texts
# Processed 242000/2506058 texts
# Processed 243000/2506058 texts
# Processed 244000/2506058 texts
# Processed 245000/2506058 texts
# Processed 246000/2506058 texts
# Processed 247000/2506058 texts
# Processed 248000/2506058 texts
# Processed 249000/2506058 texts
# Processed 250000/2506058 texts
# Processed 251000/2506058 texts
# Processed 252000/2506058 texts
# Processed 253000/2506058 texts
# Processed 254000/2506058 texts
# Processed 255000/2506058 texts
# Processed 256000/2506058 texts
# Processed 257000/2506058 texts
# Processed 258000/2506058 texts
# Processed 259000/2506058 texts
# Processed 260000/2506058 texts
# Processed 261000/2506058 texts
# Processed 262000/2506058 texts
# Processed 263000/2506058 texts
# Processed 264000/2506058 texts
# Processed 265000/2506058 texts
# Processed 266000/2506058 texts
# Processed 267000/2506058 texts
# Processed 268000/2506058 texts
# Processed 269000/2506058 texts
# Processed 270000/2506058 texts
# Processed 271000/2506058 texts
# Processed 272000/2506058 texts
# Processed 273000/2506058 texts
# Processed 274000/2506058 texts
# Processed 275000/2506058 texts
# Processed 276000/2506058 texts
# Processed 277000/2506058 texts
# Processed 278000/2506058 texts
# Processed 279000/2506058 texts
# Processed 280000/2506058 texts
# Processed 281000/2506058 texts
# Processed 282000/2506058 texts
# Processed 283000/2506058 texts
# Processed 284000/2506058 texts
# Processed 285000/2506058 texts
# Processed 286000/2506058 texts
# Processed 287000/2506058 texts
# Processed 288000/2506058 texts
# Processed 289000/2506058 texts
# Processed 290000/2506058 texts
# Processed 291000/2506058 texts
# Processed 292000/2506058 texts
# Processed 293000/2506058 texts
# Processed 294000/2506058 texts
# Processed 295000/2506058 texts
# Processed 296000/2506058 texts
# Processed 297000/2506058 texts
# Processed 298000/2506058 texts
# Processed 299000/2506058 texts
# Processed 300000/2506058 texts
# Processed 301000/2506058 texts
# Processed 302000/2506058 texts
# Processed 303000/2506058 texts
# Processed 304000/2506058 texts
# Processed 305000/2506058 texts
# Processed 306000/2506058 texts
# Processed 307000/2506058 texts
# Processed 308000/2506058 texts
# Processed 309000/2506058 texts
# Processed 310000/2506058 texts
# Processed 311000/2506058 texts
# Processed 312000/2506058 texts
# Processed 313000/2506058 texts
# Processed 314000/2506058 texts
# Processed 315000/2506058 texts
# Processed 316000/2506058 texts
# Processed 317000/2506058 texts
# Processed 318000/2506058 texts
# Processed 319000/2506058 texts
# Processed 320000/2506058 texts
# Processed 321000/2506058 texts
# Processed 322000/2506058 texts
# Processed 323000/2506058 texts
# Processed 324000/2506058 texts
# Processed 325000/2506058 texts
# Processed 326000/2506058 texts
# Processed 327000/2506058 texts
# Processed 328000/2506058 texts
# Processed 329000/2506058 texts
# Processed 330000/2506058 texts
# Processed 331000/2506058 texts
# Processed 332000/2506058 texts
# Processed 333000/2506058 texts
# Processed 334000/2506058 texts
# Processed 335000/2506058 texts
# Processed 336000/2506058 texts
# Processed 337000/2506058 texts
# Processed 338000/2506058 texts
# Processed 339000/2506058 texts
# Processed 340000/2506058 texts
# Processed 341000/2506058 texts
# Processed 342000/2506058 texts
# Processed 343000/2506058 texts
# Processed 344000/2506058 texts
# Processed 345000/2506058 texts
# Processed 346000/2506058 texts
# Processed 347000/2506058 texts
# Processed 348000/2506058 texts
# Processed 349000/2506058 texts
# Processed 350000/2506058 texts
# Processed 351000/2506058 texts
# Processed 352000/2506058 texts
# Processed 353000/2506058 texts
# Processed 354000/2506058 texts
# Processed 355000/2506058 texts
# Processed 356000/2506058 texts
# Processed 357000/2506058 texts
# Processed 358000/2506058 texts
# Processed 359000/2506058 texts
# Processed 360000/2506058 texts
# Processed 361000/2506058 texts
# Processed 362000/2506058 texts
# Processed 363000/2506058 texts
# Processed 364000/2506058 texts
# Processed 365000/2506058 texts
# Processed 366000/2506058 texts
# Processed 367000/2506058 texts
# Processed 368000/2506058 texts
# Processed 369000/2506058 texts
# Processed 370000/2506058 texts
# Processed 371000/2506058 texts
# Processed 372000/2506058 texts
# Processed 373000/2506058 texts
# Processed 374000/2506058 texts
# Processed 375000/2506058 texts
# Processed 376000/2506058 texts
# Processed 377000/2506058 texts
# Processed 378000/2506058 texts
# Processed 379000/2506058 texts
# Processed 380000/2506058 texts
# Processed 381000/2506058 texts
# Processed 382000/2506058 texts
# Processed 383000/2506058 texts
# Processed 384000/2506058 texts
# Processed 385000/2506058 texts
# Processed 386000/2506058 texts
# Processed 387000/2506058 texts
# Processed 388000/2506058 texts
# Processed 389000/2506058 texts
# Processed 390000/2506058 texts
# Processed 391000/2506058 texts
# Processed 392000/2506058 texts
# Processed 393000/2506058 texts
# Processed 394000/2506058 texts
# Processed 395000/2506058 texts
# Processed 396000/2506058 texts
# Processed 397000/2506058 texts
# Processed 398000/2506058 texts
# Processed 399000/2506058 texts
# Processed 400000/2506058 texts
# Processed 401000/2506058 texts
# Processed 402000/2506058 texts
# Processed 403000/2506058 texts
# Processed 404000/2506058 texts
# Processed 405000/2506058 texts
# Processed 406000/2506058 texts
# Processed 407000/2506058 texts
# Processed 408000/2506058 texts
# Processed 409000/2506058 texts
# Processed 410000/2506058 texts
# Processed 411000/2506058 texts
# Processed 412000/2506058 texts
# Processed 413000/2506058 texts
# Processed 414000/2506058 texts
# Processed 415000/2506058 texts
# Processed 416000/2506058 texts
# Processed 417000/2506058 texts
# Processed 418000/2506058 texts
# Processed 419000/2506058 texts
# Processed 420000/2506058 texts
# Processed 421000/2506058 texts
# Processed 422000/2506058 texts
# Processed 423000/2506058 texts
# Processed 424000/2506058 texts
# Processed 425000/2506058 texts
# Processed 426000/2506058 texts
# Processed 427000/2506058 texts
# Processed 428000/2506058 texts
# Processed 429000/2506058 texts
# Processed 430000/2506058 texts
# Processed 431000/2506058 texts
# Processed 432000/2506058 texts
# Processed 433000/2506058 texts
# Processed 434000/2506058 texts
# Processed 435000/2506058 texts
# Processed 436000/2506058 texts
# Processed 437000/2506058 texts
# Processed 438000/2506058 texts
# Processed 439000/2506058 texts
# Processed 440000/2506058 texts
# Processed 441000/2506058 texts
# Processed 442000/2506058 texts
# Processed 443000/2506058 texts
# Processed 444000/2506058 texts
# Processed 445000/2506058 texts
# Processed 446000/2506058 texts
# Processed 447000/2506058 texts
# Processed 448000/2506058 texts
# Processed 449000/2506058 texts
# Processed 450000/2506058 texts
# Processed 451000/2506058 texts
# Processed 452000/2506058 texts
# Processed 453000/2506058 texts
# Processed 454000/2506058 texts
# Processed 455000/2506058 texts
# Processed 456000/2506058 texts
# Processed 457000/2506058 texts
# Processed 458000/2506058 texts
# Processed 459000/2506058 texts
# Processed 460000/2506058 texts
# Processed 461000/2506058 texts
# Processed 462000/2506058 texts
# Processed 463000/2506058 texts
# Processed 464000/2506058 texts
# Processed 465000/2506058 texts
# Processed 466000/2506058 texts
# Processed 467000/2506058 texts
# Processed 468000/2506058 texts
# Processed 469000/2506058 texts
# Processed 470000/2506058 texts
# Processed 471000/2506058 texts
# Processed 472000/2506058 texts
# Processed 473000/2506058 texts
# Processed 474000/2506058 texts
# Processed 475000/2506058 texts
# Processed 476000/2506058 texts
# Processed 477000/2506058 texts
# Processed 478000/2506058 texts
# Processed 479000/2506058 texts
# Processed 480000/2506058 texts
# Processed 481000/2506058 texts
# Processed 482000/2506058 texts
# Processed 483000/2506058 texts
# Processed 484000/2506058 texts
# Processed 485000/2506058 texts
# Processed 486000/2506058 texts
# Processed 487000/2506058 texts
# Processed 488000/2506058 texts
# Processed 489000/2506058 texts
# Processed 490000/2506058 texts
# Processed 491000/2506058 texts
# Processed 492000/2506058 texts
# Processed 493000/2506058 texts
# Processed 494000/2506058 texts
# Processed 495000/2506058 texts
# Processed 496000/2506058 texts
# Processed 497000/2506058 texts
# Processed 498000/2506058 texts
# Processed 499000/2506058 texts
# Processed 500000/2506058 texts
# Processed 501000/2506058 texts
# Processed 502000/2506058 texts
# Processed 503000/2506058 texts
# Processed 504000/2506058 texts
# Processed 505000/2506058 texts
# Processed 506000/2506058 texts
# Processed 507000/2506058 texts
# Processed 508000/2506058 texts
# Processed 509000/2506058 texts
# Processed 510000/2506058 texts
# Processed 511000/2506058 texts
# Processed 512000/2506058 texts
# Processed 513000/2506058 texts
# Processed 514000/2506058 texts
# Processed 515000/2506058 texts
# Processed 516000/2506058 texts
# Processed 517000/2506058 texts
# Processed 518000/2506058 texts
# Processed 519000/2506058 texts
# Processed 520000/2506058 texts
# Processed 521000/2506058 texts
# Processed 522000/2506058 texts
# Processed 523000/2506058 texts
# Processed 524000/2506058 texts
# Processed 525000/2506058 texts
# Processed 526000/2506058 texts
# Processed 527000/2506058 texts
# Processed 528000/2506058 texts
# Processed 529000/2506058 texts
# Processed 530000/2506058 texts
# Processed 531000/2506058 texts
# Processed 532000/2506058 texts
# Processed 533000/2506058 texts
# Processed 534000/2506058 texts
# Processed 535000/2506058 texts
# Processed 536000/2506058 texts
# Processed 537000/2506058 texts
# Processed 538000/2506058 texts
# Processed 539000/2506058 texts
# Processed 540000/2506058 texts
# Processed 541000/2506058 texts
# Processed 542000/2506058 texts
# Processed 543000/2506058 texts
# Processed 544000/2506058 texts
# Processed 545000/2506058 texts
# Processed 546000/2506058 texts
# Processed 547000/2506058 texts
# Processed 548000/2506058 texts
# Processed 549000/2506058 texts
# Processed 550000/2506058 texts
# Processed 551000/2506058 texts
# Processed 552000/2506058 texts
# Processed 553000/2506058 texts
# Processed 554000/2506058 texts
# Processed 555000/2506058 texts
# Processed 556000/2506058 texts
# Processed 557000/2506058 texts
# Processed 558000/2506058 texts
# Processed 559000/2506058 texts
# Processed 560000/2506058 texts
# Processed 561000/2506058 texts
# Processed 562000/2506058 texts
# Processed 563000/2506058 texts
# Processed 564000/2506058 texts
# Processed 565000/2506058 texts
# Processed 566000/2506058 texts
# Processed 567000/2506058 texts
# Processed 568000/2506058 texts
# Processed 569000/2506058 texts
# Processed 570000/2506058 texts
# Processed 571000/2506058 texts
# Processed 572000/2506058 texts
# Processed 573000/2506058 texts
# Processed 574000/2506058 texts
# Processed 575000/2506058 texts
# Processed 576000/2506058 texts
# Processed 577000/2506058 texts
# Processed 578000/2506058 texts
# Processed 579000/2506058 texts
# Processed 580000/2506058 texts
# Processed 581000/2506058 texts
# Processed 582000/2506058 texts
# Processed 583000/2506058 texts
# Processed 584000/2506058 texts
# Processed 585000/2506058 texts
# Processed 586000/2506058 texts
# Processed 587000/2506058 texts
# Processed 588000/2506058 texts
# Processed 589000/2506058 texts
# Processed 590000/2506058 texts
# Processed 591000/2506058 texts
# Processed 592000/2506058 texts
# Processed 593000/2506058 texts
# Processed 594000/2506058 texts
# Processed 595000/2506058 texts
# Processed 596000/2506058 texts
# Processed 597000/2506058 texts
# Processed 598000/2506058 texts
# Processed 599000/2506058 texts
# Processed 600000/2506058 texts
# Processed 601000/2506058 texts
# Processed 602000/2506058 texts
# Processed 603000/2506058 texts
# Processed 604000/2506058 texts
# Processed 605000/2506058 texts
# Processed 606000/2506058 texts
# Processed 607000/2506058 texts
# Processed 608000/2506058 texts
# Processed 609000/2506058 texts
# Processed 610000/2506058 texts
# Processed 611000/2506058 texts
# Processed 612000/2506058 texts
# Processed 613000/2506058 texts
# Processed 614000/2506058 texts
# Processed 615000/2506058 texts
# Processed 616000/2506058 texts
# Processed 617000/2506058 texts
# Processed 618000/2506058 texts
# Processed 619000/2506058 texts
# Processed 620000/2506058 texts
# Processed 621000/2506058 texts
# Processed 622000/2506058 texts
# Processed 623000/2506058 texts
# Processed 624000/2506058 texts
# Processed 625000/2506058 texts
# Processed 626000/2506058 texts
# Processed 627000/2506058 texts
# Processed 628000/2506058 texts
# Processed 629000/2506058 texts
# Processed 630000/2506058 texts
# Processed 631000/2506058 texts
# Processed 632000/2506058 texts
# Processed 633000/2506058 texts
# Processed 634000/2506058 texts
# Processed 635000/2506058 texts
# Processed 636000/2506058 texts
# Processed 637000/2506058 texts
# Processed 638000/2506058 texts
# Processed 639000/2506058 texts
# Processed 640000/2506058 texts
# Processed 641000/2506058 texts
# Processed 642000/2506058 texts
# Processed 643000/2506058 texts
# Processed 644000/2506058 texts
# Processed 645000/2506058 texts
# Processed 646000/2506058 texts
# Processed 647000/2506058 texts
# Processed 648000/2506058 texts
# Processed 649000/2506058 texts
# Processed 650000/2506058 texts
# Processed 651000/2506058 texts
# Processed 652000/2506058 texts
# Processed 653000/2506058 texts
# Processed 654000/2506058 texts
# Processed 655000/2506058 texts
# Processed 656000/2506058 texts
# Processed 657000/2506058 texts
# Processed 658000/2506058 texts
# Processed 659000/2506058 texts
# Processed 660000/2506058 texts
# Processed 661000/2506058 texts
# Processed 662000/2506058 texts
# Processed 663000/2506058 texts
# Processed 664000/2506058 texts
# Processed 665000/2506058 texts
# Processed 666000/2506058 texts
# Processed 667000/2506058 texts
# Processed 668000/2506058 texts
# Processed 669000/2506058 texts
# Processed 670000/2506058 texts
# Processed 671000/2506058 texts
# Processed 672000/2506058 texts
# Processed 673000/2506058 texts
# Processed 674000/2506058 texts
# Processed 675000/2506058 texts
# Processed 676000/2506058 texts
# Processed 677000/2506058 texts
# Processed 678000/2506058 texts
# Processed 679000/2506058 texts
# Processed 680000/2506058 texts
# Processed 681000/2506058 texts
# Processed 682000/2506058 texts
# Processed 683000/2506058 texts
# Processed 684000/2506058 texts
# Processed 685000/2506058 texts
# Processed 686000/2506058 texts
# Processed 687000/2506058 texts
# Processed 688000/2506058 texts
# Processed 689000/2506058 texts
# Processed 690000/2506058 texts
# Processed 691000/2506058 texts
# Processed 692000/2506058 texts
# Processed 693000/2506058 texts
# Processed 694000/2506058 texts
# Processed 695000/2506058 texts
# Processed 696000/2506058 texts
# Processed 697000/2506058 texts
# Processed 698000/2506058 texts
# Processed 699000/2506058 texts
# Processed 700000/2506058 texts
# Processed 701000/2506058 texts
# Processed 702000/2506058 texts
# Processed 703000/2506058 texts
# Processed 704000/2506058 texts
# Processed 705000/2506058 texts
# Processed 706000/2506058 texts
# Processed 707000/2506058 texts
# Processed 708000/2506058 texts
# Processed 709000/2506058 texts
# Processed 710000/2506058 texts
# Processed 711000/2506058 texts
# Processed 712000/2506058 texts
# Processed 713000/2506058 texts
# Processed 714000/2506058 texts
# Processed 715000/2506058 texts
# Processed 716000/2506058 texts
# Processed 717000/2506058 texts
# Processed 718000/2506058 texts
# Processed 719000/2506058 texts
# Processed 720000/2506058 texts
# Processed 721000/2506058 texts
# Processed 722000/2506058 texts
# Processed 723000/2506058 texts
# Processed 724000/2506058 texts
# Processed 725000/2506058 texts
# Processed 726000/2506058 texts
# Processed 727000/2506058 texts
# Processed 728000/2506058 texts
# Processed 729000/2506058 texts
# Processed 730000/2506058 texts
# Processed 731000/2506058 texts
# Processed 732000/2506058 texts
# Processed 733000/2506058 texts
# Processed 734000/2506058 texts
# Processed 735000/2506058 texts
# Processed 736000/2506058 texts
# Processed 737000/2506058 texts
# Processed 738000/2506058 texts
# Processed 739000/2506058 texts
# Processed 740000/2506058 texts
# Processed 741000/2506058 texts
# Processed 742000/2506058 texts
# Processed 743000/2506058 texts
# Processed 744000/2506058 texts
# Processed 745000/2506058 texts
# Processed 746000/2506058 texts
# Processed 747000/2506058 texts
# Processed 748000/2506058 texts
# Processed 749000/2506058 texts
# Processed 750000/2506058 texts
# Processed 751000/2506058 texts
# Processed 752000/2506058 texts
# Processed 753000/2506058 texts
# Processed 754000/2506058 texts
# Processed 755000/2506058 texts
# Processed 756000/2506058 texts
# Processed 757000/2506058 texts
# Processed 758000/2506058 texts
# Processed 759000/2506058 texts
# Processed 760000/2506058 texts
# Processed 761000/2506058 texts
# Processed 762000/2506058 texts
# Processed 763000/2506058 texts
# Processed 764000/2506058 texts
# Processed 765000/2506058 texts
# Processed 766000/2506058 texts
# Processed 767000/2506058 texts
# Processed 768000/2506058 texts
# Processed 769000/2506058 texts
# Processed 770000/2506058 texts
# Processed 771000/2506058 texts
# Processed 772000/2506058 texts
# Processed 773000/2506058 texts
# Processed 774000/2506058 texts
# Processed 775000/2506058 texts
# Processed 776000/2506058 texts
# Processed 777000/2506058 texts
# Processed 778000/2506058 texts
# Processed 779000/2506058 texts
# Processed 780000/2506058 texts
# Processed 781000/2506058 texts
# Processed 782000/2506058 texts
# Processed 783000/2506058 texts
# Processed 784000/2506058 texts
# Processed 785000/2506058 texts
# Processed 786000/2506058 texts
# Processed 787000/2506058 texts
# Processed 788000/2506058 texts
# Processed 789000/2506058 texts
# Processed 790000/2506058 texts
# Processed 791000/2506058 texts
# Processed 792000/2506058 texts
# Processed 793000/2506058 texts
# Processed 794000/2506058 texts
# Processed 795000/2506058 texts
# Processed 796000/2506058 texts
# Processed 797000/2506058 texts
# Processed 798000/2506058 texts
# Processed 799000/2506058 texts
# Processed 800000/2506058 texts
# Processed 801000/2506058 texts
# Processed 802000/2506058 texts
# Processed 803000/2506058 texts
# Processed 804000/2506058 texts
# Processed 805000/2506058 texts
# Processed 806000/2506058 texts
# Processed 807000/2506058 texts
# Processed 808000/2506058 texts
# Processed 809000/2506058 texts
# Processed 810000/2506058 texts
# Processed 811000/2506058 texts
# Processed 812000/2506058 texts
# Processed 813000/2506058 texts
# Processed 814000/2506058 texts
# Processed 815000/2506058 texts
# Processed 816000/2506058 texts
# Processed 817000/2506058 texts
# Processed 818000/2506058 texts
# Processed 819000/2506058 texts
# Processed 820000/2506058 texts
# Processed 821000/2506058 texts
# Processed 822000/2506058 texts
# Processed 823000/2506058 texts
# Processed 824000/2506058 texts
# Processed 825000/2506058 texts
# Processed 826000/2506058 texts
# Processed 827000/2506058 texts
# Processed 828000/2506058 texts
# Processed 829000/2506058 texts
# Processed 830000/2506058 texts
# Processed 831000/2506058 texts
# Processed 832000/2506058 texts
# Processed 833000/2506058 texts
# Processed 834000/2506058 texts
# Processed 835000/2506058 texts
# Processed 836000/2506058 texts
# Processed 837000/2506058 texts
# Processed 838000/2506058 texts
# Processed 839000/2506058 texts
# Processed 840000/2506058 texts
# Processed 841000/2506058 texts
# Processed 842000/2506058 texts
# Processed 843000/2506058 texts
# Processed 844000/2506058 texts
# Processed 845000/2506058 texts
# Processed 846000/2506058 texts
# Processed 847000/2506058 texts
# Processed 848000/2506058 texts
# Processed 849000/2506058 texts
# Processed 850000/2506058 texts
# Processed 851000/2506058 texts
# Processed 852000/2506058 texts
# Processed 853000/2506058 texts
# Processed 854000/2506058 texts
# Processed 855000/2506058 texts
# Processed 856000/2506058 texts
# Processed 857000/2506058 texts
# Processed 858000/2506058 texts
# Processed 859000/2506058 texts
# Processed 860000/2506058 texts
# Processed 861000/2506058 texts
# Processed 862000/2506058 texts
# Processed 863000/2506058 texts
# Processed 864000/2506058 texts
# Processed 865000/2506058 texts
# Processed 866000/2506058 texts
# Processed 867000/2506058 texts
# Processed 868000/2506058 texts
# Processed 869000/2506058 texts
# Processed 870000/2506058 texts
# Processed 871000/2506058 texts
# Processed 872000/2506058 texts
# Processed 873000/2506058 texts
# Processed 874000/2506058 texts
# Processed 875000/2506058 texts
# Processed 876000/2506058 texts
# Processed 877000/2506058 texts
# Processed 878000/2506058 texts
# Processed 879000/2506058 texts
# Processed 880000/2506058 texts
# Processed 881000/2506058 texts
# Processed 882000/2506058 texts
# Processed 883000/2506058 texts
# Processed 884000/2506058 texts
# Processed 885000/2506058 texts
# Processed 886000/2506058 texts
# Processed 887000/2506058 texts
# Processed 888000/2506058 texts
# Processed 889000/2506058 texts
# Processed 890000/2506058 texts
# Processed 891000/2506058 texts
# Processed 892000/2506058 texts
# Processed 893000/2506058 texts
# Processed 894000/2506058 texts
# Processed 895000/2506058 texts
# Processed 896000/2506058 texts
# Processed 897000/2506058 texts
# Processed 898000/2506058 texts
# Processed 899000/2506058 texts
# Processed 900000/2506058 texts
# Processed 901000/2506058 texts
# Processed 902000/2506058 texts
# Processed 903000/2506058 texts
# Processed 904000/2506058 texts
# Processed 905000/2506058 texts
# Processed 906000/2506058 texts
# Processed 907000/2506058 texts
# Processed 908000/2506058 texts
# Processed 909000/2506058 texts
# Processed 910000/2506058 texts
# Processed 911000/2506058 texts
# Processed 912000/2506058 texts
# Processed 913000/2506058 texts
# Processed 914000/2506058 texts
# Processed 915000/2506058 texts
# Processed 916000/2506058 texts
# Processed 917000/2506058 texts
# Processed 918000/2506058 texts
# Processed 919000/2506058 texts
# Processed 920000/2506058 texts
# Processed 921000/2506058 texts
# Processed 922000/2506058 texts
# Processed 923000/2506058 texts
# Processed 924000/2506058 texts
# Processed 925000/2506058 texts
# Processed 926000/2506058 texts
# Processed 927000/2506058 texts
# Processed 928000/2506058 texts
# Processed 929000/2506058 texts
# Processed 930000/2506058 texts
# Processed 931000/2506058 texts
# Processed 932000/2506058 texts
# Processed 933000/2506058 texts
# Processed 934000/2506058 texts
# Processed 935000/2506058 texts
# Processed 936000/2506058 texts
# Processed 937000/2506058 texts
# Processed 938000/2506058 texts
# Processed 939000/2506058 texts
# Processed 940000/2506058 texts
# Processed 941000/2506058 texts
# Processed 942000/2506058 texts
# Processed 943000/2506058 texts
# Processed 944000/2506058 texts
# Processed 945000/2506058 texts
# Processed 946000/2506058 texts
# Processed 947000/2506058 texts
# Processed 948000/2506058 texts
# Processed 949000/2506058 texts
# Processed 950000/2506058 texts
# Processed 951000/2506058 texts
# Processed 952000/2506058 texts
# Processed 953000/2506058 texts
# Processed 954000/2506058 texts
# Processed 955000/2506058 texts
# Processed 956000/2506058 texts
# Processed 957000/2506058 texts
# Processed 958000/2506058 texts
# Processed 959000/2506058 texts
# Processed 960000/2506058 texts
# Processed 961000/2506058 texts
# Processed 962000/2506058 texts
# Processed 963000/2506058 texts
# Processed 964000/2506058 texts
# Processed 965000/2506058 texts
# Processed 966000/2506058 texts
# Processed 967000/2506058 texts
# Processed 968000/2506058 texts
# Processed 969000/2506058 texts
# Processed 970000/2506058 texts
# Processed 971000/2506058 texts
# Processed 972000/2506058 texts
# Processed 973000/2506058 texts
# Processed 974000/2506058 texts
# Processed 975000/2506058 texts
# Processed 976000/2506058 texts
# Processed 977000/2506058 texts
# Processed 978000/2506058 texts
# Processed 979000/2506058 texts
# Processed 980000/2506058 texts
# Processed 981000/2506058 texts
# Processed 982000/2506058 texts
# Processed 983000/2506058 texts
# Processed 984000/2506058 texts
# Processed 985000/2506058 texts
# Processed 986000/2506058 texts
# Processed 987000/2506058 texts
# Processed 988000/2506058 texts
# Processed 989000/2506058 texts
# Processed 990000/2506058 texts
# Processed 991000/2506058 texts
# Processed 992000/2506058 texts
# Processed 993000/2506058 texts
# Processed 994000/2506058 texts
# Processed 995000/2506058 texts
# Processed 996000/2506058 texts
# Processed 997000/2506058 texts
# Processed 998000/2506058 texts
# Processed 999000/2506058 texts
# Processed 1000000/2506058 texts
# Processed 1001000/2506058 texts
# Processed 1002000/2506058 texts
# Processed 1003000/2506058 texts
# Processed 1004000/2506058 texts
# Processed 1005000/2506058 texts
# Processed 1006000/2506058 texts
# Processed 1007000/2506058 texts
# Processed 1008000/2506058 texts
# Processed 1009000/2506058 texts
# Processed 1010000/2506058 texts
# Processed 1011000/2506058 texts
# Processed 1012000/2506058 texts
# Processed 1013000/2506058 texts
# Processed 1014000/2506058 texts
# Processed 1015000/2506058 texts
# Processed 1016000/2506058 texts
# Processed 1017000/2506058 texts
# Processed 1018000/2506058 texts
# Processed 1019000/2506058 texts
# Processed 1020000/2506058 texts
# Processed 1021000/2506058 texts
# Processed 1022000/2506058 texts
# Processed 1023000/2506058 texts
# Processed 1024000/2506058 texts
# Processed 1025000/2506058 texts
# Processed 1026000/2506058 texts
# Processed 1027000/2506058 texts
# Processed 1028000/2506058 texts
# Processed 1029000/2506058 texts
# Processed 1030000/2506058 texts
# Processed 1031000/2506058 texts
# Processed 1032000/2506058 texts
# Processed 1033000/2506058 texts
# Processed 1034000/2506058 texts
# Processed 1035000/2506058 texts
# Processed 1036000/2506058 texts
# Processed 1037000/2506058 texts
# Processed 1038000/2506058 texts
# Processed 1039000/2506058 texts
# Processed 1040000/2506058 texts
# Processed 1041000/2506058 texts
# Processed 1042000/2506058 texts
# Processed 1043000/2506058 texts
# Processed 1044000/2506058 texts
# Processed 1045000/2506058 texts
# Processed 1046000/2506058 texts
# Processed 1047000/2506058 texts
# Processed 1048000/2506058 texts
# Processed 1049000/2506058 texts
# Processed 1050000/2506058 texts
# Processed 1051000/2506058 texts
# Processed 1052000/2506058 texts
# Processed 1053000/2506058 texts
# Processed 1054000/2506058 texts
# Processed 1055000/2506058 texts
# Processed 1056000/2506058 texts
# Processed 1057000/2506058 texts
# Processed 1058000/2506058 texts
# Processed 1059000/2506058 texts
# Processed 1060000/2506058 texts
# Processed 1061000/2506058 texts
# Processed 1062000/2506058 texts
# Processed 1063000/2506058 texts
# Processed 1064000/2506058 texts
# Processed 1065000/2506058 texts
# Processed 1066000/2506058 texts
# Processed 1067000/2506058 texts
# Processed 1068000/2506058 texts
# Processed 1069000/2506058 texts
# Processed 1070000/2506058 texts
# Processed 1071000/2506058 texts
# Processed 1072000/2506058 texts
# Processed 1073000/2506058 texts
# Processed 1074000/2506058 texts
# Processed 1075000/2506058 texts
# Processed 1076000/2506058 texts
# Processed 1077000/2506058 texts
# Processed 1078000/2506058 texts
# Processed 1079000/2506058 texts
# Processed 1080000/2506058 texts
# Processed 1081000/2506058 texts
# Processed 1082000/2506058 texts
# Processed 1083000/2506058 texts
# Processed 1084000/2506058 texts
# Processed 1085000/2506058 texts
# Processed 1086000/2506058 texts
# Processed 1087000/2506058 texts
# Processed 1088000/2506058 texts
# Processed 1089000/2506058 texts
# Processed 1090000/2506058 texts
# Processed 1091000/2506058 texts
# Processed 1092000/2506058 texts
# Processed 1093000/2506058 texts
# Processed 1094000/2506058 texts
# Processed 1095000/2506058 texts
# Processed 1096000/2506058 texts
# Processed 1097000/2506058 texts
# Processed 1098000/2506058 texts
# Processed 1099000/2506058 texts
# Processed 1100000/2506058 texts
# Processed 1101000/2506058 texts
# Processed 1102000/2506058 texts
# Processed 1103000/2506058 texts
# Processed 1104000/2506058 texts
# Processed 1105000/2506058 texts
# Processed 1106000/2506058 texts
# Processed 1107000/2506058 texts
# Processed 1108000/2506058 texts
# Processed 1109000/2506058 texts
# Processed 1110000/2506058 texts
# Processed 1111000/2506058 texts
# Processed 1112000/2506058 texts
# Processed 1113000/2506058 texts
# Processed 1114000/2506058 texts
# Processed 1115000/2506058 texts
# Processed 1116000/2506058 texts
# Processed 1117000/2506058 texts
# Processed 1118000/2506058 texts
# Processed 1119000/2506058 texts
# Processed 1120000/2506058 texts
# Processed 1121000/2506058 texts
# Processed 1122000/2506058 texts
# Processed 1123000/2506058 texts
# Processed 1124000/2506058 texts
# Processed 1125000/2506058 texts
# Processed 1126000/2506058 texts
# Processed 1127000/2506058 texts
# Processed 1128000/2506058 texts
# Processed 1129000/2506058 texts
# Processed 1130000/2506058 texts
# Processed 1131000/2506058 texts
# Processed 1132000/2506058 texts
# Processed 1133000/2506058 texts
# Processed 1134000/2506058 texts
# Processed 1135000/2506058 texts
# Processed 1136000/2506058 texts
# Processed 1137000/2506058 texts
# Processed 1138000/2506058 texts
# Processed 1139000/2506058 texts
# Processed 1140000/2506058 texts
# Processed 1141000/2506058 texts
# Processed 1142000/2506058 texts
# Processed 1143000/2506058 texts
# Processed 1144000/2506058 texts
# Processed 1145000/2506058 texts
# Processed 1146000/2506058 texts
# Processed 1147000/2506058 texts
# Processed 1148000/2506058 texts
# Processed 1149000/2506058 texts
# Processed 1150000/2506058 texts
# Processed 1151000/2506058 texts
# Processed 1152000/2506058 texts
# Processed 1153000/2506058 texts
# Processed 1154000/2506058 texts
# Processed 1155000/2506058 texts
# Processed 1156000/2506058 texts
# Processed 1157000/2506058 texts
# Processed 1158000/2506058 texts
# Processed 1159000/2506058 texts
# Processed 1160000/2506058 texts
# Processed 1161000/2506058 texts
# Processed 1162000/2506058 texts
# Processed 1163000/2506058 texts
# Processed 1164000/2506058 texts
# Processed 1165000/2506058 texts
# Processed 1166000/2506058 texts
# Processed 1167000/2506058 texts
# Processed 1168000/2506058 texts
# Processed 1169000/2506058 texts
# Processed 1170000/2506058 texts
# Processed 1171000/2506058 texts
# Processed 1172000/2506058 texts
# Processed 1173000/2506058 texts
# Processed 1174000/2506058 texts
# Processed 1175000/2506058 texts
# Processed 1176000/2506058 texts
# Processed 1177000/2506058 texts
# Processed 1178000/2506058 texts
# Processed 1179000/2506058 texts
# Processed 1180000/2506058 texts
# Processed 1181000/2506058 texts
# Processed 1182000/2506058 texts
# Processed 1183000/2506058 texts
# Processed 1184000/2506058 texts
# Processed 1185000/2506058 texts
# Processed 1186000/2506058 texts
# Processed 1187000/2506058 texts
# Processed 1188000/2506058 texts
# Processed 1189000/2506058 texts
# Processed 1190000/2506058 texts
# Processed 1191000/2506058 texts
# Processed 1192000/2506058 texts
# Processed 1193000/2506058 texts
# Processed 1194000/2506058 texts
# Processed 1195000/2506058 texts
# Processed 1196000/2506058 texts
# Processed 1197000/2506058 texts
# Processed 1198000/2506058 texts
# Processed 1199000/2506058 texts
# Processed 1200000/2506058 texts
# Processed 1201000/2506058 texts
# Processed 1202000/2506058 texts
# Processed 1203000/2506058 texts
# Processed 1204000/2506058 texts
# Processed 1205000/2506058 texts
# Processed 1206000/2506058 texts
# Processed 1207000/2506058 texts
# Processed 1208000/2506058 texts
# Processed 1209000/2506058 texts
# Processed 1210000/2506058 texts
# Processed 1211000/2506058 texts
# Processed 1212000/2506058 texts
# Processed 1213000/2506058 texts
# Processed 1214000/2506058 texts
# Processed 1215000/2506058 texts
# Processed 1216000/2506058 texts
# Processed 1217000/2506058 texts
# Processed 1218000/2506058 texts
# Processed 1219000/2506058 texts
# Processed 1220000/2506058 texts
# Processed 1221000/2506058 texts
# Processed 1222000/2506058 texts
# Processed 1223000/2506058 texts
# Processed 1224000/2506058 texts
# Processed 1225000/2506058 texts
# Processed 1226000/2506058 texts
# Processed 1227000/2506058 texts
# Processed 1228000/2506058 texts
# Processed 1229000/2506058 texts
# Processed 1230000/2506058 texts
# Processed 1231000/2506058 texts
# Processed 1232000/2506058 texts
# Processed 1233000/2506058 texts
# Processed 1234000/2506058 texts
# Processed 1235000/2506058 texts
# Processed 1236000/2506058 texts
# Processed 1237000/2506058 texts
# Processed 1238000/2506058 texts
# Processed 1239000/2506058 texts
# Processed 1240000/2506058 texts
# Processed 1241000/2506058 texts
# Processed 1242000/2506058 texts
# Processed 1243000/2506058 texts
# Processed 1244000/2506058 texts
# Processed 1245000/2506058 texts
# Processed 1246000/2506058 texts
# Processed 1247000/2506058 texts
# Processed 1248000/2506058 texts
# Processed 1249000/2506058 texts
# Processed 1250000/2506058 texts
# Processed 1251000/2506058 texts
# Processed 1252000/2506058 texts
# Processed 1253000/2506058 texts
# Processed 1254000/2506058 texts
# Processed 1255000/2506058 texts
# Processed 1256000/2506058 texts
# Processed 1257000/2506058 texts
# Processed 1258000/2506058 texts
# Processed 1259000/2506058 texts
# Processed 1260000/2506058 texts
# Processed 1261000/2506058 texts
# Processed 1262000/2506058 texts
# Processed 1263000/2506058 texts
# Processed 1264000/2506058 texts
# Processed 1265000/2506058 texts
# Processed 1266000/2506058 texts
# Processed 1267000/2506058 texts
# Processed 1268000/2506058 texts
# Processed 1269000/2506058 texts
# Processed 1270000/2506058 texts
# Processed 1271000/2506058 texts
# Processed 1272000/2506058 texts
# Processed 1273000/2506058 texts
# Processed 1274000/2506058 texts
# Processed 1275000/2506058 texts
# Processed 1276000/2506058 texts
# Processed 1277000/2506058 texts
# Processed 1278000/2506058 texts
# Processed 1279000/2506058 texts
# Processed 1280000/2506058 texts
# Processed 1281000/2506058 texts
# Processed 1282000/2506058 texts
# Processed 1283000/2506058 texts
# Processed 1284000/2506058 texts
# Processed 1285000/2506058 texts
# Processed 1286000/2506058 texts
# Processed 1287000/2506058 texts
# Processed 1288000/2506058 texts
# Processed 1289000/2506058 texts
# Processed 1290000/2506058 texts
# Processed 1291000/2506058 texts
# Processed 1292000/2506058 texts
# Processed 1293000/2506058 texts
# Processed 1294000/2506058 texts
# Processed 1295000/2506058 texts
# Processed 1296000/2506058 texts
# Processed 1297000/2506058 texts
# Processed 1298000/2506058 texts
# Processed 1299000/2506058 texts
# Processed 1300000/2506058 texts
# Processed 1301000/2506058 texts
# Processed 1302000/2506058 texts
# Processed 1303000/2506058 texts
# Processed 1304000/2506058 texts
# Processed 1305000/2506058 texts
# Processed 1306000/2506058 texts
# Processed 1307000/2506058 texts
# Processed 1308000/2506058 texts
# Processed 1309000/2506058 texts
# Processed 1310000/2506058 texts
# Processed 1311000/2506058 texts
# Processed 1312000/2506058 texts
# Processed 1313000/2506058 texts
# Processed 1314000/2506058 texts
# Processed 1315000/2506058 texts
# Processed 1316000/2506058 texts
# Processed 1317000/2506058 texts
# Processed 1318000/2506058 texts
# Processed 1319000/2506058 texts
# Processed 1320000/2506058 texts
# Processed 1321000/2506058 texts
# Processed 1322000/2506058 texts
# Processed 1323000/2506058 texts
# Processed 1324000/2506058 texts
# Processed 1325000/2506058 texts
# Processed 1326000/2506058 texts
# Processed 1327000/2506058 texts
# Processed 1328000/2506058 texts
# Processed 1329000/2506058 texts
# Processed 1330000/2506058 texts
# Processed 1331000/2506058 texts
# Processed 1332000/2506058 texts
# Processed 1333000/2506058 texts
# Processed 1334000/2506058 texts
# Processed 1335000/2506058 texts
# Processed 1336000/2506058 texts
# Processed 1337000/2506058 texts
# Processed 1338000/2506058 texts
# Processed 1339000/2506058 texts
# Processed 1340000/2506058 texts
# Processed 1341000/2506058 texts
# Processed 1342000/2506058 texts
# Processed 1343000/2506058 texts
# Processed 1344000/2506058 texts
# Processed 1345000/2506058 texts
# Processed 1346000/2506058 texts
# Processed 1347000/2506058 texts
# Processed 1348000/2506058 texts
# Processed 1349000/2506058 texts
# Processed 1350000/2506058 texts
# Processed 1351000/2506058 texts
# Processed 1352000/2506058 texts
# Processed 1353000/2506058 texts
# Processed 1354000/2506058 texts
# Processed 1355000/2506058 texts
# Processed 1356000/2506058 texts
# Processed 1357000/2506058 texts
# Processed 1358000/2506058 texts
# Processed 1359000/2506058 texts
# Processed 1360000/2506058 texts
# Processed 1361000/2506058 texts
# Processed 1362000/2506058 texts
# Processed 1363000/2506058 texts
# Processed 1364000/2506058 texts
# Processed 1365000/2506058 texts
# Processed 1366000/2506058 texts
# Processed 1367000/2506058 texts
# Processed 1368000/2506058 texts
# Processed 1369000/2506058 texts
# Processed 1370000/2506058 texts
# Processed 1371000/2506058 texts
# Processed 1372000/2506058 texts
# Processed 1373000/2506058 texts
# Processed 1374000/2506058 texts
# Processed 1375000/2506058 texts
# Processed 1376000/2506058 texts
# Processed 1377000/2506058 texts
# Processed 1378000/2506058 texts
# Processed 1379000/2506058 texts
# Processed 1380000/2506058 texts
# Processed 1381000/2506058 texts
# Processed 1382000/2506058 texts
# Processed 1383000/2506058 texts
# Processed 1384000/2506058 texts
# Processed 1385000/2506058 texts
# Processed 1386000/2506058 texts
# Processed 1387000/2506058 texts
# Processed 1388000/2506058 texts
# Processed 1389000/2506058 texts
# Processed 1390000/2506058 texts
# Processed 1391000/2506058 texts
# Processed 1392000/2506058 texts
# Processed 1393000/2506058 texts
# Processed 1394000/2506058 texts
# Processed 1395000/2506058 texts
# Processed 1396000/2506058 texts
# Processed 1397000/2506058 texts
# Processed 1398000/2506058 texts
# Processed 1399000/2506058 texts
# Processed 1400000/2506058 texts
# Processed 1401000/2506058 texts
# Processed 1402000/2506058 texts
# Processed 1403000/2506058 texts
# Processed 1404000/2506058 texts
# Processed 1405000/2506058 texts
# Processed 1406000/2506058 texts
# Processed 1407000/2506058 texts
# Processed 1408000/2506058 texts
# Processed 1409000/2506058 texts
# Processed 1410000/2506058 texts
# Processed 1411000/2506058 texts
# Processed 1412000/2506058 texts
# Processed 1413000/2506058 texts
# Processed 1414000/2506058 texts
# Processed 1415000/2506058 texts
# Processed 1416000/2506058 texts
# Processed 1417000/2506058 texts
# Processed 1418000/2506058 texts
# Processed 1419000/2506058 texts
# Processed 1420000/2506058 texts
# Processed 1421000/2506058 texts
# Processed 1422000/2506058 texts
# Processed 1423000/2506058 texts
# Processed 1424000/2506058 texts
# Processed 1425000/2506058 texts
# Processed 1426000/2506058 texts
# Processed 1427000/2506058 texts
# Processed 1428000/2506058 texts
# Processed 1429000/2506058 texts
# Processed 1430000/2506058 texts
# Processed 1431000/2506058 texts
# Processed 1432000/2506058 texts
# Processed 1433000/2506058 texts
# Processed 1434000/2506058 texts
# Processed 1435000/2506058 texts
# Processed 1436000/2506058 texts
# Processed 1437000/2506058 texts
# Processed 1438000/2506058 texts
# Processed 1439000/2506058 texts
# Processed 1440000/2506058 texts
# Processed 1441000/2506058 texts
# Processed 1442000/2506058 texts
# Processed 1443000/2506058 texts
# Processed 1444000/2506058 texts
# Processed 1445000/2506058 texts
# Processed 1446000/2506058 texts
# Processed 1447000/2506058 texts
# Processed 1448000/2506058 texts
# Processed 1449000/2506058 texts
# Processed 1450000/2506058 texts
# Processed 1451000/2506058 texts
# Processed 1452000/2506058 texts
# Processed 1453000/2506058 texts
# Processed 1454000/2506058 texts
# Processed 1455000/2506058 texts
# Processed 1456000/2506058 texts
# Processed 1457000/2506058 texts
# Processed 1458000/2506058 texts
# Processed 1459000/2506058 texts
# Processed 1460000/2506058 texts
# Processed 1461000/2506058 texts
# Processed 1462000/2506058 texts
# Processed 1463000/2506058 texts
# Processed 1464000/2506058 texts
# Processed 1465000/2506058 texts
# Processed 1466000/2506058 texts
# Processed 1467000/2506058 texts
# Processed 1468000/2506058 texts
# Processed 1469000/2506058 texts
# Processed 1470000/2506058 texts
# Processed 1471000/2506058 texts
# Processed 1472000/2506058 texts
# Processed 1473000/2506058 texts
# Processed 1474000/2506058 texts
# Processed 1475000/2506058 texts
# Processed 1476000/2506058 texts
# Processed 1477000/2506058 texts
# Processed 1478000/2506058 texts
# Processed 1479000/2506058 texts
# Processed 1480000/2506058 texts
# Processed 1481000/2506058 texts
# Processed 1482000/2506058 texts
# Processed 1483000/2506058 texts
# Processed 1484000/2506058 texts
# Processed 1485000/2506058 texts
# Processed 1486000/2506058 texts
# Processed 1487000/2506058 texts
# Processed 1488000/2506058 texts
# Processed 1489000/2506058 texts
# Processed 1490000/2506058 texts
# Processed 1491000/2506058 texts
# Processed 1492000/2506058 texts
# Processed 1493000/2506058 texts
# Processed 1494000/2506058 texts
# Processed 1495000/2506058 texts
# Processed 1496000/2506058 texts
# Processed 1497000/2506058 texts
# Processed 1498000/2506058 texts
# Processed 1499000/2506058 texts
# Processed 1500000/2506058 texts
# Processed 1501000/2506058 texts
# Processed 1502000/2506058 texts
# Processed 1503000/2506058 texts
# Processed 1504000/2506058 texts
# Processed 1505000/2506058 texts
# Processed 1506000/2506058 texts
# Processed 1507000/2506058 texts
# Processed 1508000/2506058 texts
# Processed 1509000/2506058 texts
# Processed 1510000/2506058 texts
# Processed 1511000/2506058 texts
# Processed 1512000/2506058 texts
# Processed 1513000/2506058 texts
# Processed 1514000/2506058 texts
# Processed 1515000/2506058 texts
# Processed 1516000/2506058 texts
# Processed 1517000/2506058 texts
# Processed 1518000/2506058 texts
# Processed 1519000/2506058 texts
# Processed 1520000/2506058 texts
# Processed 1521000/2506058 texts
# Processed 1522000/2506058 texts
# Processed 1523000/2506058 texts
# Processed 1524000/2506058 texts
# Processed 1525000/2506058 texts
# Processed 1526000/2506058 texts
# Processed 1527000/2506058 texts
# Processed 1528000/2506058 texts
# Processed 1529000/2506058 texts
# Processed 1530000/2506058 texts
# Processed 1531000/2506058 texts
# Processed 1532000/2506058 texts
# Processed 1533000/2506058 texts
# Processed 1534000/2506058 texts
# ...
# Processed 2008000/2506058 texts
# Processed 2009000/2506058 texts
# Processed 2010000/2506058 texts
# Processed 2011000/2506058 texts
# Processed 2012000/2506058 texts
# Processed 2013000/2506058 texts
# Processed 2014000/2506058 texts
# Processed 2015000/2506058 texts
# Processed 2016000/2506058 texts
# Processed 2017000/2506058 texts
# Processed 2018000/2506058 texts
# Processed 2019000/2506058 texts
# Processed 2020000/2506058 texts
# Processed 2021000/2506058 texts
# Processed 2022000/2506058 texts
# Processed 2023000/2506058 texts
# Processed 2024000/2506058 texts
# Processed 2025000/2506058 texts
# Processed 2026000/2506058 texts
# Processed 2027000/2506058 texts
# Processed 2028000/2506058 texts
# Processed 2029000/2506058 texts
# Processed 2030000/2506058 texts
# Processed 2031000/2506058 texts
# Processed 2032000/2506058 texts
# Processed 2033000/2506058 texts
# Processed 2034000/2506058 texts
# Processed 2035000/2506058 texts
# Processed 2036000/2506058 texts
# Processed 2037000/2506058 texts
# Processed 2038000/2506058 texts
# Processed 2039000/2506058 texts
# Processed 2040000/2506058 texts
# Processed 2041000/2506058 texts
# Processed 2042000/2506058 texts
# Processed 2043000/2506058 texts
# Processed 2044000/2506058 texts
# Processed 2045000/2506058 texts
# Processed 2046000/2506058 texts
# Processed 2047000/2506058 texts
# Processed 2048000/2506058 texts
# Processed 2049000/2506058 texts
# Processed 2050000/2506058 texts
# Processed 2051000/2506058 texts
# Processed 2052000/2506058 texts
# Processed 2053000/2506058 texts
# Processed 2054000/2506058 texts
# Processed 2055000/2506058 texts
# Processed 2056000/2506058 texts
# Processed 2057000/2506058 texts
# Processed 2058000/2506058 texts
# Processed 2059000/2506058 texts
# Processed 2060000/2506058 texts
# Processed 2061000/2506058 texts
# Processed 2062000/2506058 texts
# Processed 2063000/2506058 texts
# Processed 2064000/2506058 texts
# Processed 2065000/2506058 texts
# Processed 2066000/2506058 texts
# Processed 2067000/2506058 texts
# Processed 2068000/2506058 texts
# Processed 2069000/2506058 texts
# Processed 2070000/2506058 texts
# Processed 2071000/2506058 texts
# Processed 2072000/2506058 texts
# Processed 2073000/2506058 texts
# Processed 2074000/2506058 texts
# Processed 2075000/2506058 texts
# Processed 2076000/2506058 texts
# Processed 2077000/2506058 texts
# Processed 2078000/2506058 texts
# Processed 2079000/2506058 texts
# Processed 2080000/2506058 texts
# Processed 2081000/2506058 texts
# Processed 2082000/2506058 texts
# Processed 2083000/2506058 texts
# Processed 2084000/2506058 texts
# Processed 2085000/2506058 texts
# Processed 2086000/2506058 texts
# Processed 2087000/2506058 texts
# Processed 2088000/2506058 texts
# Processed 2089000/2506058 texts
# Processed 2090000/2506058 texts
# Processed 2091000/2506058 texts
# Processed 2092000/2506058 texts
# Processed 2093000/2506058 texts
# Processed 2094000/2506058 texts
# Processed 2095000/2506058 texts
# Processed 2096000/2506058 texts
# Processed 2097000/2506058 texts
# Processed 2098000/2506058 texts
# Processed 2099000/2506058 texts
# Processed 2100000/2506058 texts
# Processed 2101000/2506058 texts
# Processed 2102000/2506058 texts
# Processed 2103000/2506058 texts
# Processed 2104000/2506058 texts
# Processed 2105000/2506058 texts
# Processed 2106000/2506058 texts
# Processed 2107000/2506058 texts
# Processed 2108000/2506058 texts
# Processed 2109000/2506058 texts
# Processed 2110000/2506058 texts
# Processed 2111000/2506058 texts
# Processed 2112000/2506058 texts
# Processed 2113000/2506058 texts
# Processed 2114000/2506058 texts
# Processed 2115000/2506058 texts
# Processed 2116000/2506058 texts
# Processed 2117000/2506058 texts
# Processed 2118000/2506058 texts
# Processed 2119000/2506058 texts
# Processed 2120000/2506058 texts
# Processed 2121000/2506058 texts
# Processed 2122000/2506058 texts
# Processed 2123000/2506058 texts
# Processed 2124000/2506058 texts
# Processed 2125000/2506058 texts
# Processed 2126000/2506058 texts
# Processed 2127000/2506058 texts
# Processed 2128000/2506058 texts
# Processed 2129000/2506058 texts
# Processed 2130000/2506058 texts
# Processed 2131000/2506058 texts
# Processed 2132000/2506058 texts
# Processed 2133000/2506058 texts
# Processed 2134000/2506058 texts
# Processed 2135000/2506058 texts
# Processed 2136000/2506058 texts
# Processed 2137000/2506058 texts
# Processed 2138000/2506058 texts
# Processed 2139000/2506058 texts
# Processed 2140000/2506058 texts
# Processed 2141000/2506058 texts
# Processed 2142000/2506058 texts
# Processed 2143000/2506058 texts
# Processed 2144000/2506058 texts
# Processed 2145000/2506058 texts
# Processed 2146000/2506058 texts
# Processed 2147000/2506058 texts
# Processed 2148000/2506058 texts
# Processed 2149000/2506058 texts
# Processed 2150000/2506058 texts
# Processed 2151000/2506058 texts
# Processed 2152000/2506058 texts
# Processed 2153000/2506058 texts
# Processed 2154000/2506058 texts
# Processed 2155000/2506058 texts
# Processed 2156000/2506058 texts
# Processed 2157000/2506058 texts
# Processed 2158000/2506058 texts
# Processed 2159000/2506058 texts
# Processed 2160000/2506058 texts
# Processed 2161000/2506058 texts
# Processed 2162000/2506058 texts
# Processed 2163000/2506058 texts
# Processed 2164000/2506058 texts
# Processed 2165000/2506058 texts
# Processed 2166000/2506058 texts
# Processed 2167000/2506058 texts
# Processed 2168000/2506058 texts
# Processed 2169000/2506058 texts
# Processed 2170000/2506058 texts
# Processed 2171000/2506058 texts
# Processed 2172000/2506058 texts
# Processed 2173000/2506058 texts
# Processed 2174000/2506058 texts
# Processed 2175000/2506058 texts
# Processed 2176000/2506058 texts
# Processed 2177000/2506058 texts
# Processed 2178000/2506058 texts
# Processed 2179000/2506058 texts
# Processed 2180000/2506058 texts
# Processed 2181000/2506058 texts
# Processed 2182000/2506058 texts
# Processed 2183000/2506058 texts
# Processed 2184000/2506058 texts
# Processed 2185000/2506058 texts
# Processed 2186000/2506058 texts
# Processed 2187000/2506058 texts
# Processed 2188000/2506058 texts
# Processed 2189000/2506058 texts
# Processed 2190000/2506058 texts
# Processed 2191000/2506058 texts
# Processed 2192000/2506058 texts
# Processed 2193000/2506058 texts
# Processed 2194000/2506058 texts
# Processed 2195000/2506058 texts
# Processed 2196000/2506058 texts
# Processed 2197000/2506058 texts
# Processed 2198000/2506058 texts
# Processed 2199000/2506058 texts
# Processed 2200000/2506058 texts
# Processed 2201000/2506058 texts
# Processed 2202000/2506058 texts
# Processed 2203000/2506058 texts
# Processed 2204000/2506058 texts
# Processed 2205000/2506058 texts
# Processed 2206000/2506058 texts
# Processed 2207000/2506058 texts
# Processed 2208000/2506058 texts
# Processed 2209000/2506058 texts
# Processed 2210000/2506058 texts
# Processed 2211000/2506058 texts
# Processed 2212000/2506058 texts
# Processed 2213000/2506058 texts
# Processed 2214000/2506058 texts
# Processed 2215000/2506058 texts
# Processed 2216000/2506058 texts
# Processed 2217000/2506058 texts
# Processed 2218000/2506058 texts
# Processed 2219000/2506058 texts
# Processed 2220000/2506058 texts
# Processed 2221000/2506058 texts
# Processed 2222000/2506058 texts
# Processed 2223000/2506058 texts
# Processed 2224000/2506058 texts
# Processed 2225000/2506058 texts
# Processed 2226000/2506058 texts
# Processed 2227000/2506058 texts
# Processed 2228000/2506058 texts
# Processed 2229000/2506058 texts
# Processed 2230000/2506058 texts
# Processed 2231000/2506058 texts
# Processed 2232000/2506058 texts
# Processed 2233000/2506058 texts
# Processed 2234000/2506058 texts
# Processed 2235000/2506058 texts
# Processed 2236000/2506058 texts
# Processed 2237000/2506058 texts
# Processed 2238000/2506058 texts
# Processed 2239000/2506058 texts
# Processed 2240000/2506058 texts
# Processed 2241000/2506058 texts
# Processed 2242000/2506058 texts
# Processed 2243000/2506058 texts
# Processed 2244000/2506058 texts
# Processed 2245000/2506058 texts
# Processed 2246000/2506058 texts
# Processed 2247000/2506058 texts
# Processed 2248000/2506058 texts
# Processed 2249000/2506058 texts
# Processed 2250000/2506058 texts
# Processed 2251000/2506058 texts
# Processed 2252000/2506058 texts
# Processed 2253000/2506058 texts
# Processed 2254000/2506058 texts
# Processed 2255000/2506058 texts
# Processed 2256000/2506058 texts
# Processed 2257000/2506058 texts
# Processed 2258000/2506058 texts
# Processed 2259000/2506058 texts
# Processed 2260000/2506058 texts
# Processed 2261000/2506058 texts
# Processed 2262000/2506058 texts
# Processed 2263000/2506058 texts
# Processed 2264000/2506058 texts
# Processed 2265000/2506058 texts
# Processed 2266000/2506058 texts
# Processed 2267000/2506058 texts
# Processed 2268000/2506058 texts
# Processed 2269000/2506058 texts
# Processed 2270000/2506058 texts
# Processed 2271000/2506058 texts
# Processed 2272000/2506058 texts
# Processed 2273000/2506058 texts
# Processed 2274000/2506058 texts
# Processed 2275000/2506058 texts
# Processed 2276000/2506058 texts
# Processed 2277000/2506058 texts
# Processed 2278000/2506058 texts
# Processed 2279000/2506058 texts
# Processed 2280000/2506058 texts
# Processed 2281000/2506058 texts
# Processed 2282000/2506058 texts
# Processed 2283000/2506058 texts
# Processed 2284000/2506058 texts
# Processed 2285000/2506058 texts
# Processed 2286000/2506058 texts
# Processed 2287000/2506058 texts
# Processed 2288000/2506058 texts
# Processed 2289000/2506058 texts
# Processed 2290000/2506058 texts
# Processed 2291000/2506058 texts
# Processed 2292000/2506058 texts
# Processed 2293000/2506058 texts
# Processed 2294000/2506058 texts
# Processed 2295000/2506058 texts
# Processed 2296000/2506058 texts
# Processed 2297000/2506058 texts
# Processed 2298000/2506058 texts
# Processed 2299000/2506058 texts
# Processed 2300000/2506058 texts
# Processed 2301000/2506058 texts
# Processed 2302000/2506058 texts
# Processed 2303000/2506058 texts
# Processed 2304000/2506058 texts
# Processed 2305000/2506058 texts
# Processed 2306000/2506058 texts
# Processed 2307000/2506058 texts
# Processed 2308000/2506058 texts
# Processed 2309000/2506058 texts
# Processed 2310000/2506058 texts
# Processed 2311000/2506058 texts
# Processed 2312000/2506058 texts
# Processed 2313000/2506058 texts
# Processed 2314000/2506058 texts
# Processed 2315000/2506058 texts
# Processed 2316000/2506058 texts
# Processed 2317000/2506058 texts
# Processed 2318000/2506058 texts
# Processed 2319000/2506058 texts
# Processed 2320000/2506058 texts
# Processed 2321000/2506058 texts
# Processed 2322000/2506058 texts
# Processed 2323000/2506058 texts
# Processed 2324000/2506058 texts
# Processed 2325000/2506058 texts
# Processed 2326000/2506058 texts
# Processed 2327000/2506058 texts
# Processed 2328000/2506058 texts
# Processed 2329000/2506058 texts
# Processed 2330000/2506058 texts
# Processed 2331000/2506058 texts
# Processed 2332000/2506058 texts
# Processed 2333000/2506058 texts
# Processed 2334000/2506058 texts
# Processed 2335000/2506058 texts
# Processed 2336000/2506058 texts
# Processed 2337000/2506058 texts
# Processed 2338000/2506058 texts
# Processed 2339000/2506058 texts
# Processed 2340000/2506058 texts
# Processed 2341000/2506058 texts
# Processed 2342000/2506058 texts
# Processed 2343000/2506058 texts
# Processed 2344000/2506058 texts
# Processed 2345000/2506058 texts
# Processed 2346000/2506058 texts
# Processed 2347000/2506058 texts
# Processed 2348000/2506058 texts
# Processed 2349000/2506058 texts
# Processed 2350000/2506058 texts
# Processed 2351000/2506058 texts
# Processed 2352000/2506058 texts
# Processed 2353000/2506058 texts
# Processed 2354000/2506058 texts
# Processed 2355000/2506058 texts
# Processed 2356000/2506058 texts
# Processed 2357000/2506058 texts
# Processed 2358000/2506058 texts
# Processed 2359000/2506058 texts
# Processed 2360000/2506058 texts
# Processed 2361000/2506058 texts
# Processed 2362000/2506058 texts
# Processed 2363000/2506058 texts
# Processed 2364000/2506058 texts
# Processed 2365000/2506058 texts
# Processed 2366000/2506058 texts
# Processed 2367000/2506058 texts
# Processed 2368000/2506058 texts
# Processed 2369000/2506058 texts
# Processed 2370000/2506058 texts
# Processed 2371000/2506058 texts
# Processed 2372000/2506058 texts
# Processed 2373000/2506058 texts
# Processed 2374000/2506058 texts
# Processed 2375000/2506058 texts
# Processed 2376000/2506058 texts
# Processed 2377000/2506058 texts
# Processed 2378000/2506058 texts
# Processed 2379000/2506058 texts
# Processed 2380000/2506058 texts
# Processed 2381000/2506058 texts
# Processed 2382000/2506058 texts
# Processed 2383000/2506058 texts
# Processed 2384000/2506058 texts
# Processed 2385000/2506058 texts
# Processed 2386000/2506058 texts
# Processed 2387000/2506058 texts
# Processed 2388000/2506058 texts
# Processed 2389000/2506058 texts
# Processed 2390000/2506058 texts
# Processed 2391000/2506058 texts
# Processed 2392000/2506058 texts
# Processed 2393000/2506058 texts
# Processed 2394000/2506058 texts
# Processed 2395000/2506058 texts
# Processed 2396000/2506058 texts
# Processed 2397000/2506058 texts
# Processed 2398000/2506058 texts
# Processed 2399000/2506058 texts
# Processed 2400000/2506058 texts
# Processed 2401000/2506058 texts
# Processed 2402000/2506058 texts
# Processed 2403000/2506058 texts
# Processed 2404000/2506058 texts
# Processed 2405000/2506058 texts
# Processed 2406000/2506058 texts
# Processed 2407000/2506058 texts
# Processed 2408000/2506058 texts
# Processed 2409000/2506058 texts
# Processed 2410000/2506058 texts
# Processed 2411000/2506058 texts
# Processed 2412000/2506058 texts
# Processed 2413000/2506058 texts
# Processed 2414000/2506058 texts
# Processed 2415000/2506058 texts
# Processed 2416000/2506058 texts
# Processed 2417000/2506058 texts
# Processed 2418000/2506058 texts
# Processed 2419000/2506058 texts
# Processed 2420000/2506058 texts
# Processed 2421000/2506058 texts
# Processed 2422000/2506058 texts
# Processed 2423000/2506058 texts
# Processed 2424000/2506058 texts
# Processed 2425000/2506058 texts
# Processed 2426000/2506058 texts
# Processed 2427000/2506058 texts
# Processed 2428000/2506058 texts
# Processed 2429000/2506058 texts
# Processed 2430000/2506058 texts
# Processed 2431000/2506058 texts
# Processed 2432000/2506058 texts
# Processed 2433000/2506058 texts
# Processed 2434000/2506058 texts
# Processed 2435000/2506058 texts
# Processed 2436000/2506058 texts
# Processed 2437000/2506058 texts
# Processed 2438000/2506058 texts
# Processed 2439000/2506058 texts
# Processed 2440000/2506058 texts
# Processed 2441000/2506058 texts
# Processed 2442000/2506058 texts
# Processed 2443000/2506058 texts
# Processed 2444000/2506058 texts
# Processed 2445000/2506058 texts
# Processed 2446000/2506058 texts
# Processed 2447000/2506058 texts
# Processed 2448000/2506058 texts
# Processed 2449000/2506058 texts
# Processed 2450000/2506058 texts
# Processed 2451000/2506058 texts
# Processed 2452000/2506058 texts
# Processed 2453000/2506058 texts
# Processed 2454000/2506058 texts
# Processed 2455000/2506058 texts
# Processed 2456000/2506058 texts
# Processed 2457000/2506058 texts
# Processed 2458000/2506058 texts
# Processed 2459000/2506058 texts
# Processed 2460000/2506058 texts
# Processed 2461000/2506058 texts
# Processed 2462000/2506058 texts
# Processed 2463000/2506058 texts
# Processed 2464000/2506058 texts
# Processed 2465000/2506058 texts
# Processed 2466000/2506058 texts
# Processed 2467000/2506058 texts
# Processed 2468000/2506058 texts
# Processed 2469000/2506058 texts
# Processed 2470000/2506058 texts
# Processed 2471000/2506058 texts
# Processed 2472000/2506058 texts
# Processed 2473000/2506058 texts
# Processed 2474000/2506058 texts
# Processed 2475000/2506058 texts
# Processed 2476000/2506058 texts
# Processed 2477000/2506058 texts
# Processed 2478000/2506058 texts
# Processed 2479000/2506058 texts
# Processed 2480000/2506058 texts
# Processed 2481000/2506058 texts
# Processed 2482000/2506058 texts
# Processed 2483000/2506058 texts
# Processed 2484000/2506058 texts
# Processed 2485000/2506058 texts
# Processed 2486000/2506058 texts
# Processed 2487000/2506058 texts
# Processed 2488000/2506058 texts
# Processed 2489000/2506058 texts
# Processed 2490000/2506058 texts
# Processed 2491000/2506058 texts
# Processed 2492000/2506058 texts
# Processed 2493000/2506058 texts
# Processed 2494000/2506058 texts
# Processed 2495000/2506058 texts
# Processed 2496000/2506058 texts
# Processed 2497000/2506058 texts
# Processed 2498000/2506058 texts
# Processed 2499000/2506058 texts
# Processed 2500000/2506058 texts
# Processed 2501000/2506058 texts
# Processed 2502000/2506058 texts
# Processed 2503000/2506058 texts
# Processed 2504000/2506058 texts
# Processed 2505000/2506058 texts
# Processed 2506000/2506058 texts
# Processed 2506058/2506058 texts

# %%
sentiment_df.head()
# Out:
#   ticker_symbol company_name            tweet_id         writer  \
# 0          AAPL        apple  550441672312512512    KeralaGuy77
# 1          TSLA    Tesla Inc  550442977802207232   ShowDreamCar
# 2          AAPL        apple  550444969924653056  AppleNewsAAPL
# 3          AAPL        apple  550444970738335744   espositooooo
# 4          AAPL        apple  550445066444369921     Bidnessetc
#
#              date_utc                                               body  \
# 0 2015-01-01 00:01:36  insanity of today weirdo massive selling $aapl...
# 1 2015-01-01 00:06:47  $gm $tsla volkswagen pushes 2014 record recall...
# 2 2015-01-01 00:14:42  $aapl apple goes global with start something n...
# 3 2015-01-01 00:14:42  @wsj apple is being sued for falsely advertisi...
# 4 2015-01-01 00:15:05  apple filed for its own stylus patent in 2010 ...
#
#    comment_num  retweet_num  like_num  word_count  ...  cashtag_count  \
# 0            0            0         0          20  ...              1
# 1            0            0         1          13  ...              2
# 2            0            0         1          12  ...              1
# 3            0            0         0          15  ...              1
# 4            0            0         0          11  ...              1
#
#    mention_count  cashtag_ratio  hashtag_ratio  mention_ratio  keyword_count  \
# 0              0       0.050000            0.0       0.000000              0
# 1              2       0.153846            0.0       0.153846              0
# 2              1       0.083333            0.0       0.083333              1
# 3              0       0.066667            0.0       0.000000              0
# 4              0       0.090909            0.0       0.000000              0
#
#               date_new_york hour  sentiment  \
# 0 2014-12-31 19:01:36-05:00   19          3
# 1 2014-12-31 19:06:47-05:00   19          1
# 2 2014-12-31 19:14:42-05:00   19          2
# 3 2014-12-31 19:14:42-05:00   19          3
# 4 2014-12-31 19:15:05-05:00   19          1
#
#                                sentiment_probability
# 0  [0.2874074315094731, 0.23019124368310678, 0.48...
# 1  [0.6947310550372033, 0.24863109754717022, 0.05...
# 2  [0.408449110584451, 0.42334809219510977, 0.168...
# 3  [0.29036728717008936, 0.3391678624867592, 0.37...
# 4  [0.5134419420397436, 0.24901102379967055, 0.23...
#
# [5 rows x 21 columns]

# %%
# Replace sentiment values so we can compute their average

# Convert the 'sentiment' column to integer
sentiment_df['sentiment'] = sentiment_df['sentiment'].astype(int)

# Define the mapping of old values to new values
replacement_map = {2: 0, 3: -1}

# Replace the values in the 'sentiment' column
sentiment_df['sentiment'] = sentiment_df['sentiment'].replace(replacement_map)

sentiment_df.head(n=2)
# Out:
#   ticker_symbol company_name            tweet_id        writer  \
# 0          AAPL        apple  550441672312512512   KeralaGuy77
# 1          TSLA    Tesla Inc  550442977802207232  ShowDreamCar
#
#              date_utc                                               body  \
# 0 2015-01-01 00:01:36  insanity of today weirdo massive selling $aapl...
# 1 2015-01-01 00:06:47  $gm $tsla volkswagen pushes 2014 record recall...
#
#    comment_num  retweet_num  like_num  word_count  ...  cashtag_count  \
# 0            0            0         0          20  ...              1
# 1            0            0         1          13  ...              2
#
#    mention_count  cashtag_ratio  hashtag_ratio  mention_ratio  keyword_count  \
# 0              0       0.050000            0.0       0.000000              0
# 1              2       0.153846            0.0       0.153846              0
#
#               date_new_york hour  sentiment  \
# 0 2014-12-31 19:01:36-05:00   19         -1
# 1 2014-12-31 19:06:47-05:00   19          1
#
#                                sentiment_probability
# 0  [0.2874074315094731, 0.23019124368310678, 0.48...
# 1  [0.6947310550372033, 0.24863109754717022, 0.05...
#
# [2 rows x 21 columns]

# %%
# Add column which calculates sentiment score as weighted sum of the probabilites
sentiment_df['sentiment_prob_sum'] = (sentiment_df['sentiment_probability'].apply(lambda p: 1 * p[0] + 0 * p[1] + -1 * p[2]))*100

# Add date_only column
sentiment_df['date_only_NY'] = pd.to_datetime(sentiment_df['date_new_york'].dt.date)

# %%
sentiment_df.head()
# Out:
#   ticker_symbol company_name            tweet_id         writer  \
# 0          AAPL        apple  550441672312512512    KeralaGuy77
# 1          TSLA    Tesla Inc  550442977802207232   ShowDreamCar
# 2          AAPL        apple  550444969924653056  AppleNewsAAPL
# 3          AAPL        apple  550444970738335744   espositooooo
# 4          AAPL        apple  550445066444369921     Bidnessetc
#
#              date_utc                                               body  \
# 0 2015-01-01 00:01:36  insanity of today weirdo massive selling $aapl...
# 1 2015-01-01 00:06:47  $gm $tsla volkswagen pushes 2014 record recall...
# 2 2015-01-01 00:14:42  $aapl apple goes global with start something n...
# 3 2015-01-01 00:14:42  @wsj apple is being sued for falsely advertisi...
# 4 2015-01-01 00:15:05  apple filed for its own stylus patent in 2010 ...
#
#    comment_num  retweet_num  like_num  word_count  ...  cashtag_ratio  \
# 0            0            0         0          20  ...       0.050000
# 1            0            0         1          13  ...       0.153846
# 2            0            0         1          12  ...       0.083333
# 3            0            0         0          15  ...       0.066667
# 4            0            0         0          11  ...       0.090909
#
#    hashtag_ratio  mention_ratio  keyword_count             date_new_york  \
# 0            0.0       0.000000              0 2014-12-31 19:01:36-05:00
# 1            0.0       0.153846              0 2014-12-31 19:06:47-05:00
# 2            0.0       0.083333              1 2014-12-31 19:14:42-05:00
# 3            0.0       0.000000              0 2014-12-31 19:14:42-05:00
# 4            0.0       0.000000              0 2014-12-31 19:15:05-05:00
#
#    hour  sentiment                              sentiment_probability  \
# 0    19         -1  [0.2874074315094731, 0.23019124368310678, 0.48...
# 1    19          1  [0.6947310550372033, 0.24863109754717022, 0.05...
# 2    19          0  [0.408449110584451, 0.42334809219510977, 0.168...
# 3    19         -1  [0.29036728717008936, 0.3391678624867592, 0.37...
# 4    19          1  [0.5134419420397436, 0.24901102379967055, 0.23...
#
#    sentiment_prob_sum  date_only_NY
# 0          -19.499389    2014-12-31
# 1           63.809321    2014-12-31
# 2           24.024631    2014-12-31
# 3           -8.009756    2014-12-31
# 4           27.589491    2014-12-31
#
# [5 rows x 23 columns]

# %%
# Plot average sentiment per hour on a random day

jan_21_2015 = sentiment_df[sentiment_df['date_only_NY']=='2015-01-21']

jan_21_2015_hourly_sentiment = jan_21_2015.groupby(['ticker_symbol', 'hour'])['sentiment_prob_sum'].mean().reset_index()


jan_22_2015 = sentiment_df[sentiment_df['date_only_NY']=='2015-01-22']

jan_22_2015_hourly_sentiment = jan_22_2015.groupby(['ticker_symbol', 'hour'])['sentiment_prob_sum'].mean().reset_index()

jan_23_2015 = sentiment_df[sentiment_df['date_only_NY']=='2015-01-23']

jan_23_2015_hourly_sentiment = jan_23_2015.groupby(['ticker_symbol', 'hour'])['sentiment_prob_sum'].mean().reset_index()

# %%
jan_22_2015_hourly_sentiment.head()
# Out:
#   ticker_symbol  hour  sentiment_prob_sum
# 0          AAPL     0           20.494141
# 1          AAPL     1           32.530002
# 2          AAPL     2           42.145236
# 3          AAPL     4           19.092485
# 4          AAPL     5           14.435276

# %%
companies = np.array(jan_21_2015_hourly_sentiment['ticker_symbol'].unique())

# %%
import matplotlib.pyplot as plt

# Assuming 'companies' and your dataframes are already defined and imported
plt.figure(figsize=(20, 10))
for i in range(len(companies)):
    # Specific hours where vertical lines should be added
    vertical_lines = [8, 9, 16, 17]

    # Plot for January 21, 2015
    plt.subplot(3, 5, 1 + i)
    df = jan_21_2015_hourly_sentiment[jan_21_2015_hourly_sentiment['ticker_symbol'] == companies[i]]
    mean_sentiment = df['sentiment_prob_sum'].mean()  # Calculate mean sentiment
    plt.plot(df['hour'], df['sentiment_prob_sum'])
    plt.axhline(y=mean_sentiment, color='r', linestyle='--')  # Plot mean line
    for hour in vertical_lines:
        plt.axvline(x=hour, color='g', linestyle=':')  # Add vertical lines
    plt.title(companies[i])

    # Plot for January 22, 2015
    plt.subplot(3, 5, 6 + i)
    df = jan_22_2015_hourly_sentiment[jan_22_2015_hourly_sentiment['ticker_symbol'] == companies[i]]
    mean_sentiment = df['sentiment_prob_sum'].mean()
    plt.plot(df['hour'], df['sentiment_prob_sum'])
    plt.axhline(y=mean_sentiment, color='r', linestyle='--')
    for hour in vertical_lines:
        plt.axvline(x=hour, color='g', linestyle=':')  # Add vertical lines
    plt.title(companies[i])

    # Plot for January 23, 2015
    plt.subplot(3, 5, 11 + i)
    df = jan_23_2015_hourly_sentiment[jan_23_2015_hourly_sentiment['ticker_symbol'] == companies[i]]
    mean_sentiment = df['sentiment_prob_sum'].mean()
    plt.plot(df['hour'], df['sentiment_prob_sum'])
    plt.axhline(y=mean_sentiment, color='r', linestyle='--')
    for hour in vertical_lines:
        plt.axvline(x=hour, color='g', linestyle=':')  # Add vertical lines
    plt.title(companies[i])

plt.show()  # Ensure this is correctly called to display the figure

# %% [markdown]
# ## Create slope variable for sentiment index
# The slope refers to the slope from hour 9 until hour 16, so actually 9:00 - 16:59.

# %%
hourly_sentiment = sentiment_df.groupby(['ticker_symbol', 'date_only_NY', 'hour'])['sentiment_prob_sum'].mean().reset_index()

# %%
hourly_sentiment.head()
# Out:
#   ticker_symbol date_only_NY  hour  sentiment_prob_sum
# 0          AAPL   2014-12-31    19           16.724170
# 1          AAPL   2014-12-31    20           28.704085
# 2          AAPL   2014-12-31    21           28.592820
# 3          AAPL   2014-12-31    22           10.454112
# 4          AAPL   2014-12-31    23            7.722677

# %%
hourly_sentiment_9_16 = hourly_sentiment[(hourly_sentiment['hour']==9)|(hourly_sentiment['hour']==16)]

# %%
hourly_sentiment_9_16
# Out:
#        ticker_symbol date_only_NY  hour  sentiment_prob_sum
# 14              AAPL   2015-01-01     9           23.756269
# 21              AAPL   2015-01-01    16           -0.296172
# 38              AAPL   2015-01-02     9           10.946513
# 45              AAPL   2015-01-02    16           20.420781
# 60              AAPL   2015-01-03     9           21.854713
# ...              ...          ...   ...                 ...
# 192392          TSLA   2019-12-29    16            5.504922
# 192409          TSLA   2019-12-30     9            5.077862
# 192416          TSLA   2019-12-30    16           15.368888
# 192433          TSLA   2019-12-31     9           18.184076
# 192440          TSLA   2019-12-31    16           14.199853
#
# [17208 rows x 4 columns]

# %%
(10.946513-20.420781)/(16-9)
# Out:
# -1.3534668571428574

# %%
# Manual test for first observations
(0.109465-0.204208)/(16-9)
# Out:
# -0.013534714285714285

# %%
import pandas as pd

# Since I cannot directly load the dataframe from a CSV file, I'll simulate the process with dummy data.
# I will write the code assuming the dataframe has been loaded from a CSV file as `df`.

# Sample data structure based on the provided image
# data = {
#     'ticker_symbol': ['AAPL', 'AAPL', 'AAPL', 'AAPL', 'TSLA', 'TSLA', 'TSLA', 'TSLA'],
#     'date_only_NY': ['2015-01-01', '2015-01-01', '2015-01-02', '2015-01-02', '2019-12-30', '2019-12-30', '2019-12-31', '2019-12-31'],
#     'hour': [9, 16, 9, 16, 9, 16, 9, 16],
#     'sentiment_prob_sum': [0.237563, -0.002962, 0.109465, 0.204208, 0.050779, 0.153689, 0.181841, 0.141999]
# }

# # Create a DataFrame
# df = pd.DataFrame(data)

# Function to calculate slope given two points
def calculate_slope(y1, y2, x1=9, x2=16):
    return (y2 - y1) / (x2 - x1)

# Group by 'ticker_symbol' and 'date_only_NY' and calculate the slope for each group
def group_and_calculate_slope(df):
    grouped = df.groupby(['ticker_symbol', 'date_only_NY'])
    slopes = {}
    
    for name, group in grouped:
        if group[group['hour'] == 9]['sentiment_prob_sum'].empty or group[group['hour'] == 16]['sentiment_prob_sum'].empty:
            # If data for both hours is not available, skip this group
            continue
        
        y1 = group[group['hour'] == 9]['sentiment_prob_sum'].values[0]
        y2 = group[group['hour'] == 16]['sentiment_prob_sum'].values[0]
        slope = calculate_slope(y1, y2)
        slopes[name] = slope
    
    # Convert the slopes dictionary to a DataFrame
    slopes_df = pd.DataFrame(list(slopes.items()), columns=['Group', 'slope'])
    # Split 'Group' back into the original columns
    slopes_df[['ticker_symbol', 'date_only_NY']] = pd.DataFrame(slopes_df['Group'].tolist(), index=slopes_df.index)
    # Drop the 'Group' column as it is no longer needed
    slopes_df.drop('Group', axis=1, inplace=True)
    
    return slopes_df

# We will call the function once the user provides their data
# slope_df = group_and_calculate_slope(df)

# For now, just to demonstrate, we will uncomment the above line
# Note: This should only be uncommented when the user's actual data is loaded
slope_df = group_and_calculate_slope(hourly_sentiment_9_16)
slope_df
# Out:
#          slope ticker_symbol date_only_NY
# 0    -3.436063          AAPL   2015-01-01
# 1     1.353467          AAPL   2015-01-02
# 2     1.044999          AAPL   2015-01-03
# 3     1.955365          AAPL   2015-01-04
# 4    -2.148962          AAPL   2015-01-05
# ...        ...           ...          ...
# 8213 -1.508083          TSLA   2019-12-27
# 8214  0.802217          TSLA   2019-12-28
# 8215 -0.509695          TSLA   2019-12-29
# 8216  1.470147          TSLA   2019-12-30
# 8217 -0.569175          TSLA   2019-12-31
#
# [8218 rows x 3 columns]

# %%
sentiment_df
# Out:
#         ticker_symbol company_name             tweet_id         writer  \
# 0                AAPL        apple   550441672312512512    KeralaGuy77
# 1                TSLA    Tesla Inc   550442977802207232   ShowDreamCar
# 2                AAPL        apple   550444969924653056  AppleNewsAAPL
# 3                AAPL        apple   550444970738335744   espositooooo
# 4                AAPL        apple   550445066444369921     Bidnessetc
# ...               ...          ...                  ...            ...
# 2506053          AAPL        apple  1212159275637886976     GMGRIFF_79
# 2506054          TSLA    Tesla Inc  1212160015332728833    Commuternyc
# 2506055          AAPL        apple  1212160410692046849    MoriaCrypto
# 2506056          MSFT    Microsoft  1212160410692046849    MoriaCrypto
# 2506057          AAPL        apple  1212160477159206912       treabase
#
#                    date_utc  \
# 0       2015-01-01 00:01:36
# 1       2015-01-01 00:06:47
# 2       2015-01-01 00:14:42
# 3       2015-01-01 00:14:42
# 4       2015-01-01 00:15:05
# ...                     ...
# 2506053 2019-12-31 23:51:06
# 2506054 2019-12-31 23:54:03
# 2506055 2019-12-31 23:55:37
# 2506056 2019-12-31 23:55:37
# 2506057 2019-12-31 23:55:53
#
#                                                       body  comment_num  \
# 0        insanity of today weirdo massive selling $aapl...            0
# 1        $gm $tsla volkswagen pushes 2014 record recall...            0
# 2        $aapl apple goes global with start something n...            0
# 3        @wsj apple is being sued for falsely advertisi...            0
# 4        apple filed for its own stylus patent in 2010 ...            0
# ...                                                    ...          ...
# 2506053  $aapl yearly~ heck of a year jan 2 19~around 2...            0
# 2506054  patiently waiting for the no twitter sitter tw...            0
# 2506055     i dont discriminate i own both $aapl and $msft            1
# 2506056     i dont discriminate i own both $aapl and $msft            1
# 2506057  $aapl #patent 10522475 vertical interconnects ...            0
#
#          retweet_num  like_num  word_count  ...  cashtag_ratio  hashtag_ratio  \
# 0                  0         0          20  ...       0.050000       0.000000
# 1                  0         1          13  ...       0.153846       0.000000
# 2                  0         1          12  ...       0.083333       0.000000
# 3                  0         0          15  ...       0.066667       0.000000
# 4                  0         0          11  ...       0.090909       0.000000
# ...              ...       ...         ...  ...            ...            ...
# 2506053            0         1          28  ...       0.035714       0.000000
# 2506054            0         5          10  ...       0.200000       0.000000
# 2506055            0         1           9  ...       0.222222       0.000000
# 2506056            0         1           9  ...       0.222222       0.000000
# 2506057            0         0          17  ...       0.058824       0.235294
#
#          mention_ratio  keyword_count             date_new_york  hour  \
# 0             0.000000              0 2014-12-31 19:01:36-05:00    19
# 1             0.153846              0 2014-12-31 19:06:47-05:00    19
# 2             0.083333              1 2014-12-31 19:14:42-05:00    19
# 3             0.000000              0 2014-12-31 19:14:42-05:00    19
# 4             0.000000              0 2014-12-31 19:15:05-05:00    19
# ...                ...            ...                       ...   ...
# 2506053       0.000000              0 2019-12-31 18:51:06-05:00    18
# 2506054       0.000000              0 2019-12-31 18:54:03-05:00    18
# 2506055       0.000000              0 2019-12-31 18:55:37-05:00    18
# 2506056       0.000000              0 2019-12-31 18:55:37-05:00    18
# 2506057       0.000000              0 2019-12-31 18:55:53-05:00    18
#
#          sentiment                              sentiment_probability  \
# 0               -1  [0.2874074315094731, 0.23019124368310678, 0.48...
# 1                1  [0.6947310550372033, 0.24863109754717022, 0.05...
# 2                0  [0.408449110584451, 0.42334809219510977, 0.168...
# 3               -1  [0.29036728717008936, 0.3391678624867592, 0.37...
# 4                1  [0.5134419420397436, 0.24901102379967055, 0.23...
# ...            ...                                                ...
# 2506053          1  [0.5647189735587874, 0.17752359647354973, 0.25...
# 2506054          0  [0.20547908629937525, 0.6204739258118407, 0.17...
# 2506055          0  [0.3006229924433762, 0.4258143532689962, 0.273...
# 2506056          0  [0.3006229924433762, 0.4258143532689962, 0.273...
# 2506057          0  [0.358996990880133, 0.5288608231597796, 0.1121...
#
#          sentiment_prob_sum  date_only_NY
# 0                -19.499389    2014-12-31
# 1                 63.809321    2014-12-31
# 2                 24.024631    2014-12-31
# 3                 -8.009756    2014-12-31
# 4                 27.589491    2014-12-31
# ...                     ...           ...
# 2506053           30.696154    2019-12-31
# 2506054            3.143210    2019-12-31
# 2506055            2.706034    2019-12-31
# 2506056            2.706034    2019-12-31
# 2506057           24.685480    2019-12-31
#
# [2506058 rows x 23 columns]

# %%
plt.scatter(sentiment_df['date_only_NY'], sentiment_df['sentiment_prob_sum'], alpha=0.005)

# %% [markdown]
# ## Calculate unweighted sentiment score per day
#
# With the information available in our dataset, we can't set the like, comment, or retweet numbers in relation to the number of views of the tweet or the author's number of followers! Therefore, weighting the sentiment scores could falsely skew resulting index!

# %%
unweighted_sentiment_df = sentiment_df.groupby(['date_only_NY', 'ticker_symbol'])['sentiment_prob_sum'].mean().reset_index()
unweighted_sentiment_df.columns = ['date_only_NY', 'ticker_symbol', 'unweighted_sentiment_score']

# %%
unweighted_sentiment_df.head(n=10)
# Out:
#   date_only_NY ticker_symbol  unweighted_sentiment_score
# 0   2014-12-31          AAPL                   18.750514
# 1   2014-12-31          AMZN                   -8.042008
# 2   2014-12-31        GOOGLE                   33.188118
# 3   2014-12-31          MSFT                   20.584616
# 4   2014-12-31          TSLA                   48.626714
# 5   2015-01-01          AAPL                   16.954817
# 6   2015-01-01          AMZN                   16.196345
# 7   2015-01-01        GOOGLE                   13.411162
# 8   2015-01-01          MSFT                   18.125337
# 9   2015-01-01          TSLA                   12.342289

# %%
slope_df
# Out:
#          slope ticker_symbol date_only_NY
# 0    -3.436063          AAPL   2015-01-01
# 1     1.353467          AAPL   2015-01-02
# 2     1.044999          AAPL   2015-01-03
# 3     1.955365          AAPL   2015-01-04
# 4    -2.148962          AAPL   2015-01-05
# ...        ...           ...          ...
# 8213 -1.508083          TSLA   2019-12-27
# 8214  0.802217          TSLA   2019-12-28
# 8215 -0.509695          TSLA   2019-12-29
# 8216  1.470147          TSLA   2019-12-30
# 8217 -0.569175          TSLA   2019-12-31
#
# [8218 rows x 3 columns]

# %% [markdown]
# ## Merge sentiment score with slope data

# %%
sentiment_slope_df = pd.merge(unweighted_sentiment_df, slope_df, on=['date_only_NY', 'ticker_symbol'])

# %%
sentiment_slope_df
# Out:
#      date_only_NY ticker_symbol  unweighted_sentiment_score     slope
# 0      2015-01-01          AAPL                   16.954817 -3.436063
# 1      2015-01-01          MSFT                   18.125337 -1.379211
# 2      2015-01-01          TSLA                   12.342289  5.328461
# 3      2015-01-02          AAPL                   14.257538  1.353467
# 4      2015-01-02          AMZN                   14.802526 -2.150535
# ...           ...           ...                         ...       ...
# 8213   2019-12-31          AAPL                   23.646889  0.002828
# 8214   2019-12-31          AMZN                   23.837000  0.774379
# 8215   2019-12-31        GOOGLE                   19.388827 -7.318812
# 8216   2019-12-31          MSFT                   25.408442  0.854491
# 8217   2019-12-31          TSLA                   17.032508 -0.569175
#
# [8218 rows x 4 columns]

# %% [markdown]
# # Load market cap data

# %%
companies
# Out:
# array(['AAPL', 'AMZN', 'GOOGLE', 'MSFT', 'TSLA'], dtype=object)

# %%
# Load market cap file

market_cap_path = "https://raw.githubusercontent.com/inga-maria01/master_thesis/main/data/market_cap/total_market_cap_2015-2019.xlsx"

market_cap_df = pd.read_excel(market_cap_path).sort_values("date").reset_index(drop=True)

market_cap_df['date'] = pd.to_datetime(market_cap_df['date'])

market_cap_df['weights_abs'] = market_cap_df['weights_abs'].astype(int)

market_cap_df['weights_rel'] = market_cap_df.groupby('date')['weights_abs'].transform(lambda x: x / x.sum())

# replace company ticker by company name for a smooth join

replacements = {"AAPL.O": "AAPL", "AMZN.O": "AMZN", "GOOG.O": "GOOGLE", "MSFT.O": "MSFT", "TSLA.O": "TSLA"}

market_cap_df['company_ticker'] = market_cap_df['company_ticker'].replace(replacements)

market_cap_df.rename(columns={'company_ticker': 'ticker_symbol'}, inplace=True)

# %%
market_cap_df.head(n=10)
# Out:
#   ticker_symbol       date  weekday    market_cap   weights_abs  weights_rel
# 0          AAPL 2015-01-02        4  6.412030e+11  697510000000     0.422972
# 1          TSLA 2015-01-02        4  2.749748e+10   30660000000     0.018592
# 2        GOOGLE 2015-01-02        4  3.576201e+11  370020000000     0.224381
# 3          MSFT 2015-01-02        4  3.854358e+11  394090000000     0.238977
# 4          AMZN 2015-01-02        4  1.434618e+11  156790000000     0.095078
# 5        GOOGLE 2015-01-05        0  3.504869e+11  370020000000     0.224381
# 6          AMZN 2015-01-05        0  1.405184e+11  156790000000     0.095078
# 7          TSLA 2015-01-05        0  2.634146e+10   30660000000     0.018592
# 8          AAPL 2015-01-05        0  6.231392e+11  697510000000     0.422972
# 9          MSFT 2015-01-05        0  3.818502e+11  394090000000     0.238977

# %%
# # Fill in values for non-workdays

# import pandas as pd
# import numpy as np

# # # Example DataFrame creation
# # data = {
# #     'company_name': ['Company A', 'Company A', 'Company B', 'Company B'],
# #     'date': ['2015-01-01', '2015-01-02', '2015-01-01', '2015-01-02'],
# #     'weekday': ['Thursday', 'Friday', 'Thursday', 'Friday'],
# #     'market_cap': [100, 105, 200, 210],
# #     'weights_abs': [10, 10.5, 20, 21],
# #     'weights_rel': [0.1, 0.105, 0.2, 0.21]
# # }

# # # Create DataFrame
# # df = pd.DataFrame(data)

# # Convert 'date' column to datetime
# market_cap_df['date'] = pd.to_datetime(market_cap_df['date'])

# # Create copy to not overwrite market_cap_df
# market_cap_copy = market_cap_df.copy()

# # Set the 'date' as index
# market_cap_copy.set_index('date', inplace=True)

# # Creating a full date range from 2015-01-01 to 2015-01-04 (for this example)
# all_dates = pd.date_range(start='2015-01-01', end='2019-12-31')

# # Reindexing DataFrame to the new date range for each company
# market_cap_full_df = market_cap_copy.groupby('company_name').apply(lambda x: x.reindex(all_dates).ffill()).reset_index(level=0, drop=True)

# # Fix the 'weekday' column to reflect the correct day of the week
# market_cap_full_df['weekday'] = market_cap_full_df.index.day_name()

# # Reset the index to convert 'date' from index to a regular column and reindex with default integer indexing
# market_cap_full_df = market_cap_full_df.reset_index().rename(columns={'index': 'date'})

# %%
# Fill 2015-01-01 with values from 2015-01-02
# jan_01_2015_data = np.array(market_cap_full_df[market_cap_full_df['date']=="2015-01-01"].index)

# %%
# for idx in jan_01_2015_data:
#     market_cap_full_df.loc[idx, 'company_name'] = market_cap_full_df.loc[idx+1, 'company_name']
#     market_cap_full_df.loc[idx, 'market_cap'] = market_cap_full_df.loc[idx+1, 'market_cap']
#     market_cap_full_df.loc[idx, 'weights_abs'] = market_cap_full_df.loc[idx+1, 'weights_abs']
#     market_cap_full_df.loc[idx, 'weights_rel'] = market_cap_full_df.loc[idx+1, 'weights_rel']

# %%
# market_cap_full_df[(market_cap_full_df['date']=="2015-01-01") | (market_cap_full_df['date']=="2015-01-02")]

# %%
# market_cap_full_sorted_df = market_cap_full_df.sort_values(by='date').reset_index(drop=True)
# market_cap_full_sorted_df.head(n=10)

# %%
# before joining, adapt column names of sentiment_slope_df
sentiment_slope_df.rename(columns={'date_only_NY': 'date'}, inplace=True)
sentiment_slope_df['date'] = pd.to_datetime(sentiment_slope_df['date'])

# join market_cap_df and unweighted_sentiment_df
unweighted_sentiment_market_cap_df = pd.merge(market_cap_df, sentiment_slope_df, on=['date', 'ticker_symbol'])

# %%
unweighted_sentiment_market_cap_df.head()
# Out:
#   ticker_symbol       date  weekday    market_cap   weights_abs  weights_rel  \
# 0          AAPL 2015-01-02        4  6.412030e+11  697510000000     0.422972
# 1        GOOGLE 2015-01-02        4  3.576201e+11  370020000000     0.224381
# 2          MSFT 2015-01-02        4  3.854358e+11  394090000000     0.238977
# 3          AMZN 2015-01-02        4  1.434618e+11  156790000000     0.095078
# 4        GOOGLE 2015-01-05        0  3.504869e+11  370020000000     0.224381
#
#    unweighted_sentiment_score     slope
# 0                   14.257538  1.353467
# 1                   13.852859 -0.194901
# 2                   18.646783 -1.888971
# 3                   14.802526 -2.150535
# 4                   14.581922  3.973458

# %%
# Calculate the weighted average of sentiment per day
sentiment_index_unweighted_df = unweighted_sentiment_market_cap_df.groupby('date').apply(
    lambda x: pd.Series({
        'sentiment_score': (x['weights_rel'] * x['unweighted_sentiment_score']).sum(),
        'sentiment_slope': (x['weights_rel'] * x['slope']).sum()
        })
).reset_index()

# Moving average sentiment (now calculated in model file)
# sentiment_index_unweighted_df['moving_average'] = sentiment_index_unweighted_df['sentiment_score'].rolling(window=30).mean()

# %%
sentiment_index_unweighted_df.head(n=10)
# Out:
#         date  sentiment_score  sentiment_slope
# 0 2015-01-02        15.002401        -0.127143
# 1 2015-01-05        17.779190        -1.688521
# 2 2015-01-06        11.840299         0.484480
# 3 2015-01-07        18.581044        -1.852799
# 4 2015-01-08        15.674553         0.916068
# 5 2015-01-09        19.543640        -2.596250
# 6 2015-01-12        15.939740         0.376702
# 7 2015-01-13        21.351272        -1.680963
# 8 2015-01-14        19.197966        -1.579964
# 9 2015-01-15        16.805301         0.454067

# %%
plt.figure(figsize=(20,5))
plt.subplot(1, 2, 1)
plt.plot(sentiment_index_unweighted_df['date'],sentiment_index_unweighted_df['sentiment_score'])
plt.title('sentiment_index_unweighted_df')
plt.subplot(1, 2, 2)
plt.plot(sentiment_index_unweighted_df['date'],sentiment_index_unweighted_df['sentiment_slope'])
plt.title('sentiment_index_unweighted_df slope')
plt.show()

# %% [markdown]
# ## Save index to xlsx file

# %%
# Save index to xlsx
sentiment_index_unweighted_path = "Users/friederikeeichholz/Library/CloudStorage/OneDrive-LundUniversity/Desktop/DABN01_Thesis/index/sentiment_index_unweighted_v4.xlsx"

sentiment_index_unweighted_df.to_excel(sentiment_index_unweighted_path, index=False)
